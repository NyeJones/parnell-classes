# %% [markdown]
# # BERTopic and Parnell

# %% [markdown]
# ## Google Colab

# %% [markdown]
# File paths on Google Drive
# - Navigate to 'My Drive' then
# - Speech report files in this directory location: 'parnell_files/sources'
# - Speech register file in this directory location: 'parnell_files/speeches'
#
# In Google Colab
# - Before running anything go to 'Edit' in the toolbar at the top of the screen
# - Click on 'Notebook settings' in the dropdown menu
# - Change 'Hardware accelerator' to 'T4 GPU'
# - Save changes
#
# You should now be ready to run this notebook in Google Colab!

# %% [markdown]
# ## Research Question

# %% [markdown]
# In this session we will explore the use of topic modelling in relation to Parnell's speeches. We will look for the main topics which appear in the speech reports and also explore filtering the corpus by date range, place, publication and keywords, before performing topic modelling on the resulting dataset. The results will be visualised in a series of graphs showing different aspects of the topics.
#
# Having extracted some topics from the speech reports, we will be able to return to the tools used in the network analysis session to gain some additional context for our overall analysis.

# %% [markdown]
# ## Topic Modelling

# %% [markdown]
# Topic models enable us to identify the latent topics within a collection of texts. They capture the underlying themes across a corpus by clustering together similar texts based on their content, essentially using the co-occurrence of words or semantic content within documents as the basis of this process.
#
# We will be using BERTopic, a highly effective topic modelling tool that uses BERT (Bidirectional Encoder Representations from Transformers) as its basis. Transformer models enable word meanings to be recognised in context, thereby allowing for greater accuracy in terms of identifying the semantic associations which make up topics.

# %% [markdown]
# ## Interactivity

# %% [markdown]
# All cells are alterable but some cells that are easy to work with interactively are highlighted at the end of the notebook. These are highlighted with the phrase 'Alterable Cells' above them in blue and have instructions

# %% [markdown]
# # Python Code

# %%
# !pip install bertopic

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/parnell_files

# %% [markdown]
# Import additional Python Libraries.

# %%
#libraries for working with files
import glob
import os
from pathlib import Path
from natsort import natsorted
from natsort import os_sorted
#libraries for data analysis and manipulation
import pandas as pd
import string
import re
from bs4 import BeautifulSoup
from datetime import datetime
#nlp libraries
import spacy
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters
from gensim.utils import simple_preprocess
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from bertopic import BERTopic
#libraries for visualisations
import plotly.express as px

#optimise notebook and spacy settings
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## Functions

# %% [markdown]
# In this notebook we will be using more functions than in previous weeks. Essentially functions divide the code up into smaller units, with each unit having a specific task. A key advantage of functions is that they can be "called" repeatedly with different inputs, so you don't have to write out a very similar piece of code repeatedly. They also keep everything well-organized and enable modularity, so that independent parts of the code can be checked and maintained separately.
#
# Functions are usually kept at the top of the code, after importing libraries and creating global settings, and are called during the execution of the code below. Explanations for what each function does are kept in a "docstring", in quotation marks after the "def" statement which begins each function.

# %% [markdown]
# ### Data Extraction Functions

# %% [markdown]
# Functions which perform the various aspects of getting from a list of file paths through to extracting specific parts of each file.

# %%
def soup_objects(file_paths):
    '''Takes either a list of file paths or a file path.
    Returns a list of beautiful soup objects or single
    beautiful soup object, depending on the input.
    '''
    if type(file_paths) == list:
        soup_list = []
        for path in file_paths:
            with path.open("r", encoding="utf-8") as xml:
                source = BeautifulSoup(xml, "lxml-xml")
                soup_list.append(source)
        return soup_list
    else:
        with file_paths.open("r", encoding="utf-8") as xml:
            soup_object = BeautifulSoup(xml, "lxml-xml")
        return soup_object

# %%
def tei_extractor(soup_obj, element, attributes=False):
    '''Takes Beautiful soup object or list of objects,
    element using element name and, where necessary, attributes.
    Returns list of elements for all input files or a list of
    elements for input file, depending on input.
    '''
    attrib_dict ={}
    if attributes:
        attrib_dict = {attr: True for attr in attributes}

    if type(soup_obj) == list:
        elem_ls = [obj.find(element, attrib_dict) for obj in soup_obj]
        return elem_ls
    else:
        elem_ls = soup_obj.find_all(element, attrib_dict)
        return elem_ls

# %%
def tei_values(object_list, attribute=False):
    '''Takes a list of beautiful soup elements, if attribute
    value is being extracted include name of that attribute.
    Return element or attribute value depending on input(s)
    '''
    if attribute:
        values = [obj[attribute] for obj in object_list]
        return values
    else:
        values = [obj.get_text() for obj in object_list]
        return values

# %% [markdown]
# ### Data Cleaning and Dataframe Functions

# %% [markdown]
# Functions to perform text cleaning, remove stopwords, convert results into dataframe format and clean dataframe format data.

# %%
def text_cleaning(text):
    '''Takes as input a string, removes/replaces special characters, newlines,
    possessive apostrophes, hyphens, underscores, digits and makes single space.
    Keeps punctuation in place.
    Returns clean string.
    '''
    text = text.replace(u"\xa0", u" ").replace("&", "and").replace("|", " ")
    text = text.replace("\n", " ").replace("’", "'").replace("'s ", ' ')
    text = text.replace("-", " "). replace("–", " ").replace("_", " ").replace("—", " ")
    non_digit_text = re.sub(r"\b\d+\b", "", text)
    sing_space_text = re.sub(r"\s\s+", " ", non_digit_text)
    sing_space_text = sing_space_text.strip()
    return sing_space_text

# %%
def punct_removal(text):
    '''Takes as input a string and removes punctuation, removes extra spacing.
    Returns string without punctuation.
    '''
    text = text.translate(str.maketrans(" ", " ", string.punctuation))
    text = re.sub(r"\s\s+", " ", text)
    text = text.strip()
    return text

# %%
def remove_stopwords(text, stopwords):
    ''' Take as input a string and list of stopwords, tokenizes
    string and removes words contained in stopwords.
    Returns re-joined string without stopwords.
    '''
    tokenized_text = text.split()
    non_stop_text = [token for token in tokenized_text if token not in stopwords]
    return ' '.join(non_stop_text)

# %%
def create_dataframe(data, columns):
    '''Takes as input a list of lists of data and a list of columns.
    Returns a dataframe.
    '''
    df = pd.DataFrame(data)
    df = df.transpose()
    df.columns = columns
    return df

# %%
def dataframe_cleaning(dataframe, clean_column=None):
    '''Takes as input a dataframe and makes lowercase, strips leading and
    trailing spaces, standardises apostrophes. Applies text_cleaning function
    to column if identified as clean column parameter.
    Returns lowercase/cleaned dataframe.
    '''
    lower_dataframe = dataframe.applymap(lambda x: x.lower())
    lower_dataframe = lower_dataframe.applymap(lambda x: x.replace("’", "'"))
    if clean_column:
        lower_dataframe[clean_column] = lower_dataframe[clean_column].apply(lambda x: text_cleaning(x))
    clean_dataframe = lower_dataframe.applymap(lambda x: x.strip())
    return clean_dataframe

# %% [markdown]
# ### Dataframe Filtering

# %% [markdown]
# Functions to filter dataframe by date range and keywords.

# %%
def dataframe_date_window(dataframe, start_date, end_date):
    '''Takes as input dataframe, start date and end date.
    Returns dataframe with just the rows where the date is on/between
    the start date and end date.
    '''
    mask = (dataframe['date'] > start_date) & (dataframe['date'] <= end_date)
    win_dataframe = dataframe.loc[mask]
    return win_dataframe

# %%
def dataframe_keyword_any(dataframe, column, keywords):
    '''Takes as input dataframe, column name and a list of keywords.
    Returns dataframe with just rows where column contains any
    of the words in keywords as substring.
    '''
    keyword_df = dataframe[dataframe[column].apply
                           (lambda cell: any(re.search(word, cell) for word in keywords))]
    return keyword_df

# %%
def dataframe_keyword_all(dataframe, column, keywords):
    '''Takes as input dataframe, column name and a list of keywords.
    Returns dataframe with just rows where column contains all
    of the words in keywords as substring.
    '''
    keyword_df = dataframe[dataframe[column].apply
                           (lambda cell: all(re.search(word, cell) for word in keywords))]
    return keyword_df

# %% [markdown]
# ### Topic Modelling, Sentence Counts and Visualisation

# %% [markdown]
# Functions to perform topic modelling and counts of sentences per year and return visualisations.

# %%
def bertopic_topics(dataframe, topic_model):
    '''Takes as input a dataframe and Bertopic topic model tool.
    Extracts dates and sentences for each dataframe row as lists.
    Fits sentence list to topic model, creates dictionary of topics/sentences.
    Returns topics, topic/sentence dictionary and topic model.
    '''
    sent_list = dataframe["sentence"].to_list()
    topics, probs = topic_model.fit_transform(sent_list)

    topic_docs = {topic: [] for topic in set(topics)}
    for topic, doc in zip(topics, sent_list):
        topic_docs[topic].append(doc)
    return (topics, topic_docs, topic_model)

# %%
def bertopic_time(dataframe, topic_model):
    '''Takes as input a dataframe and Bertopic topic model.
    Extracts dates and sentences for each dataframe row as lists.
    Sends sentence list/dates to topics_over_time provided by BERTopic 
    to create visualisation.
    Returns visualisation'''
    sent_list = dataframe["sentence"].to_list()
    date_list = dataframe["date"].to_list()
    #parameters can be adjusted for visualisation
    topics_over_time = topic_model.topics_over_time(docs=sent_list,
                                                timestamps=date_list,
                                                nr_bins=30
                                              )
    fig = topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=15, height=500, width=1000)
    fig.update_layout(yaxis_title = "Count")
    return (fig)

# %%
def year_counts(dataframe):
    '''Takes as input a dataframe.
    Returns a series with number of sentences per year.
    '''
    dataframe["year"] = dataframe["date"].dt.year
    year_counts = dataframe.groupby(["year"]).size()
    return year_counts

# %%
def year_counts_plot(year_counts):
    '''Takes as input a year count series.
    Returns a plotly bar chart of number of sentences per year.
    '''
    year_counts_plot = px.bar(year_counts,
                          title="Sentence Count by Year",
                          labels= {
                              "value":"Count",
                              "year":"Year"
                          }
                         )
    year_counts_plot.update_layout(showlegend=False)
    return year_counts_plot

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# We begin by extracting the data we need from the speech report files and the speech register file.

# %%
# get paths for speech reports
dir_path = Path('sources/')
#get filepaths to all the XML files in the directory
xml_files = (file for file in dir_path.iterdir() if file.is_file() and file.name.lower().endswith('.xml'))
#sort xml file paths numerically using os_sorted library
xml_files = os_sorted(xml_files)

#get path for speech register file
speech_file = Path('speeches/parnell_speeches.xml')

#basename returns filename removing directory path.
#split to remove ".xml" extension so that we can use later in dataframe as id
filenames = []
for path in xml_files:
    filename = os.path.basename(path)
    filename = filename.split(".")[0]
    filenames.append(filename)

# %%
#extract speech reports and speech register as beautiful soup objects using function
report_objects = soup_objects(xml_files)
speech_object = soup_objects(speech_file)

# %%
#speech register beautiful soup objects extracted as lists using function
#speech id, speech place and data
speech_objs = tei_extractor(speech_object, element='speech_id')
place_objs = tei_extractor(speech_object, element='place', attributes=['key'])
date_objs = tei_extractor(speech_object, element='date', attributes=['when'])

#speech reports beautiful soup objects extracted as lists using function
#speech id, publication name, text
speech_rep_objs = tei_extractor(report_objects, element='term', attributes=['key'])
publication_objs = tei_extractor(report_objects, element='title', attributes=['key', 'level'])
text_objs = tei_extractor(report_objects, element='body')

# %%
#use function to extract values from tei elements extracted above
speech_ids = tei_values(speech_objs)
speech_places = tei_values(place_objs)
speech_dates = tei_values(date_objs, attribute='when')

speech_rep_ids = tei_values(speech_rep_objs, attribute='key')
publications = tei_values(publication_objs)
texts = tei_values(text_objs)

#for speech ids, if more than one id present, shown by inclusion of comma, convert into a list
#some reports refer to more than one speech, so we need to capture them all 
speech_rep_ids = [item.split(',') if ',' in item else item for item in speech_rep_ids]

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# The next stage is to convert the speech data into a dataframe format where we can easily manipulate it and get different subsets prior to analysis/visualisation.

# %% [markdown]
# ### Speech Report Dataframe

# %% [markdown]
# We begin by converting the speech report data into a dataframe and performing some data cleaning on the text to standardise it and make it more suitable for data analysis. This includes making the text lower case, removing extra spacing and some special characters.

# %%
#prepare data for speech report dataframe, make list of lists of data and list of column names
speech_rep_data = [filenames, speech_rep_ids, publications, texts]
speech_rep_columns = ['filename', 'speech_id', 'publication', 'sentence']
#use function to turn the above lists into dataframe
speech_rep_df = create_dataframe(speech_rep_data, speech_rep_columns)
#if there is more than one speech id for a report, the report data will appear as row for each id
speech_rep_df = speech_rep_df.explode('speech_id')
#use function to clean the text in the dataframe and standardise it
speech_rep_df = dataframe_cleaning(speech_rep_df, clean_column='sentence')
speech_rep_df
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 2    parnell_source_00003  speech_00001             the nation
# 3    parnell_source_00004  speech_00001        the irish times
# 4    parnell_source_00005  speech_00002  the freeman's journal
# ..                    ...           ...                    ...
# 656  parnell_source_00660  speech_00396  the freeman's journal
# 657  parnell_source_00661  speech_00397  the freeman's journal
# 658  parnell_source_00662  speech_00398  the freeman's journal
# 659  parnell_source_00663  speech_00399  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence
# 0    the home rule league great meeting in the rotu...
# 1    the home rule league on saturday evening a pub...
# 2    the week "though beaten, we are not vanquished...
# 3    irish home rule league a public meeting of the...
# 4    mr. charles stewart parnell, in seconding the ...
# ..                                                 ...
# 656  fellow countrymen and fellow citizens, it is n...
# 657  mr. chairman, fellow citizens, and people of t...
# 658  people of mallow, i certainly did not expect t...
# 659  people of dungarvan, i will, through you, expr...
# 660  the chairman said one of the resolutions which...
#
# [683 rows x 4 columns]

# %% [markdown]
# ### Sentence Tokenization

# %% [markdown]
# We then use the sentence tokenizer to divide the text in each row into sentences before amending the dataframe so that each sentence has its own row with the appropriate report data for that sentence. The sentence will be the unit we use for our topic modelling process.
#
# Having done this we remove punctuation from all sentences in the sentence column and remove rows where the sentence is less than 3 words as these tend not to be proper sentences (crowd reactions etc).

# %%
#initialize nltk abbreviation words, these will be added to the sentence tokenizer
#they will prevent the tokenizer from reading some full stops as sentence-enders
punkt_param = PunktParameters()
#we can add our own abbreviation words, e.g. "hon." and "mr." frequently have full stops in the reports
punkt_param.abbrev_types = set(['hon', 'mr', 'rev', 'dr', 'm.p', 'c.s', 'c.v', 'c.e', 't.l', 'j.r', 'j.j', 'a.j',
                            'r.b', 'j.g', 'j.l', 'j.r', 'j.f', 'n.b', 'p.j', 'c.j', 't.d', 'r', 'p.p', 'l.p', 'c.c', 'wm',
                            'capt', 'messrs', 'patk', '1d', '2d', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d', '11d',
                            '1/2d', '3/4d', 'prof', 'per cent', 'adm', '2s', '1,400,000/', '400,000/'])

#initialize nltk sentence detector for dividing text into sentences
sentence_tokenizer = PunktSentenceTokenizer(punkt_param)

#apply sentence tokenizer to each text in the dataframe to convert into a list of sentences
speech_rep_df['sentence'] = speech_rep_df['sentence'].apply(lambda x: sentence_tokenizer.tokenize(x))
#use explode on the sentence column, so that each sentence is converted into its own row
speech_rep_df = speech_rep_df.explode('sentence')
#now that the text has been divided into sentences, we can remove punctuation using function
speech_rep_df['sentence'] = speech_rep_df['sentence'].apply(lambda x: punct_removal(x))
#we then remove rows with very short sentences from our dataframe, likely to be crowd reactions etc
speech_rep_df = speech_rep_df[speech_rep_df['sentence'].apply(lambda x: len(x.split()) > 3)]
speech_rep_df
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence
# 0    the home rule league great meeting in the rotu...
# 0    there was an immense attendance the platform t...
# 0    mr charles stewart parnell high sheriff of wic...
# 0    the following report of the proceedings is tak...
# 0    in view of the unwise course adopted by our op...
# ..                                                 ...
# 660  the application is a perfectly disgraceful one...
# 660  we have had a good legal opinion that all the ...
# 660  the chairman said they had already sent out fo...
# 660       the chairman you must settle that yourselves
# 660  you cannot expect me to take everything on my ...
#
# [21851 rows x 4 columns]

# %% [markdown]
# ### Speech Register Dataframe

# %% [markdown]
# We then convert the speech register into a dataframe before applying some data cleaning to make lowercase and remove spacing. We also convert dates into datetime format.

# %%
#prepare data for speech register dataframe, make list of lists of data and list of column names
speech_data = [speech_ids, speech_places, speech_dates]
speech_columns = ['speech_id', 'place', 'date']
#use function to turn the above lists into dataframe
speech_df = create_dataframe(speech_data, speech_columns)
#use function to clean the text in the dataframe and standardise it
speech_df = dataframe_cleaning(speech_df)
#make speech id index so we can use it when we merge dataframes below
speech_df.set_index('speech_id', inplace=True)
#convert date column to datetime format, enables us to manipulate dataframe using dates
speech_df['date'] = pd.to_datetime(speech_df['date'], format='%Y-%m-%d')
#drop empty rows
speech_df = speech_df.dropna(axis=0)
speech_df
# Out:
#                            place       date
# speech_id
# speech_00001     dublin, ireland 1874-07-11
# speech_00002     dublin, ireland 1875-01-21
# speech_00003     dublin, ireland 1875-01-22
# speech_00004      navan, ireland 1875-04-12
# speech_00005     london, england 1875-04-26
# ...                          ...        ...
# speech_00396       cork, ireland 1881-10-02
# speech_00397       cork, ireland 1881-10-02
# speech_00398     mallow, ireland 1881-10-03
# speech_00399  dungarvan, ireland 1881-10-05
# speech_00400  waterford, ireland 1881-10-05
#
# [400 rows x 2 columns]

# %% [markdown]
# ### Joint Dataframe

# %% [markdown]
# Having converted our speech reports and register into dataframes, we then join the dataframes together using the speech id contained in both dataframes. We end up with each sentence row in the final dataframe containing the appropriate speech data as well.

# %%
#join the speech register and speech report dataframes indexing on speech_id
df_all = speech_rep_df.merge(speech_df, left_on='speech_id', right_index=True)
df_all
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 0    the home rule league great meeting in the rotu...     dublin, ireland
# 0    there was an immense attendance the platform t...     dublin, ireland
# 0    mr charles stewart parnell high sheriff of wic...     dublin, ireland
# 0    the following report of the proceedings is tak...     dublin, ireland
# 0    in view of the unwise course adopted by our op...     dublin, ireland
# ..                                                 ...                 ...
# 660  the application is a perfectly disgraceful one...  waterford, ireland
# 660  we have had a good legal opinion that all the ...  waterford, ireland
# 660  the chairman said they had already sent out fo...  waterford, ireland
# 660       the chairman you must settle that yourselves  waterford, ireland
# 660  you cannot expect me to take everything on my ...  waterford, ireland
#
#           date
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [21851 rows x 6 columns]

# %% [markdown]
# ## Topic Modelling

# %% [markdown]
# Having prepared our main dataframe, we are now able to begin our topic modelling stage, which will involve manipulating the data in different ways before performing topic modelling on the resulting data subsets and getting visualisations of the results.

# %% [markdown]
# ### Sentence Count by Year

# %% [markdown]
# We first do a count visualisation for the number of sentences in each year of the dataset to use alongside our topic modelling process. This gives an idea of the distribution of the currently transcribed speech report material over time.

# %%
#make copy of main dataframe
df_year_counts = df_all.copy()
#use function to get a count of all sentences by year
year_counts_all = year_counts(df_year_counts)
#use function to get visualisation of year/sentence count
report_sent_nums = year_counts_plot(year_counts_all)
report_sent_nums
# Out:
# <div>                            <div id="7a62a133-3ebb-4d48-a1d6-d8c197d778e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a62a133-3ebb-4d48-a1d6-d8c197d778e5")) {                    Plotly.newPlot(                        "7a62a133-3ebb-4d48-a1d6-d8c197d778e5",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":[1874,1875,1876,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891],"xaxis":"x","y":[32,1030,615,39,5870,2102,2037,485,410,1387,3474,864,345,729,834,1598],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type": ...

# %% [markdown]
# ### Initializing BERTopic

# %% [markdown]
# We then initialize our topic model, setting our embedding model, which is a Sentence Transformers model, alongside the minimum topic size, which is the number of times a topic needs to occur in order to be included. Other parameters are also available and can be seen on the BERTopic website.
#
# Sentence Transformers creates embeddings for all the input sentences in our dataset and uses the similarity of these embeddings to calculate sentence similarity. In the context of BERTopic these embeddings are used to calculate topics.
#
# BERTopic is stochastic by nature and this means that every time the tool is run we get different results, although the difference between runs should ideally be relatively small.
#
# As mentioned before, the sentence is the unit of comparison in the BERTopic process. So sentences with similar content form clusters with each other.

# %%
#initialize BERTopic topic model with parameters, uses a sentence transformers model to calculate topics
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", nr_topics="auto", top_n_words=15, min_topic_size=15)

# %% [markdown]
# ### Removing Stopwords

# %% [markdown]
# Next we remove stopwords from the dataframe, stopwords are words that will tend to lack specific meaning within a dataset due to their high frequency of appearance. We are also able to extend them to include our own stopwords specific to a dataset, such as crowd reactions.

# %%
#initialize stopwords list
stop_words = stopwords.words('english')
#extend stop words to include extra words
stop_words.extend(['every', 'would', 'cheer', 'hiss', 'applause', 'groan' 'could', 'upon', 'may', 'go',
                   'said', 'say', 'know', 'far', 'come', 'put', 'us', 'parnell', 'ireland', 'irish', 'mp',
                   'mr', 'dr', 'laughter', 'laugh', 'italics', 'irishman'])

#copy from main dataframe
df_stop = df_all.copy()
#use function to remove stopwords from all sentences in dataframe
df_stop['sentence'] = df_stop['sentence'].apply(lambda x: remove_stopwords(x, stop_words))
df_stop
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 0    home rule league great meeting rotundo great s...     dublin, ireland
# 0    immense attendance platform gallery admission ...     dublin, ireland
# 0    charles stewart high sheriff wicklow occupied ...     dublin, ireland
# 0    following report proceedings taken somewhat ab...     dublin, ireland
# 0    view unwise course adopted opponents notably e...     dublin, ireland
# ..                                                 ...                 ...
# 660  application perfectly disgraceful one one cann...  waterford, ireland
# 660  good legal opinion sales since passing land ac...  waterford, ireland
# 660  chairman already sent forms requesting particu...  waterford, ireland
# 660                               chairman must settle  waterford, ireland
# 660            cannot expect take everything shoulders  waterford, ireland
#
#           date
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [21851 rows x 6 columns]

# %% [markdown]
# ## <font color="blue">Alterable Cells - Dataframe Filtering</font>

# %% [markdown]
# <font color="blue">General guidelines:</font>
#
# <ul style="color: blue;">
# <li>Fill out dates in 'YYYY-MM-DD' format e.g. '1880-01-15'</li>
# <li>Add one or more keywords in quotes, separated by a comma to list e.g keywords = ['labor', 'labour'].</li>
# <li>Use lower-case for all letters in searches.</li>
# <li>keywords will act as substrings, so 'labour' will find 'labourer'.</li>
# <li>To prevent words acting as substring, search with a space on either side. So ' rent ' will not find 'different', 'referent', etc.</li>
# <li>Use alongside tools from previous sessions for a fuller exploration of the dataset.</li>
# </ul>
#
# <ul style="color: blue;">
# <li>Run cells underneath each header sequentially</li>
# <li>Try running repeatedly and looking at how patterns of topics shift</li>
# <li>Try different keywords and date ranges to see what comes up</li>
# </ul>

# %% [markdown]
# ### <font color="blue">Visualisation - All Data (Stopwords Removed)</font>

# %% [markdown]
# <font color="blue">Nothing to amend here in terms of keywords/dates etc, but try running repeatedly (in sequence) for different results.</font>

# %%
topics_data_all = bertopic_topics(df_stop, topic_model)
model_all = topics_data_all[2]

# %% [markdown]
# <font color="blue">Below are the topics ordered by frequency of allocation to a sentence. Within each topic are the most prominent words for that topic with their weighting score. Ignore topic 0 as this refers to outliers not allocated a topic.</font>

# %%
model_all.get_topics()
# Out:
# {-1: [('hear', 0.008336596734031958),
#   ('people', 0.008275234277201244),
#   ('land', 0.00789695756486613),
#   ('hon', 0.00762179364396049),
#   ('one', 0.0075590223280279515),
#   ('cheers', 0.007486549742302133),
#   ('government', 0.007343448443136852),
#   ('bill', 0.007309446993899213),
#   ('right', 0.0072107178111463135),
#   ('country', 0.0071012761359954815),
#   ('great', 0.006951028356623023),
#   ('question', 0.006922067142516249),
#   ('could', 0.006768653408794319),
#   ('gentleman', 0.006292872381913528),
#   ('time', 0.006210062084489615)],
#  0: [('cheers', 0.00884170540627568),
#   ('land', 0.008259987929660857),
#   ('hear', 0.007631504287281451),
#   ('right', 0.007612700358110571),
#   ('government', 0.007602332630250162),
#   ('people', 0.007299329206541224),
#   ('hon', 0.007170543423671186),
#   ('question', 0.006692889620379164),
#   ('country', 0.006636271314889421),
#   ('great', 0.006593262346023479),
#   ('gentleman', 0.0063573593741663645),
#   ('one', 0.0062612083243022655),
#   ('act', 0.0062173978224692025),
#   ('could', 0.0060762225682821054),
#   ('time', 0.005965703987123062)],
#  1: [('situation', 0.07251438585892973),
#   ('reason', 0.06623087635190099),
#   ('forward', 0.053879611188269866),
#   ('nothing', 0.05116021816233232),
#   ('faults', 0.0487390196882675),
#   ('troubles', 0.04747485637123691),
#   ('tell', 0.045515625179824416),
#   ('fault', 0.04281021133891206),
#   ('attain', 0.04060724588204872),
#   ('want', 0.0392748252131979),
#   ('farther', 0.038991215750614004),
#   ('shall', 0.03724142416366472),
#   ('gone', 0.03676399018632866),
#   ('let', 0.03523135126095207),
#   ('think', 0.03158064885088564)],
#  2: [('emigration', 0.16046806525387644),
#   ('migration', 0.041482560463952316),
#   ('emigrants', 0.03990252898115389),
#   ('emigrate', 0.03584290839900672),
#   ('population', 0.03330313039547228),
#   ('families', 0.030913005836627462),
#   ('plains', 0.029877212225869303),
#   ('cure', 0.029729039305261443),
#   ('instead', 0.028604566213154523),
#   ('west', 0.02550567205121615),
#   ('emigrated', 0.023704320265115607),
#   ('east', 0.023686816860642047),
#   ('scheme', 0.023283733612948238),
#   ('meath', 0.022934402265128453),
#   ('baldwin', 0.02146775947586613)],
#  3: [('rule', 0.23546686096619787),
#   ('home', 0.20545263397978314),
#   ('repeal', 0.04941804032131404),
#   ('difference', 0.02750913644268918),
#   ('cheers', 0.026838867186465814),
#   ('utilitarian', 0.024169877323899334),
#   ('ministerial', 0.021955027828203254),
#   ('question', 0.021643225207832274),
#   ('forward', 0.02141788533792167),
#   ('lose', 0.01922137663602428),
#   ('obtaining', 0.018867576546122217),
#   ('depends', 0.017970196480477832),
#   ('trifling', 0.017547421993871676),
#   ('neglected', 0.017200942669767613),
#   ('confederation', 0.01707365092723802)],
#  4: [('piers', 0.10701316566854992),
#   ('fishery', 0.09468586981736508),
#   ('harbours', 0.08595536382867631),
#   ('fishermen', 0.08061815957172214),
#   ('coast', 0.06146075165018113),
#   ('fisheries', 0.05570667520392142),
#   ('harbour', 0.042044711126712694),
#   ('pier', 0.03403369185797095),
#   ('grant', 0.03193032639212404),
#   ('west', 0.0312621874124972),
#   ('work', 0.02992200055471184),
#   ('boats', 0.029171735878260812),
#   ('silting', 0.025584443043669757),
#   ('cornish', 0.025584443043669757),
#   ('notice', 0.02400886810225762)],
#  5: [('herald', 0.24820459422618563),
#   ('york', 0.19438995744150986),
#   ('new', 0.14176037147546622),
#   ('proxy', 0.04793733995187657),
#   ('committee', 0.03969120343104248),
#   ('hisses', 0.03912880349422908),
#   ('telegram', 0.028299790426460022),
#   ('fund', 0.027396089047621027),
#   ('dismisses', 0.02670914529232217),
#   ('thoughts', 0.026541050325294187),
#   ('america', 0.025660311668454668),
#   ('cardinal', 0.025378447450526566),
#   ('answer', 0.02439353642201477),
#   ('gives', 0.023275552338175225),
#   ('shield', 0.022639832341168016)],
#  6: [('mission', 0.16431492105932868),
#   ('fulfilled', 0.15278827726173122),
#   ('resolve', 0.11823938929794552),
#   ('belongs', 0.10963215410014067),
#   ('fullest', 0.10072972193434977),
#   ('comes', 0.08588742033635514),
#   ('human', 0.08456183374754592),
#   ('hearts', 0.08321881948827235),
#   ('race', 0.08244323148701997),
#   ('shall', 0.08015764525871336),
#   ('everything', 0.07713526154553446),
#   ('lies', 0.07352155565765119),
#   ('rights', 0.07156981777580396),
#   ('obtain', 0.06959058985637628),
#   ('times', 0.06386709638229272)],
#  7: [('cries', 0.4606411002454673),
#   ('no', 0.1569149537448502),
#   ('shame', 0.12159866567701702),
#   ('never', 0.09752403001916893),
#   ('loud', 0.07538000267311357),
#   ('yes', 0.07374501413215553),
#   ('hisses', 0.058704829960147614),
#   ('cry', 0.05306226167408601),
#   ('raised', 0.05198422197724829),
#   ('atheist', 0.05006302584682799),
#   ('blinking', 0.047414467689766114),
#   ('acquit', 0.04553573293211754),
#   ('fight', 0.0441365910061825),
#   ('guiltless', 0.04288871354924932),
#   ('oh', 0.042378638391572986)],
#  8: [('carnarvon', 0.24401606133362258),
#   ('lord', 0.1770156239379626),
#   ('salisbury', 0.10100741304937354),
#   ('interview', 0.07775795456665434),
#   ('cabinet', 0.04612886856098095),
#   ('gray', 0.029505258868339358),
#   ('resigned', 0.025533110971482965),
#   ('denied', 0.021328306953032526),
#   ('hear', 0.01986629670621488),
#   ('statutory', 0.019670172578892905),
#   ('behaved', 0.019556636768844227),
#   ('interviews', 0.018791091646323272),
#   ('ruler', 0.018791091646323272),
#   ('expectations', 0.017671710695194597),
#   ('contradicted', 0.017671710695194597)],
#  9: [('position', 0.3756679004331916),
#   ('unions', 0.11214429688877027),
#   ('winning', 0.10603521219971697),
#   ('firmness', 0.09071595313036172),
#   ('trades', 0.08090462003720542),
#   ('impregnable', 0.07776287263517444),
#   ('union', 0.07048193824092923),
#   ('urged', 0.06810134903156732),
#   ('spot', 0.06047730208690781),
#   ('understand', 0.05741816407776182),
#   ('determination', 0.05697855295896223),
#   ('yield', 0.05442936208842056),
#   ('placed', 0.0508415376894514),
#   ('strong', 0.05010764573632039),
#   ('application', 0.04353908906183312)],
#  10: [('forster', 0.29572433590375613),
#   ('buckshot', 0.040817124364681545),
#   ('desirable', 0.03896345761679672),
#   ('boycotting', 0.03767696168020946),
#   ('intimidation', 0.0356487850434551),
#   ('simply', 0.0337752032802932),
#   ('gentleness', 0.03282540070829962),
#   ('assistant', 0.03282540070829962),
#   ('holder', 0.03282540070829962),
#   ('hisses', 0.03251344428562022),
#   ('ambition', 0.031251337167407155),
#   ('used', 0.030859173558172574),
#   ('bottle', 0.030516104915435965),
#   ('groans', 0.029016134835203485),
#   ('inferior', 0.027860698474111278)],
#  11: [('davitt', 0.29182290306657294),
#   ('michael', 0.1473620834979697),
#   ('father', 0.03247833864037078),
#   ('egan', 0.027192352153157625),
#   ('saw', 0.024876307791079872),
#   ('disgrace', 0.024839295589333506),
#   ('arrest', 0.024480662835615778),
#   ('expresses', 0.02355329076796823),
#   ('founder', 0.02262002317731813),
#   ('neillan', 0.02262002317731813),
#   ('portland', 0.02262002317731813),
#   ('league', 0.02154996396858265),
#   ('gospel', 0.021305107704659567),
#   ('recovery', 0.021305107704659567),
#   ('regaining', 0.021305107704659567)],
#  12: [('oh', 1.0806552789851112),
#   ('lion', 0.9068016945667768),
#   ('lamb', 0.8202466466293933),
#   ('directly', 0.6424152043821973),
#   ('yes', 0.5641493581109898),
#   ('notice', 0.3955461019846943),
#   ('still', 0.33768390375052093),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05)],
#  13: [('constitution', 0.3995508032656885),
#   ('lose', 0.31183061473236573),
#   ('proportionately', 0.2433000670924389),
#   ('desperate', 0.2117166375598089),
#   ('careful', 0.17897563845201675),
#   ('methods', 0.11041329534352863),
#   ('nothing', 0.08998028320008197),
#   ('parnellite', 0.08980423500844854),
#   ('constitutional', 0.08686164806345738),
#   ('give', 0.07845595909639172),
#   ('ones', 0.07525385512720835),
#   ('ways', 0.07160938485803041),
#   ('points', 0.05995165298381147),
#   ('within', 0.056877765069557606),
#   ('bad', 0.055573165784449666)],
#  14: [('moment', 0.07855235131253027),
#   ('years', 0.07291933614130168),
#   ('climax', 0.06699006864051907),
#   ('movement', 0.05987413785595143),
#   ('past', 0.057298505843667615),
#   ('normal', 0.055677216709539394),
#   ('times', 0.0551818731105249),
#   ('experience', 0.054381626554418645),
#   ('things', 0.052368234208353515),
#   ('instances', 0.05155088620874448),
#   ('time', 0.04888493315896007),
#   ('present', 0.04747739759726764),
#   ('condition', 0.044921106095782516),
#   ('supporting', 0.04299989025390629),
#   ('afforded', 0.04139867371784651)],
#  15: [('shaw', 0.4651465495993677),
#   ('twenty', 0.3013195531565853),
#   ('voted', 0.2970689522178656),
#   ('members', 0.17226168434784034),
#   ('party', 0.1373766840300579),
#   ('william', 0.13148124274617387),
#   ('wm', 0.11474948460968423),
#   ('leader', 0.11145519748634472),
#   ('famous', 0.0870277648449271),
#   ('proposed', 0.08495644359652237),
#   ('nominated', 0.07381249753831888),
#   ('two', 0.06398157891650369),
#   ('also', 0.05656049615449812),
#   ('chairman', 0.05163965691334785),
#   ('division', 0.04684361844060107)],
#  16: [('dillon', 0.2970548698429031),
#   ('john', 0.10551198460752749),
#   ('friend', 0.07180955480326816),
#   ('tipperary', 0.06433845236393991),
#   ('joseph', 0.04329873705333798),
#   ('mckenna', 0.04256138960446031),
#   ('cousin', 0.03529789379983724),
#   ('valentine', 0.03529789379983724),
#   ('york', 0.03414204973757499),
#   ('america', 0.03257257828044309),
#   ('mission', 0.03247405279000348),
#   ('candidates', 0.030248778330929392),
#   ('alderman', 0.029530221111787824),
#   ('abide', 0.02891595401493981),
#   ('keegan', 0.02891595401493981)],
#  17: [('denied', 0.3122554896676953),
#   ('honest', 0.17188727600390188),
#   ('statement', 0.13854602261236723),
#   ('absurdity', 0.13634165917570124),
#   ('undoubtedly', 0.12163525734458058),
#   ('assertion', 0.11630176782036723),
#   ('admit', 0.11078411037337547),
#   ('deny', 0.09602542265718975),
#   ('claimed', 0.09020640265494859),
#   ('wholehearted', 0.08885696137738926),
#   ('well', 0.0886541466245125),
#   ('boundless', 0.07717461230355548),
#   ('absolutely', 0.07696521470892949),
#   ('denies', 0.0741166716873828),
#   ('contradict', 0.07174531049267391)],
#  18: [('resolution', 0.4669569449406993),
#   ('keegan', 0.22277261613876706),
#   ('subsequent', 0.11059949904051848),
#   ('circular', 0.09703283587379752),
#   ('second', 0.09362037916797498),
#   ('move', 0.09193977462035126),
#   ('recollection', 0.08801488268450618),
#   ('supported', 0.07125157605417445),
#   ('saw', 0.0680050544347864),
#   ('seconded', 0.06683786792787295),
#   ('call', 0.06321058191741878),
#   ('sullivan', 0.05720644865399919),
#   ('divided', 0.05445217588073146),
#   ('wicklow', 0.05292294185096158),
#   ('resolutions', 0.04980375169801122)],
#  19: [('case', 0.2824462638624896),
#   ('cent', 0.2225539238342453),
#   ('per', 0.2052843790293562),
#   ('cases', 0.19700232546019295),
#   ('analogous', 0.11968192116507316),
#   ('instances', 0.08377019008920977),
#   ('three', 0.07702577486544962),
#   ('crisis', 0.06599895322573542),
#   ('sis', 0.06525433101152024),
#   ('epitome', 0.06525433101152024),
#   ('invincibles', 0.05667510591042355),
#   ('two', 0.056583708854282946),
#   ('improvements', 0.054575865987361985),
#   ('seventy', 0.05126541541433708),
#   ('coward', 0.04902157829095265)],
#  20: [('oclock', 0.26198231267203526),
#   ('hotel', 0.14080938058081435),
#   ('crowd', 0.08529678502682228),
#   ('railway', 0.0849158938568322),
#   ('steps', 0.06713207571181176),
#   ('reception', 0.06562134252400807),
#   ('addressed', 0.06117043560171966),
#   ('morning', 0.05120341112029613),
#   ('drove', 0.04869493941875002),
#   ('barna', 0.04869493941875002),
#   ('fay', 0.04616730114363976),
#   ('shortly', 0.04586830537854984),
#   ('village', 0.045641659199850394),
#   ('half', 0.044989345052507124),
#   ('met', 0.04282851403679197)],
#  21: [('ford', 0.49585542680580563),
#   ('eventually', 0.4372946470045808),
#   ('settled', 0.29262559837099),
#   ('patrick', 0.1983268689824206),
#   ('question', 0.12477319332315306),
#   ('constantly', 0.09395825940574341),
#   ('spoken', 0.07813443243140603),
#   ('great', 0.07483888404433889),
#   ('denounced', 0.07216467587675697),
#   ('policy', 0.06466962575204305),
#   ('years', 0.05617489599033611),
#   ('five', 0.05583171658934531),
#   ('unsolved', 0.055683695796497276),
#   ('agreed', 0.051940320080641485),
#   ('need', 0.05150258979597036)],
#  22: [('spirit', 0.348702988285677),
#   ('candidature', 0.3376571760656104),
#   ('withdrawing', 0.2946266494713425),
#   ('admire', 0.2927813745736274),
#   ('temper', 0.2786400375407249),
#   ('exhibited', 0.25613721944891626),
#   ('entered', 0.17469311695285555),
#   ('admired', 0.15990371094111674),
#   ('equally', 0.1549807500792727),
#   ('appreciate', 0.1205570365891407),
#   ('feelings', 0.10338297568227087),
#   ('feeling', 0.09066743627863008),
#   ('fault', 0.0823273294979078),
#   ('lynch', 0.06531191180720673),
#   ('latent', 0.05356393674520757)],
#  23: [('trevelyan', 0.40481710954710665),
#   ('galashiels', 0.10283346330057538),
#   ('nephew', 0.09685569259092466),
#   ('impugned', 0.092616413597667),
#   ('justify', 0.08241322964991438),
#   ('uncle', 0.08030716114244518),
#   ('utterances', 0.07773359939926562),
#   ('hoodwink', 0.07465748176728429),
#   ('dust', 0.07264176944319349),
#   ('grand', 0.06354925559639907),
#   ('going', 0.0580025586792091),
#   ('water', 0.05488750986598356),
#   ('simple', 0.0538401904890503),
#   ('orangemen', 0.0538401904890503),
#   ('went', 0.04882926497161075)],
#  24: [('overseer', 0.24224151849876913),
#   ('orangeman', 0.20777888929311222),
#   ('irritated', 0.18880882744564975),
#   ('digging', 0.15676353304106366),
#   ('workman', 0.14050267017197213),
#   ('works', 0.12423870345519164),
#   ('drain', 0.12015107201086801),
#   ('drains', 0.10617700296358626),
#   ('catholic', 0.1048147988960826),
#   ('shovel', 0.08148499577326296),
#   ('papist', 0.08148499577326296),
#   ('nice', 0.07674822424602509),
#   ('executing', 0.07674822424602509),
#   ('crust', 0.0733890294882098),
#   ('assaulted', 0.07078466864239084)],
#  25: [('healy', 0.3416796745833749),
#   ('sexton', 0.15816467883504212),
#   ('timothy', 0.12514663338980878),
#   ('tom', 0.11328401851404851),
#   ('tim', 0.10419606473590176),
#   ('murphy', 0.08293228229284251),
#   ('biggar', 0.07957888581854154),
#   ('groans', 0.052134681289268056),
#   ('sharp', 0.05101432537595073),
#   ('father', 0.048796723420654636),
#   ('identified', 0.04591707186914849),
#   ('sixteen', 0.0444405129069696),
#   ('cries', 0.044076352931555034),
#   ('going', 0.04259808510044897),
#   ('lesson', 0.041161214773850985)],
#  26: [('literature', 0.3391288614146878),
#   ('americans', 0.221076286281376),
#   ('born', 0.1512312105297468),
#   ('native', 0.15073508399120025),
#   ('assassination', 0.1496035407465391),
#   ('study', 0.12625054628459495),
#   ('especially', 0.11972636746365946),
#   ('domestic', 0.08869707423797492),
#   ('welcoming', 0.0829053310811564),
#   ('sympathy', 0.08125313641581178),
#   ('america', 0.0726190015772892),
#   ('efforts', 0.06830829635343286),
#   ('american', 0.06773201106059572),
#   ('concession', 0.06583601310810955),
#   ('peace', 0.060316387407358965)],
#  27: [('whiskey', 0.16621422466815425),
#   ('tobacco', 0.11616293990257998),
#   ('whisky', 0.10636262814780677),
#   ('duties', 0.10562276721905027),
#   ('collecting', 0.10290388033991218),
#   ('custom', 0.09223015969062279),
#   ('anticipate', 0.08232310427192975),
#   ('scotch', 0.07718535281760368),
#   ('deprive', 0.07665011987365047),
#   ('separate', 0.07587071548696801),
#   ('explained', 0.07498505991497698),
#   ('insist', 0.06415523893893102),
#   ('drink', 0.05716904275969693),
#   ('sundays', 0.047272279176803),
#   ('mixed', 0.04445628052047675)],
#  28: [('ambition', 0.3426399039045194),
#   ('personal', 0.2668734176254071),
#   ('gained', 0.21310696825914147),
#   ('measures', 0.21210979149358092),
#   ('entered', 0.20829168196991393),
#   ('motives', 0.1950130223886271),
#   ('struggle', 0.174392456679349),
#   ('stand', 0.1613745336108196),
#   ('duty', 0.14386136939850513),
#   ('till', 0.1419115969254123),
#   ('bright', 0.09944991852093268),
#   ('great', 0.092213929756319),
#   ('meet', 0.09127353522846882),
#   ('motive', 0.09012343249481863),
#   ('believed', 0.08220125742450225)],
#  29: [('principle', 0.5206449733878309),
#   ('proceeded', 0.1625331768508489),
#   ('contend', 0.11613962625636304),
#   ('assumption', 0.10525372467694638),
#   ('concluding', 0.10525372467694638),
#   ('support', 0.10006561462061356),
#   ('confident', 0.09616573905309116),
#   ('principles', 0.08378240435707766),
#   ('proceed', 0.06814002278712168),
#   ('faulty', 0.0666055909092581),
#   ('vicious', 0.063081857013341),
#   ('always', 0.06194708897306356),
#   ('comprehension', 0.06058232294446942),
#   ('fight', 0.05872085586039933),
#   ('shake', 0.05706063628726214)],
#  30: [('hear', 0.6712945821384422),
#   ('benches', 0.3263896375522538),
#   ('divided', 0.1437877769350565),
#   ('let', 0.08650554997108766),
#   ('going', 0.08186819480242535),
#   ('trying', 0.07189388846752826),
#   ('heard', 0.051973595907620934),
#   ('want', 0.04821686131084564),
#   ('late', 0.046818823330767985),
#   ('thing', 0.046686313923534055),
#   ('months', 0.04410346710388766),
#   ('cheers', 0.030219935416010826),
#   ('made', 0.02591802069246327),
#   ('great', 0.019489292719879918),
#   ('', 1e-05)],
#  31: [('sir', 0.769634958570946),
#   ('creeds', 0.2882426252690526),
#   ('well', 0.23521946967310173),
#   ('single', 0.1538643767222509),
#   ('classes', 0.15286748375799572),
#   ('want', 0.14931673180132843),
#   ('draught', 0.12354262829943036),
#   ('cannot', 0.11729173375592074),
#   ('marum', 0.10335577389125739),
#   ('give', 0.09443187012206826),
#   ('point', 0.08487070615477096),
#   ('another', 0.084599066322523),
#   ('deny', 0.07279346556270835),
#   ('venture', 0.0708782121721361),
#   ('follow', 0.06787769384648304)],
#  32: [('treason', 0.5110808619900366),
#   ('felony', 0.20987264705624084),
#   ('preaching', 0.09121790720651897),
#   ('jurisdiction', 0.07057895693324576),
#   ('convictions', 0.05671960906522942),
#   ('secession', 0.054517031705086705),
#   ('offences', 0.052862235824972355),
#   ('defection', 0.04958695472323119),
#   ('traitorism', 0.04958695472323119),
#   ('high', 0.0424568645686067),
#   ('leave', 0.04154999186055781),
#   ('excuses', 0.04019786362921896),
#   ('statute', 0.03380846402549953),
#   ('easy', 0.031411134414015385),
#   ('meshes', 0.02972439277393093)],
#  33: [('power', 0.27319638798550083),
#   ('powers', 0.12141509007391818),
#   ('bear', 0.08300036272791152),
#   ('strain', 0.08041422040649092),
#   ('force', 0.07965028942323751),
#   ('ruled', 0.07830900912527293),
#   ('arbitrary', 0.07487922037749671),
#   ('possess', 0.06506971500798198),
#   ('immense', 0.06401135389673843),
#   ('choose', 0.06241388138714467),
#   ('weight', 0.06153937934031159),
#   ('great', 0.059802761222645225),
#   ('existence', 0.05151697943093608),
#   ('incalculable', 0.04968776408585078),
#   ('wipe', 0.04968776408585078)],
#  34: [('weakened', 0.28366734550287714),
#   ('guarantee', 0.24122173889889517),
#   ('assurances', 0.2345531460169676),
#   ('miscalculate', 0.1480492562558003),
#   ('safety', 0.13583235528629897),
#   ('possess', 0.12925412777095738),
#   ('constitutionally', 0.11817205179167543),
#   ('cannot', 0.11542996020423946),
#   ('guarantees', 0.09865193696454962),
#   ('satisfactory', 0.09732421502117872),
#   ('surest', 0.0823413492370669),
#   ('strength', 0.06543434488346908),
#   ('much', 0.06018735992910806),
#   ('insecure', 0.056820097751527826),
#   ('comforted', 0.056820097751527826)],
#  35: [('fetter', 0.3712938140444428),
#   ('alone', 0.2752651847269569),
#   ('careful', 0.2731300003983998),
#   ('view', 0.23186541307562086),
#   ('object', 0.1997442657294865),
#   ('strength', 0.19670447234907884),
#   ('prevent', 0.18678051765174375),
#   ('control', 0.1755753010450225),
#   ('anything', 0.17295210422203958),
#   ('possible', 0.14621318600823752),
#   ('always', 0.14568333807571185),
#   ('way', 0.11489574719209698),
#   ('home', 0.0993705152236128),
#   ('people', 0.06302579303767054),
#   ('category', 0.0445056046413142)],
#  36: [('harrington', 0.24334296365459293),
#   ('newspaper', 0.1119839943196218),
#   ('brother', 0.07532142049783626),
#   ('weekly', 0.06933352074417919),
#   ('type', 0.06839091186368618),
#   ('prison', 0.06547854602534921),
#   ('utter', 0.055588581101429765),
#   ('castle', 0.05045699692275063),
#   ('common', 0.049000645666537467),
#   ('seized', 0.04880090280079247),
#   ('engaged', 0.0478625727163136),
#   ('bringing', 0.046827806572471396),
#   ('snatching', 0.04284102494016268),
#   ('unscrupulousness', 0.04284102494016268),
#   ('beguile', 0.04284102494016268)],
#  37: [('blow', 0.21262164694966154),
#   ('struck', 0.20407658613029903),
#   ('satisfaction', 0.18356954846150314),
#   ('successful', 0.16837705694797925),
#   ('results', 0.16760451506372603),
#   ('look', 0.13721870665017713),
#   ('proved', 0.13597121673959198),
#   ('back', 0.1284001707058224),
#   ('month', 0.11080847316202924),
#   ('day', 0.10978720582309096),
#   ('proceedings', 0.10811568747987849),
#   ('butt', 0.09197701713199524),
#   ('testimonial', 0.08627823081874902),
#   ('many', 0.064699602518161),
#   ('months', 0.061171372329850385)],
#  38: [('guernsey', 0.3975600640262432),
#   ('island', 0.2101554469128172),
#   ('owns', 0.15522389149861995),
#   ('farm', 0.14648314787179445),
#   ('area', 0.14181595006116723),
#   ('acres', 0.14145939557922516),
#   ('facilitates', 0.14061091364127595),
#   ('population', 0.13727783073233157),
#   ('peopled', 0.11680420108942),
#   ('densely', 0.1076984534665203),
#   ('moist', 0.09445461045253989),
#   ('cultivable', 0.09445461045253989),
#   ('markets', 0.08705729639491991),
#   ('easy', 0.08653459578763062),
#   ('supports', 0.08623549527701109)],
#  39: [('kerry', 0.33118938974277207),
#   ('outrages', 0.1631571822199781),
#   ('denounce', 0.14253367477642084),
#   ('lurid', 0.07886840592317487),
#   ('allusion', 0.0733170985299744),
#   ('unfairly', 0.06951138264498787),
#   ('occur', 0.0687199545696209),
#   ('occurrences', 0.06538752880955678),
#   ('neither', 0.061181430480915296),
#   ('county', 0.05830506371959741),
#   ('munster', 0.05751173950106961),
#   ('cast', 0.057210705716192474),
#   ('numerous', 0.05663026291596072),
#   ('unhappy', 0.05663026291596072),
#   ('excuse', 0.05088436471407482)],
#  40: [('minority', 0.4003019185022938),
#   ('majority', 0.2004949473969746),
#   ('sometimes', 0.1266312372545893),
#   ('often', 0.11696449944880866),
#   ('small', 0.1071920625702148),
#   ('bound', 0.1036022654291107),
#   ('remarkable', 0.09291945091172289),
#   ('party', 0.0795449648706013),
#   ('least', 0.05992885260683784),
#   ('representatives', 0.056207423382827755),
#   ('larger', 0.051059858181806486),
#   ('scrupulously', 0.04913267276161524),
#   ('4⅓', 0.04913267276161524),
#   ('reversed', 0.04913267276161524),
#   ('numbers', 0.04507001646854471)],
#  41: [('marlborough', 0.22397042989908827),
#   ('duchess', 0.1998082590752001),
#   ('wife', 0.10204823540854281),
#   ('fund', 0.092887150109241),
#   ('duke', 0.06853235689853938),
#   ('troops', 0.058313277376310174),
#   ('funds', 0.05577057101122132),
#   ('lieutenant', 0.050568832466546414),
#   ('connemara', 0.05048506434739354),
#   ('husband', 0.04822883312881403),
#   ('paid', 0.04628355914044923),
#   ('distress', 0.04280332557448753),
#   ('churchill', 0.041251577226894875),
#   ('purposes', 0.0401192264082157),
#   ('obediently', 0.03999813553297484)],
#  42: [('adoption', 0.23980070217166108),
#   ('standard', 0.19624377260364506),
#   ('adopting', 0.14564879127693542),
#   ('unfavourable', 0.13023381779051235),
#   ('22nd', 0.1270194741142093),
#   ('15th', 0.12463996685786623),
#   ('20th', 0.12463996685786623),
#   ('stronger', 0.11014901488771889),
#   ('relative', 0.1067477527450795),
#   ('wealth', 0.1029886864319656),
#   ('adopt', 0.0949001203620316),
#   ('countries', 0.08467028505147696),
#   ('convinced', 0.0790890250540234),
#   ('rev', 0.051689015813082086),
#   ('case', 0.0516596167293146)],
#  43: [('danger', 0.36087314699758516),
#   ('faced', 0.3344092010470222),
#   ('risk', 0.30915975746088875),
#   ('otherwise', 0.22745225892947288),
#   ('physical', 0.12645240315477493),
#   ('personal', 0.12534076814643572),
#   ('running', 0.1014339796392943),
#   ('operative', 0.10078477571795634),
#   ('post', 0.09272196651882572),
#   ('away', 0.07818941961524241),
#   ('opposite', 0.06215335170942059),
#   ('usual', 0.06148458992713034),
#   ('separation', 0.05911019331372035),
#   ('safe', 0.05884195508429281),
#   ('bugbear', 0.05495101558864862)],
#  44: [('cheers', 0.47439596728530203),
#   ('counter', 0.40847929741560546),
#   ('oh', 0.40779444490004196),
#   ('ironical', 0.2418135087267154),
#   ('quantity', 0.1209067543633577),
#   ('quality', 0.10925340637343578),
#   ('stick', 0.10925340637343578),
#   ('eventually', 0.10313552995391057),
#   ('great', 0.07060272079654611),
#   ('butt', 0.07006739748498694),
#   ('thank', 0.06419936428810372),
#   ('settled', 0.06370658890515021),
#   ('glad', 0.05913474803472015),
#   ('thing', 0.056375926247286406),
#   ('cries', 0.051145201986615735)],
#  45: [('plus', 0.27861368715170004),
#   ('ne', 0.27861368715170004),
#   ('ultra', 0.27861368715170004),
#   ('thou', 0.27574217355630093),
#   ('shalt', 0.27574217355630093),
#   ('nationhood', 0.23328367793687366),
#   ('fix', 0.21506584666656464),
#   ('thus', 0.20060973495967774),
#   ('attempted', 0.19485401183935372),
#   ('progress', 0.17231560829044945),
#   ('never', 0.16603683152373344),
#   ('man', 0.09725555058723917),
#   ('farther', 0.09545327297998978),
#   ('right', 0.06799447662306948),
#   ('country', 0.06399303612704665)],
#  46: [('manchester', 0.42118297962719986),
#   ('maloney', 0.1749400287439075),
#   ('condon', 0.14716943832560841),
#   ('convicted', 0.14101417667627789),
#   ('trial', 0.11847803266697672),
#   ('attack', 0.11815009504153984),
#   ('report', 0.10535823966793745),
#   ('van', 0.0961581306022894),
#   ('workman', 0.08697178859513932),
#   ('apprehended', 0.08358209542233383),
#   ('hanged', 0.08215505659173417),
#   ('murderers', 0.07347082385642678),
#   ('gives', 0.07091495584180085),
#   ('fellow', 0.07024614434636975),
#   ('malloney', 0.06931803578791568)],
#  47: [('division', 0.2956316154402722),
#   ('motion', 0.1293206227515939),
#   ('challenged', 0.08155535968721263),
#   ('weakening', 0.0777902341094639),
#   ('absent', 0.07551115726351304),
#   ('teller', 0.07192153008980923),
#   ('appearance', 0.0703075923488942),
#   ('fatal', 0.061893650065809006),
#   ('affect', 0.05891795325109802),
#   ('distance', 0.053030984412256),
#   ('evening', 0.050375562000398846),
#   ('authority', 0.04820625450928031),
#   ('taken', 0.04394238553880066),
#   ('particular', 0.0404268738653149),
#   ('snatched', 0.039213870279223434)],
#  48: [('balfour', 0.30385293915834444),
#   ('initiated', 0.06111781189521369),
#   ('prosecutions', 0.05222037823742947),
#   ('aj', 0.042610215409319134),
#   ('controlled', 0.04074520793014246),
#   ('semi', 0.039299280317691025),
#   ('lost', 0.03762364514316016),
#   ('twenty', 0.034607724652318844),
#   ('defeat', 0.030844735036251198),
#   ('disposed', 0.030343044379622767),
#   ('hand', 0.029103156731553694),
#   ('firm', 0.028657560942656892),
#   ('chuckling', 0.027118683017774647),
#   ('nonchalance', 0.027118683017774647),
#   ('bastard', 0.027118683017774647)],
#  49: [('quarrels', 0.5318547117261865),
#   ('happens', 0.3045523931885973),
#   ('old', 0.29146273230369196),
#   ('defeated', 0.2882111925438545),
#   ('retract', 0.28480257694479816),
#   ('generally', 0.26152677838039473),
#   ('distant', 0.23209929781493605),
#   ('unhappy', 0.20449817164096926),
#   ('recollections', 0.17932116056072347),
#   ('back', 0.16384495856980005),
#   ('recur', 0.16120919014520477),
#   ('desire', 0.15330376104647145),
#   ('refer', 0.14427866689067076),
#   ('like', 0.10893355991610307),
#   ('dislike', 0.0999119879453533)],
#  50: [('victory', 0.7421365668026557),
#   ('remarkable', 0.40409156559284143),
#   ('one', 0.15331711366296694),
#   ('providential', 0.09712272522644873),
#   ('unsullied', 0.09712272522644873),
#   ('miraculously', 0.09712272522644873),
#   ('elated', 0.09712272522644873),
#   ('shining', 0.08906561575075211),
#   ('depressed', 0.0843536460062118),
#   ('triumphed', 0.08101124579783701),
#   ('successors', 0.08101124579783701),
#   ('banners', 0.07841929286408544),
#   ('brink', 0.07841929286408544),
#   ('carraroe', 0.07841929286408544),
#   ('brilliant', 0.06825858243806789)],
#  51: [('boycotting', 0.4405612979537719),
#   ('practice', 0.14607012260069233),
#   ('advocating', 0.09606490744324471),
#   ('speech', 0.08490057970525179),
#   ('advocated', 0.08095770414301291),
#   ('bellman', 0.07676628102152608),
#   ('boycotted', 0.06781013736780908),
#   ('grew', 0.04419340936229942),
#   ('outrages', 0.04316327571957092),
#   ('number', 0.04268764175670252),
#   ('reprobate', 0.040527211399813134),
#   ('sanctions', 0.040527211399813134),
#   ('illustrated', 0.03838314051076304),
#   ('moonlighting', 0.03838314051076304),
#   ('boycott', 0.03838314051076304)],
#  52: [('welcomed', 0.22506132543877652),
#   ('prime', 0.22445994043025108),
#   ('minister', 0.21492173042837806),
#   ('truly', 0.15917863081332567),
#   ('cheerfully', 0.14222263409238758),
#   ('unless', 0.1398842413768268),
#   ('proceed', 0.12340319087431485),
#   ('measure', 0.11169820450390798),
#   ('regards', 0.10654835854307952),
#   ('ought', 0.10552436173215293),
#   ('members', 0.08120088179509798),
#   ('people', 0.044490254691552475),
#   ('included', 0.0422148989425939),
#   ('proceeded', 0.036793927830408704),
#   ('disavowals', 0.03288407232076611)],
#  53: [('results', 0.5591538422736324),
#   ('result', 0.22836602199247116),
#   ('system', 0.1788157096524263),
#   ('stands', 0.13786201346029026),
#   ('condemned', 0.1265457659674013),
#   ('collections', 0.1176416108376703),
#   ('traced', 0.10788229513471384),
#   ('stated', 0.09738291811058039),
#   ('explaining', 0.09498674910297673),
#   ('deprecated', 0.09242215736669221),
#   ('preserved', 0.08672132905321961),
#   ('self', 0.08021223847803491),
#   ('chiefly', 0.07698849419094733),
#   ('heartily', 0.07482727768699281),
#   ('repeated', 0.06937487417403268)],
#  54: [('path', 0.6481142878849644),
#   ('crooked', 0.6054764290824418),
#   ('led', 0.3661389454677146),
#   ('lead', 0.30828875044855747),
#   ('never', 0.18921781911327884),
#   ('wrong', 0.18364926114987246),
#   ('foolish', 0.15844008949441335),
#   ('teaching', 0.0850759143430991),
#   ('confusion', 0.0828486618281873),
#   ('signature', 0.08092023635915506),
#   ('straight', 0.0800450235039411),
#   ('employers', 0.07699618428661578),
#   ('follows', 0.07285066814849914),
#   ('always', 0.06883009885895951),
#   ('employed', 0.0680856952215532)],
#  55: [('believe', 0.4965153346127995),
#   ('mode', 0.1893625190217367),
#   ('best', 0.13378469399348591),
#   ('settle', 0.12009098992070869),
#   ('dont', 0.10614200225865716),
#   ('anyhow', 0.10335577389125739),
#   ('hope', 0.08268417645533126),
#   ('probable', 0.07944542042510194),
#   ('lie', 0.07750308580453948),
#   ('scheme', 0.07000141847505728),
#   ('mean', 0.06453760194344645),
#   ('contrary', 0.06433845236393991),
#   ('programme', 0.0630116390575855),
#   ('question', 0.06037412580152567),
#   ('one', 0.05799972921560919)],
#  56: [('contest', 0.2488724668097427),
#   ('calculated', 0.2210241766958139),
#   ('devotion', 0.21882311165235996),
#   ('try', 0.17661551571514503),
#   ('circumstances', 0.15139424403359597),
#   ('remarkable', 0.15099410773154967),
#   ('union', 0.14038084574273316),
#   ('test', 0.13423649716323371),
#   ('stood', 0.1253386456759452),
#   ('spirit', 0.11827449555230506),
#   ('lengthened', 0.11125163913464002),
#   ('fact', 0.11061201251330004),
#   ('well', 0.0995729477712815),
#   ('event', 0.08416273525090769),
#   ('hear', 0.0789758331927579)],
#  57: [('quite', 0.6655141247531198),
#   ('agree', 0.6590532175949178),
#   ('true', 0.3305945034705167),
#   ('fair', 0.26246912953924717),
#   ('play', 0.25562271455121155),
#   ('point', 0.2192493242331583),
#   ('entirely', 0.18215192994476362),
#   ('exactly', 0.1416759822502726),
#   ('mean', 0.11114809223593555),
#   ('indeed', 0.1014231311899988),
#   ('enough', 0.09784658401638233),
#   ('important', 0.07076965419519529),
#   ('well', 0.05787145682433455),
#   ('right', 0.03182519253052002),
#   ('', 1e-05)],
#  58: [('leader', 0.41502395906099415),
#   ('chairman', 0.3845795501704589),
#   ('nominated', 0.320663503560109),
#   ('proposed', 0.25776745508379545),
#   ('voted', 0.2552748384949068),
#   ('party', 0.19275698724125973),
#   ('narrates', 0.07326802078486483),
#   ('nominee', 0.05504177211615736),
#   ('wonder', 0.049542103858818104),
#   ('seconded', 0.049542103858818104),
#   ('member', 0.047022704720866455),
#   ('indebted', 0.0440938254583021),
#   ('appointment', 0.04143556780628039),
#   ('endeavoured', 0.04143556780628039),
#   ('choice', 0.03905279830257821)],
#  59: [('candidature', 0.45659551940787035),
#   ('withdrawn', 0.37858999198706134),
#   ('lynch', 0.1892523482964653),
#   ('word', 0.17413367660734144),
#   ('regard', 0.16118839178799987),
#   ('intervening', 0.1482333433747656),
#   ('book', 0.128033896876253),
#   ('wish', 0.12498341269369236),
#   ('byrne', 0.11879779380386593),
#   ('affair', 0.11407004607892395),
#   ('favour', 0.11294635904350732),
#   ('closed', 0.11021083267016457),
#   ('commissioned', 0.10864741779524371),
#   ('unreservedly', 0.10864741779524371),
#   ('record', 0.09694070938854385)],
#  60: [('cell', 0.1205071145780223),
#   ('prison', 0.11965144381610575),
#   ('naked', 0.11525284138953161),
#   ('muscles', 0.09703682282462371),
#   ('warders', 0.09441688018755606),
#   ('unable', 0.0937400892546539),
#   ('convicts', 0.0922022731116253),
#   ('legs', 0.0922022731116253),
#   ('sharp', 0.09028434562938042),
#   ('paralysis', 0.08859301241408046),
#   ('discharged', 0.0870804196967542),
#   ('instruments', 0.08126330704899662),
#   ('thrust', 0.08126330704899662),
#   ('dragged', 0.08033807638534819),
#   ('winter', 0.08014903741088435)],
#  61: [('defence', 0.3302240828062485),
#   ('defenceless', 0.2517578494692216),
#   ('defensive', 0.15145580736117353),
#   ('tie', 0.14660998231111624),
#   ('chain', 0.14265159071815536),
#   ('offensive', 0.13930560828821648),
#   ('bond', 0.13930560828821648),
#   ('constructed', 0.1258789247346108),
#   ('dwell', 0.12427299274228096),
#   ('let', 0.12035554778586108),
#   ('alliance', 0.11352683045295785),
#   ('additional', 0.10268814630252097),
#   ('section', 0.10062649317046046),
#   ('leadership', 0.09513021591031418),
#   ('opponents', 0.09397002425957487)],
#  62: [('responsibility', 0.43734375967363837),
#   ('accept', 0.11818884158553744),
#   ('federation', 0.07767343007585403),
#   ('step', 0.07144574841592115),
#   ('heavy', 0.07018703682172238),
#   ('guidance', 0.06929160807448392),
#   ('shoulders', 0.06439680867607865),
#   ('taking', 0.06432080849139944),
#   ('abatement', 0.06278677739997254),
#   ('clearly', 0.060507140082078636),
#   ('carefully', 0.053963866745380805),
#   ('evasion', 0.05062154163317934),
#   ('exonerate', 0.05062154163317934),
#   ('everybody', 0.049941793224829514),
#   ('especially', 0.04708430882072534)],
#  63: [('smyth', 0.37001281526571),
#   ('association', 0.09899779286945423),
#   ('deviate', 0.09365316449614834),
#   ('member', 0.08667617959741802),
#   ('changed', 0.07259050558473946),
#   ('course', 0.07190105050431818),
#   ('weeks', 0.06351834281508097),
#   ('recent', 0.06048305208927191),
#   ('remain', 0.05814214934400165),
#   ('appeared', 0.0550201989607238),
#   ('devolved', 0.04594936091625815),
#   ('clique', 0.04594936091625815),
#   ('completely', 0.04516484454421207),
#   ('points', 0.04451633934245702),
#   ('intelligence', 0.04445533026537627)],
#  64: [('oconnor', 0.2258274786114847),
#   ('oconor', 0.18086373394099595),
#   ('odonnell', 0.11352683045295785),
#   ('worshipping', 0.11100931818209685),
#   ('feeling', 0.10737427236309814),
#   ('covert', 0.10513642835556833),
#   ('superfluous', 0.10513642835556833),
#   ('wretches', 0.09773998820741084),
#   ('detect', 0.08923499076490712),
#   ('pitch', 0.08771143723078866),
#   ('intense', 0.0839192831564072),
#   ('oconnell', 0.0828486618281873),
#   ('quick', 0.0800450235039411),
#   ('disunion', 0.07769988645955689),
#   ('renew', 0.07699618428661578)],
#  65: [('justice', 0.2949678679137766),
#   ('impossible', 0.23336325685377832),
#   ('done', 0.19619893858888027),
#   ('forecast', 0.193270716954933),
#   ('way', 0.16378104799360135),
#   ('none', 0.1602299064566133),
#   ('full', 0.15692283848185615),
#   ('settled', 0.15405851917747354),
#   ('extent', 0.14939292643452184),
#   ('means', 0.1403972857247509),
#   ('national', 0.1026243794494417),
#   ('future', 0.0923226756946602),
#   ('given', 0.07850659198501195),
#   ('question', 0.056930734596115466),
#   ('inflexible', 0.031758761861120116)],
#  66: [('address', 0.46785821546703316),
#   ('countrymen', 0.4160901663167759),
#   ('several', 0.3730366358425938),
#   ('gentlemen', 0.289471971160494),
#   ('desire', 0.2874445519621339),
#   ('fellow', 0.24149063400852003),
#   ('impose', 0.14986798191802994),
#   ('wishes', 0.0928468874643974),
#   ('visitor', 0.0928061596608288),
#   ('delegate', 0.07493399095901497),
#   ('name', 0.06584332590471527),
#   ('desires', 0.06073536763952511),
#   ('america', 0.052357403606341855),
#   ('opinion', 0.04978418403930374),
#   ('order', 0.04886452192088722)],
#  67: [('address', 0.24644705329785194),
#   ('sheehy', 0.22175371134825275),
#   ('detain', 0.20316647106356112),
#   ('apart', 0.20005255921399165),
#   ('father', 0.17397092697798608),
#   ('desired', 0.14708306016272935),
#   ('longer', 0.14383403051420124),
#   ('addressed', 0.12200842318386476),
#   ('election', 0.12049929877541762),
#   ('view', 0.11586808407039804),
#   ('detaining', 0.09510106047877023),
#   ('fact', 0.09223833373461363),
#   ('also', 0.08699250223762482),
#   ('think', 0.07551894290429174),
#   ('day', 0.07341877325229478)],
#  68: [('touched', 0.6767862357528995),
#   ('customs', 0.6276934255247336),
#   ('touch', 0.3022584726676818),
#   ('question', 0.2793429701264621),
#   ('touchstone', 0.20796916831683532),
#   ('answered', 0.15005062991780418),
#   ('miseries', 0.10398458415841766),
#   ('schools', 0.09564265643668593),
#   ('pleasing', 0.0918987218325163),
#   ('turning', 0.0918987218325163),
#   ('subject', 0.08957238785433429),
#   ('relieved', 0.08761549387572892),
#   ('reference', 0.08678315116263192),
#   ('disagreeable', 0.08243442719062592),
#   ('dispute', 0.0661559619741373)],
#  69: [('desire', 0.5518935397672972),
#   ('compulsion', 0.1708815461668789),
#   ('briefly', 0.14728284324725166),
#   ('speak', 0.1311493895602298),
#   ('prejudge', 0.10212857272752911),
#   ('dumb', 0.09672551408712286),
#   ('perpetuate', 0.09289289518151977),
#   ('versus', 0.09289289518151977),
#   ('preparation', 0.08992078915081797),
#   ('brief', 0.07216467587675697),
#   ('trespass', 0.07083648954368653),
#   ('harm', 0.06852428846743439),
#   ('non', 0.06166007801155014),
#   ('interfere', 0.05834653242499269),
#   ('decide', 0.056112226913092644)],
#  70: [('sometimes', 0.3538735945196742),
#   ('beyond', 0.3123474382464644),
#   ('strength', 0.2781706624954781),
#   ('subservient', 0.2578904036486422),
#   ('unreliant', 0.25303620668953114),
#   ('anxiety', 0.23995341402089992),
#   ('teach', 0.21120499870099638),
#   ('fail', 0.15373212852902093),
#   ('direction', 0.14764666822853564),
#   ('encourage', 0.14294027445134144),
#   ('even', 0.13703722484937336),
#   ('asked', 0.12463202699011541),
#   ('perhaps', 0.12142915684385537),
#   ('attempt', 0.11204625378065122),
#   ('hold', 0.10854693242334403)],
#  71: [('castle', 0.37351044716586257),
#   ('sheridan', 0.3048111370125009),
#   ('darling', 0.29869852937471364),
#   ('annul', 0.17144158527983439),
#   ('forwarded', 0.1627599523377164),
#   ('inquired', 0.15431147103566295),
#   ('affidavit', 0.1474111297554393),
#   ('delay', 0.13832867260064674),
#   ('defeated', 0.13288425885730995),
#   ('appointment', 0.1290616046425127),
#   ('appoint', 0.12218548050290311),
#   ('occurred', 0.12163986356540755),
#   ('weeks', 0.11627674777624113),
#   ('seven', 0.10383134331508151),
#   ('objection', 0.09860884948193717)]}

# %% [markdown]
# <font color="blue">Topics are generated through a process of clustering, where documents begin in one cluster and are then gradually divided on the basis of similarity. As such, clusters of topics can have an underlying similarity. The below visualisation shows clusters of similar topics.</font>
#
# <font color="blue">Use the slider at the bottom and the hover functionality for more detail on what the topics are.</font>

# %%
model_all.visualize_topics()
# Out:
# <div>                            <div id="5d42dbbf-eab5-49fa-9144-ab29be9b0a6d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d42dbbf-eab5-49fa-9144-ab29be9b0a6d")) {                    Plotly.newPlot(                        "5d42dbbf-eab5-49fa-9144-ab29be9b0a6d",                        [{"customdata":[[0,"cheers | land | hear | right | government",9050],[1,"situation | reason | forward | nothing | faults",212],[2,"emigration | migration | emigrants | emigrate | population",127],[3,"rule | home | repeal | difference | cheers",113],[4,"piers | fishery | harbours | fishermen | coast",82],[5,"herald | york | new | proxy | committee",82],[6,"mission | fulfilled | resolve | belongs | fullest",67],[7,"cries | no | shame | never | loud",67],[8,"carnarvon | lord | salisbury | interview | cabinet",64],[9,"position | unions | winning | firmness | trades",45],[10,"forster | buckshot | desirable | boycotting | intimidation",45],[11,"davitt | michael | father | egan | saw",41],[12,"oh | lion | lamb | directly | yes",39],[13,"constitution | lose | proportionately | desperate | careful",34],[14,"moment | years | climax | movement | past",34],[15,"shaw | twenty | voted | members | party",33],[16,"dillon | john | friend | tipperary | joseph",32],[17,"denied | honest | statement | absurdity | undoubtedly",31],[18,"resolution | keegan | subsequent | circular | second",31],[19,"case | cent | per | cases | analogous",31],[20,"oclock | hotel | crowd | railway | steps",30],[21,"ford | eventually | settled | patrick | question",28],[22,"spirit | candidature | withdrawing | admire | temper",28],[23,"trevelyan | galashiels | nephew | impugned | justify",28],[24,"overseer | orangeman | irritated | digging | workman",28],[25,"healy | sexton | timothy | tom | tim",27],[26,"literature | americans | born | native | assassination",27],[27,"whiskey | tobacco | whisky | duties | collecting",27],[28,"ambition | personal | gained | measures | entered",27],[29,"principle | proceeded | contend | assumption | concluding",27],[30,"hear | benches | divided | let | going",26],[31,"sir | creeds | well | single | classes",25],[32,"treason | felony | preaching | jurisdiction | convictions",24],[33,"power | powers | bear | strain | force",24],[34,"weakened | guarantee | assurances | miscalculate | safety",24],[35,"fetter | alone | careful | view | object",24],[36,"harrington | newspaper | brother | weekly | type",24],[37,"blow | struck | satisfaction | successful | results",24],[38,"guernsey | island | owns | farm | area",24],[39,"kerry | outrages | denounce | lurid | allusion",23],[40,"minority | majority | sometimes | often | small",23],[41,"marlborough | duchess | wife | fund | duke",22],[42,"adoption | standard | adopting | unfavourable | 22nd",22],[43,"danger | faced | risk | otherwise | physical",22],[44,"cheers | counter | oh | ironical | quantity",22],[45,"plus | ne | ultra | thou | shalt",21],[46,"manchester | maloney | condon | convicted | trial",20],[47,"division | motion | challenged | weakening | absent",20],[48,"balfour | initiated | prosecutions | aj | controlled",19],[49,"quarrels | happens | old | defeated | retract",19],[50,"victory | remarkable | one | providential | unsullied",19],[51,"boycotting | practice | advocating | speech | advocated",19],[52,"welcomed | prime | minister | truly | cheerfully",19],[53,"results | result | system | stands | condemned",18],[54,"path | crooked | led | lead | never",18],[55,"believe | mode | best | settle | dont",18],[56,"contest | calculated | devotion | try | circumstances",18],[57,"quite | agree | true | fair | play",18],[58,"leader | chairman | nominated | proposed | voted",18],[59,"candidature | withdrawn | lynch | word | regard",17],[60,"cell | prison | naked | muscles | wa ...

# %% [markdown]
# <font color="blue">The below visualisation is a hierarchical clustering tree, showing how clusters are related to each other and how larger topics are divided into smaller topics on the basis of similarity.</font>

# %%
model_all.visualize_hierarchy()
# Out:
# <div>                            <div id="72973d12-2e56-41f3-b672-a8fce82c76df" class="plotly-graph-div" style="height:1280px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72973d12-2e56-41f3-b672-a8fce82c76df")) {                    Plotly.newPlot(                        "72973d12-2e56-41f3-b672-a8fce82c76df",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6301900356044827,0.6301900356044827,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7367939766103065,0.7367939766103065,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9235900542922019,0.9235900542922019,0.7367939766103065],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.724109939486516,0.724109939486516,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9172111014575131,0.9172111014575131,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.9172111014575131,0.9577744787149711,0.9577744787149711,0.0],"xaxis":"x","y":[-90.0,-90.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9894440683373678,0.9894440683373678,0.9577744787149711],"xaxis":"x","y":[-75.0,-75.0,-97.5,-97.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9089229545179554,0.9089229545179554,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.9089229545179554,0.9566491992299715,0.9566491992299715,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.8898245118155511,0.8898245118155511,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9566491992299715,1.0063814541120133,1.0063814541120133,0.8898245118155511],"xaxis":"x","y":[-127.5,-127.5,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9894440683373678,1.0659812956165335,1.0659812956165335,1.0063814541120133],"xaxis":"x","y":[-86.25,-86.25,-138.75,-138.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8944684480073096,0.8944684480073096,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9466528262905548,0.9466528262905548,0.0],"xaxis":"x","y":[-185.0,-185.0,-195.0,-195.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8944684480073096,1.0368471823657455,1.0368471823657455,0.9466528262905548],"xaxis":"x","y":[-170.0,-170.0,-190.0,-190.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9371176476875589,0.9371176476875589,0.0],"xaxis":"x","y":[-205.0,-205.0,-215.0,-215.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9517078323701346,0.9517078323701346,0.0],"xaxis":"x","y":[-225.0,-225.0,-2 ...

# %% [markdown]
# <font color="blue">Finally, we have the topics over time visualisation, showing the distribution of topics over time.</font>

# %%
model_all_time = bertopic_time(df_stop, model_all)
model_all_time
# Out:
# <div>                            <div id="ab73c4c6-dcc1-4f31-b5de-65d390b6f2a8" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab73c4c6-dcc1-4f31-b5de-65d390b6f2a8")) {                    Plotly.newPlot(                        "ab73c4c6-dcc1-4f31-b5de-65d390b6f2a8",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rotundo, grattan, interval, rule, commencement","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: militia, meath, commanding, whether, mass","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: condon, meath, whether, education, hear","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: adjournment, penal, servitude, debate, magistrates","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: land, landlords, system, prussia, people","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: land, government, cheers, cork, people","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: government, people, coercion, could, cheers","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: land, tenant, league, hear, farmers","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: recently, philanthropy, perfidious, slanderer, coercionist","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hon, person, amendment, learned, right","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: improvements, rent, act, tenant, tenants","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: lord, spencer, mayor, coercion, movement","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: underlined, land, disunion, constitutional, likely","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: labourer, cork, secure, shall, cheers","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: underlined, hear, league, shall, parliament","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: oshea, galway, lynch, party, captain","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hon, right, gentleman, ulster, protestants","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: jury, judges, hon, gentleman, right","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: party, hon, gentleman, revision, evictions","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: campaign, plan, national, league, rome","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: learned, letters, attorney, inquiry, forgeries","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, empire, great, country, without","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: prisoners, political, treatment, prison, government","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, obrien, country, great, government","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, gladstone, question, hear, men"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_cheers_land_hear_right","x":["1874-07-04T21:34:33.600000","1875-01-30T08:48:00","1875-08-21T17:36:00","1876-03-12T02:24:00","1879-07-15T07:12:00","1880-02-03T16:00:00","1880-08-25T00:48:00","1881-03-16T09:36:00","1881-10-05T18:24:00","1882-04-27T03:12:00","1882-11-16T12:00:00","1883-06-07T20:48:00","1883-12-28T05:36:00","1884-07-18T14:24:00","1885-02-06T23:12:00","1885-08-29T08:00:00","1886-03-20T16:48:00","1886-10-10T01:36:00","1887-05-01T10:24:00","1887-11-20T19:12:00","1888-06-11T04:00:00","1888-12-31T12:48:00","1889-07-22T21:36:00","1890-02-11T06:24:00","1890-09-02T15:12:00"],"y":[27,155,268,160,803,1531,178,914,2,755,76,158,103,453,50,801,859,265,66,67,59,57,258,85,900],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic  ...

# %% [markdown]
# ### <font color="blue">Date Range</font>

# %% [markdown]
# <font color="blue">Set dates in first cell and then run cells underneath sequentially to get results. Error messages can occur if the format of the dates is incorrect or if not enough data for model. Experiment with different date ranges.</font>

# %%
#set date range
#date format - 'YYYY-MM-DD'
start_date = '1886-01-01'
end_date = '1886-12-31'
#use function to restrict dataframe to a date window
df_year_range = dataframe_date_window(df_stop, start_date, end_date)

# %%
topics_data_years = bertopic_topics(df_year_range, topic_model)
model_years = topics_data_years[2]

# %%
model_years.get_topics()
# Out:
# {-1: [('hon', 0.027388893673581195),
#   ('gentleman', 0.02261176085708787),
#   ('right', 0.021808524233359196),
#   ('member', 0.021394056231123722),
#   ('oshea', 0.019747707362421756),
#   ('party', 0.019087322529284214),
#   ('house', 0.0185507512081673),
#   ('hear', 0.01798106424482604),
#   ('night', 0.016821634303529794),
#   ('question', 0.01616408474233609),
#   ('cheers', 0.015119802718125462),
#   ('people', 0.014346634320929742),
#   ('bill', 0.014174417727321286),
#   ('future', 0.013514946770771986),
#   ('could', 0.013241409556203104)],
#  0: [('right', 0.021313921626800944),
#   ('hon', 0.01916326272152016),
#   ('gentleman', 0.018409956708576),
#   ('lynch', 0.01721341352736029),
#   ('oshea', 0.015946903918599067),
#   ('hear', 0.015474672715601826),
#   ('cheers', 0.015367209936277939),
#   ('parliament', 0.014060617149259916),
#   ('people', 0.013999354117616294),
#   ('galway', 0.013915958735278901),
#   ('one', 0.01319334131297726),
#   ('ulster', 0.012999852852343953),
#   ('could', 0.012867574330641547),
#   ('party', 0.012487139276610111),
#   ('bill', 0.011841217736505791)],
#  1: [('ford', 0.09853741895142663),
#   ('five', 0.08863896030445845),
#   ('hear', 0.07901150456358634),
#   ('years', 0.07788494290495901),
#   ('agree', 0.0713552797262982),
#   ('heard', 0.06948611605857412),
#   ('well', 0.06496691067070974),
#   ('believe', 0.0637305383912387),
#   ('remarkable', 0.060943403260023586),
#   ('lecture', 0.06063696378271307),
#   ('troubles', 0.06063696378271307),
#   ('fact', 0.059560381237209026),
#   ('denied', 0.05955952805020638),
#   ('gone', 0.05497638098511719),
#   ('policy', 0.05474301052857035)],
#  2: [('literature', 0.2228784878699874),
#   ('americans', 0.18538070743601728),
#   ('native', 0.15773396731817166),
#   ('born', 0.145169170882203),
#   ('american', 0.1256435130520402),
#   ('america', 0.10290534332793128),
#   ('especially', 0.09999649033083798),
#   ('assassination', 0.09898558418375118),
#   ('study', 0.08742936628129452),
#   ('sympathy', 0.08333040860903164),
#   ('newspapers', 0.07992234021391491),
#   ('domestic', 0.06424879074597592),
#   ('england', 0.06330763736322885),
#   ('conductors', 0.06199126230235321),
#   ('editors', 0.06199126230235321)],
#  3: [('proposed', 0.42333962432528166),
#   ('leader', 0.42189635736582576),
#   ('chairman', 0.3352108341129062),
#   ('shaw', 0.3289026072110078),
#   ('nominated', 0.2468387672210518),
#   ('also', 0.18385485413230196),
#   ('party', 0.1736527923567361),
#   ('wm', 0.14254054902048008),
#   ('position', 0.12148177332336253),
#   ('william', 0.11695056380027875),
#   ('voted', 0.11580970099205172),
#   ('famous', 0.1024655613383584),
#   ('attained', 0.0903756853372462),
#   ('division', 0.07219859185597685),
#   ('took', 0.0705566040542136)],
#  4: [('cheers', 0.5580879548807021),
#   ('cries', 0.3185792493498821),
#   ('oh', 0.24454122661915353),
#   ('given', 0.2310943446685607),
#   ('counter', 0.18445611005219975),
#   ('also', 0.14490255452800072),
#   ('concluding', 0.10593178376710988),
#   ('ironical', 0.10593178376710988),
#   ('response', 0.10215786779663863),
#   ('called', 0.09786105579268822),
#   ('three', 0.08427081601273861),
#   ('amid', 0.06470187015038595),
#   ('jolly', 0.06470187015038595),
#   ('uproarious', 0.06470187015038595),
#   ('expose', 0.06470187015038595)],
#  5: [('quarrels', 0.37806017415276466),
#   ('old', 0.35516029687697603),
#   ('desire', 0.2603571142192415),
#   ('happens', 0.2585468233770206),
#   ('generally', 0.23265241486323981),
#   ('defeated', 0.23265241486323981),
#   ('retract', 0.231643278984107),
#   ('distant', 0.2039119157986541),
#   ('unhappy', 0.18615963065110908),
#   ('back', 0.1855562217523043),
#   ('refer', 0.15237636671685006),
#   ('like', 0.13643789054395852),
#   ('nothing', 0.13279055196873207),
#   ('recur', 0.11402048673361874),
#   ('recollections', 0.11402048673361874)],
#  6: [('voice', 1.0648211215839922),
#   ('talk', 0.6712919897015371),
#   ('separation', 0.5274490335718756),
#   ('worthy', 0.5082453408252502),
#   ('welcome', 0.5059863212889489),
#   ('country', 0.12541360884825464),
#   ('utterance', 0.1211876298054848),
#   ('hollowest', 0.1211876298054848),
#   ('portsmouth', 0.09920595622634099),
#   ('absurd', 0.09278531618351456),
#   ('favourable', 0.09034613148586484),
#   ('policy', 0.08637230550063321),
#   ('really', 0.06966245799061904),
#   ('people', 0.06329598427781621),
#   ('ever', 0.05690365668721457)],
#  7: [('demerits', 0.416920006145713),
#   ('knew', 0.38756983061323685),
#   ('speak', 0.35577163215629226),
#   ('recommended', 0.330790756299243),
#   ('best', 0.30807995378312264),
#   ('time', 0.28869601961343677),
#   ('find', 0.24261442671353184),
#   ('man', 0.2331119222867617),
#   ('also', 0.2226367374258344),
#   ('fault', 0.21835298404217865),
#   ('wish', 0.20817685490931437),
#   ('came', 0.09021566080888446),
#   ('already', 0.07115432643125845),
#   ('forward', 0.07018019950793915),
#   ('shall', 0.06213905599809451)],
#  8: [('injury', 0.5745099978980234),
#   ('cannot', 0.40472961471182356),
#   ('return', 0.34132318967627534),
#   ('isolated', 0.323290093562554),
#   ('claim', 0.2424625789662624),
#   ('apart', 0.21990224383519638),
#   ('sufficient', 0.20951151270939694),
#   ('national', 0.20591861571833162),
#   ('act', 0.20514232875559402),
#   ('cause', 0.1646861778789323),
#   ('party', 0.13895716237195077),
#   ('give', 0.12772601323445293),
#   ('considerations', 0.12491416381007912),
#   ('damage', 0.12491416381007912),
#   ('consideration', 0.11578677361868409)],
#  9: [('task', 0.3049472044951501),
#   ('unravelling', 0.2744524840456351),
#   ('terrible', 0.2466046591580416),
#   ('seems', 0.21765820986159573),
#   ('devoted', 0.2061670163885478),
#   ('energy', 0.20424329119254253),
#   ('extraordinary', 0.17905250780282259),
#   ('large', 0.17444031371999186),
#   ('even', 0.17241294249963085),
#   ('many', 0.16680823110118967),
#   ('mind', 0.16027120923090574),
#   ('question', 0.11135357297677342),
#   ('seemed', 0.10332538628574307),
#   ('great', 0.10296567620268947),
#   ('people', 0.10253949453006227)],
#  10: [('mission', 0.7747049459080897),
#   ('fulfilled', 0.7516505805832472),
#   ('comes', 0.487100303529438),
#   ('shall', 0.3535021852336043),
#   ('day', 0.351158104775113),
#   ('regard', 0.33197288467762565),
#   ('settled', 0.12888041307268408),
#   ('considered', 0.09850992784436167),
#   ('great', 0.05630935417334581),
#   ('question', 0.054130209085931524),
#   ('established', 0.04632297252171619),
#   ('national', 0.03367627361226881),
#   ('parliament', 0.019213643326123818),
#   ('cheers', 0.014441749709632204),
#   ('', 1e-05)],
#  11: [('rule', 0.6810827664082181),
#   ('home', 0.6533007747714912),
#   ('cheers', 0.34660199303117295),
#   ('ministerial', 0.2632645747136661),
#   ('loud', 0.17712790304229076),
#   ('oh', 0.15187297232136904),
#   ('cries', 0.09892724058759496),
#   ('believe', 0.08335283573801483),
#   ('ditch', 0.08036653344995308),
#   ('much', 0.06179627675280907),
#   ('counter', 0.057278476279367295),
#   ('desperate', 0.05617448503858028),
#   ('renewed', 0.05062432410712301),
#   ('soon', 0.050027703975416345),
#   ('got', 0.050027703975416345)],
#  12: [('carnarvon', 0.32107664142739767),
#   ('lord', 0.2277734813183626),
#   ('cabinet', 0.1756623050764491),
#   ('denied', 0.09415103511753363),
#   ('statutory', 0.09069908163481971),
#   ('assertion', 0.06901504809162227),
#   ('resigned', 0.06517335439247503),
#   ('deny', 0.06230673946419725),
#   ('legislature', 0.05731130497808423),
#   ('hicks', 0.052993562638927245),
#   ('beach', 0.052993562638927245),
#   ('unofficially', 0.052993562638927245),
#   ('behaved', 0.052993562638927245),
#   ('views', 0.05164011622327653),
#   ('spoke', 0.049018708407428765)],
#  13: [('sums', 0.3658121174144466),
#   ('countrymen', 0.36265391052653184),
#   ('treasury', 0.323315011104315),
#   ('address', 0.3164651237835495),
#   ('several', 0.3164651237835495),
#   ('various', 0.30324803075925666),
#   ('gentlemen', 0.3012546530499595),
#   ('borrow', 0.2950409985485042),
#   ('purposes', 0.28290063471627563),
#   ('desire', 0.2687960602983766),
#   ('fellow', 0.24092777142431093),
#   ('large', 0.2280265538823423),
#   ('money', 0.21185614990326318),
#   ('able', 0.20534690873974784),
#   ('present', 0.02660958759662149)],
#  14: [('lose', 0.7187984034198771),
#   ('desperate', 0.4401299858692888),
#   ('proportionately', 0.4401299858692888),
#   ('careful', 0.3833591484906011),
#   ('constitution', 0.34256999087657897),
#   ('nothing', 0.3139515455480676),
#   ('give', 0.2362649081332443),
#   ('parnellite', 0.2292270805198327),
#   ('people', 0.20554881492280522),
#   ('submit', 0.12886546891256664),
#   ('hear', 0.11040876598341821),
#   ('behave', 0.07870949152314992),
#   ('love', 0.057306770129958176),
#   ('trouble', 0.057306770129958176),
#   ('promised', 0.0550162482336611)],
#  15: [('amendment', 0.28785472970548726),
#   ('oppose', 0.2708921867342704),
#   ('modification', 0.2708921867342704),
#   ('measure', 0.24918684379347167),
#   ('points', 0.23853014862491168),
#   ('reaches', 0.22573631279618042),
#   ('strongly', 0.2190650525515598),
#   ('serious', 0.21397102108301963),
#   ('press', 0.21238358989399936),
#   ('stage', 0.20934889433126347),
#   ('committee', 0.20124951551001607),
#   ('shape', 0.20034575594553347),
#   ('tremendous', 0.1933512016537018),
#   ('several', 0.19116421182864154),
#   ('meet', 0.17670952147621963)],
#  16: [('overseer', 0.32205206184218876),
#   ('irritated', 0.257407219489536),
#   ('works', 0.25315795424991516),
#   ('orangeman', 0.25315795424991516),
#   ('digging', 0.21862989829847784),
#   ('workman', 0.21217106596716753),
#   ('drain', 0.17371114695643572),
#   ('catholic', 0.1583195268927241),
#   ('way', 0.11385133130917915),
#   ('executing', 0.11160670075463361),
#   ('nice', 0.11160670075463361),
#   ('drains', 0.11160670075463361),
#   ('workmen', 0.11160670075463361),
#   ('papist', 0.11160670075463361),
#   ('replied', 0.11160670075463361)],
#  17: [('land', 0.3440391906795801),
#   ('act', 0.13145855352909494),
#   ('question', 0.12151679590719322),
#   ('movement', 0.11857728763899333),
#   ('settle', 0.09699248729927658),
#   ('passing', 0.07361189984964314),
#   ('league', 0.06670586298701504),
#   ('pressing', 0.06670586298701504),
#   ('rebel', 0.06377525757407634),
#   ('threatened', 0.061503206122466104),
#   ('passed', 0.049074599899762095),
#   ('difficulty', 0.04794942783582408),
#   ('happened', 0.04601942330101513),
#   ('brought', 0.040708762935454515),
#   ('atlantic', 0.03895316672319154)],
#  18: [('ambition', 0.44776603959848055),
#   ('struggle', 0.4050899937854104),
#   ('personal', 0.3876072749733781),
#   ('measures', 0.363381820287542),
#   ('entered', 0.32816055946295863),
#   ('stand', 0.32128223496068736),
#   ('motives', 0.31622009261584033),
#   ('gained', 0.30355275049199004),
#   ('duty', 0.27481355833250143),
#   ('till', 0.25518177104269457),
#   ('great', 0.23300422416556885),
#   ('motive', 0.13855894712647537),
#   ('completed', 0.11270990642633577),
#   ('serve', 0.043878279757158294),
#   ('people', 0.03437626732329674)],
#  19: [('faced', 0.4372597965969557),
#   ('danger', 0.4274420108222724),
#   ('risk', 0.4065961510357626),
#   ('otherwise', 0.3226306767563198),
#   ('personal', 0.18817987122033425),
#   ('physical', 0.17390913145119558),
#   ('running', 0.14040393790338326),
#   ('post', 0.1288208247368755),
#   ('away', 0.1104718935755554),
#   ('like', 0.08979840755189106),
#   ('protect', 0.08486842638686701),
#   ('opposite', 0.08214139863987756),
#   ('something', 0.07978253562208693),
#   ('separation', 0.07417252034604499),
#   ('looks', 0.0681680417655852)],
#  20: [('force', 0.6249299216230347),
#   ('unfair', 0.28894846308123046),
#   ('ask', 0.28056353923950583),
#   ('pay', 0.25352883847237917),
#   ('control', 0.24387281437377675),
#   ('proportion', 0.229400223963836),
#   ('whatever', 0.22701597851538555),
#   ('large', 0.18459292457141996),
#   ('perpetrated', 0.17006735353087027),
#   ('abuses', 0.11929540652166157),
#   ('power', 0.10917135659466888),
#   ('shall', 0.10821495466334825),
#   ('committed', 0.10697442887876821),
#   ('injustice', 0.10358478508024688),
#   ('real', 0.10358478508024688)]}

# %%
model_years.visualize_topics()
# Out:
# <div>                            <div id="8a508df9-a79c-4990-a7e4-726e53d5ad28" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a508df9-a79c-4990-a7e4-726e53d5ad28")) {                    Plotly.newPlot(                        "8a508df9-a79c-4990-a7e4-726e53d5ad28",                        [{"customdata":[[0,"right | hon | gentleman | lynch | oshea",1978],[1,"ford | five | hear | years | agree",140],[2,"literature | americans | native | born | american",41],[3,"proposed | leader | chairman | shaw | nominated",36],[4,"cheers | cries | oh | given | counter",33],[5,"quarrels | old | desire | happens | generally",28],[6,"voice | talk | separation | worthy | welcome",27],[7,"demerits | knew | speak | recommended | best",24],[8,"injury | cannot | return | isolated | claim",22],[9,"task | unravelling | terrible | seems | devoted",21],[10,"mission | fulfilled | comes | shall | day",20],[11,"rule | home | cheers | ministerial | loud",19],[12,"carnarvon | lord | cabinet | denied | statutory",19],[13,"sums | countrymen | treasury | address | several",18],[14,"lose | desperate | proportionately | careful | constitution",18],[15,"amendment | oppose | modification | measure | points",18],[16,"overseer | irritated | works | orangeman | digging",18],[17,"land | act | question | movement | settle",17],[18,"ambition | struggle | personal | measures | entered",16],[19,"faced | danger | risk | otherwise | personal",16],[20,"force | unfair | ask | pay | control",16]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1978,140,41,36,33,28,27,24,22,21,20,19,19,18,18,18,18,17,16,16,16],"sizemode":"area","sizeref":1.23625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.4459097385406494,-6.546685695648193,-1.9535127878189087,-4.293359756469727,15.465487480163574,-3.4614899158477783,-6.805522441864014,-6.285160541534424,-3.2511165142059326,-6.673561096191406,-2.1478471755981445,15.226778984069824,-4.326554775238037,-3.1111068725585938,-7.182508945465088,-2.3485264778137207,-2.808049201965332,-2.4823381900787354,-2.107980489730835,-1.7237122058868408,-3.600170135498047],"xaxis":"x","y":[5.314974784851074,4.902007579803467,4.9597954750061035,5.924347877502441,1.8638814687728882,5.792722225189209,4.464541435241699,4.777899265289307,7.1880340576171875,5.02876615524292,6.72484016418457,2.094006061553955,6.588680267333984,6.233539581298828,4.820938587188721,6.2777419090271,4.948764801025391,5.65008544921875,5.3371052742004395,5.59422492980957,5.063784599304199],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0. ...

# %%
model_years.visualize_hierarchy()
# Out:
# <div>                            <div id="6d1a63a8-48ef-4b2d-96d8-964103cb48f0" class="plotly-graph-div" style="height:515px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d1a63a8-48ef-4b2d-96d8-964103cb48f0")) {                    Plotly.newPlot(                        "6d1a63a8-48ef-4b2d-96d8-964103cb48f0",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6870350008646176,0.6870350008646176,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9303995480198853,0.9303995480198853,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9299477419660996,0.9299477419660996,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9817314336275561,0.9817314336275561,0.9299477419660996],"xaxis":"x","y":[-45.0,-45.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9554131188319573,0.9554131188319573,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.992623847723614,0.992623847723614,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.992623847723614,0.9951948718281484,0.9951948718281484,0.0],"xaxis":"x","y":[-100.0,-100.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9554131188319573,1.019510188676203,1.019510188676203,0.9951948718281484],"xaxis":"x","y":[-80.0,-80.0,-107.5,-107.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9521496420382985,0.9521496420382985,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.9521496420382985,0.9888360238498958,0.9888360238498958,0.0],"xaxis":"x","y":[-130.0,-130.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.019510188676203,1.0306125385113092,1.0306125385113092,0.9888360238498958],"xaxis":"x","y":[-93.75,-93.75,-137.5,-137.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9817314336275561,1.0407192427196976,1.0407192427196976,1.0306125385113092],"xaxis":"x","y":[-52.5,-52.5,-115.625,-115.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9303995480198853,1.0461187340847635,1.0461187340847635,1.0407192427196976],"xaxis":"x","y":[-30.0,-30.0,-84.0625,-84.0625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7527833762857971,0.7527833762857971,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7527833762857971,0.8937465007346074,0.8937465007346074,0.0],"xaxis":"x","y":[-170.0,-170.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9727136826285745,0.9727136826285745,0.8937465007346074],"xaxis":"x","y":[-155.0,-155.0,-177.5,-177.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9299315190057449,0.92993151900 ...

# %%
model_years_time = bertopic_time(df_year_range, model_years)
model_years_time
# Out:
# <div>                            <div id="9792d754-5517-45e7-91ce-f868c51a07bc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9792d754-5517-45e7-91ce-f868c51a07bc")) {                    Plotly.newPlot(                        "9792d754-5517-45e7-91ce-f868c51a07bc",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rents, tenants, agricultural, reduction, cent","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: lynch, oshea, galway, captain, party","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: right, hon, gentleman, bill, lord","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ulster, right, hon, parliament, gentleman","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: gladstone, great, bill, cheers, people"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_right_hon_gentleman_lynch","x":["1886-01-20T20:13:55.200000","1886-02-05T16:48:00","1886-04-04T06:24:00","1886-06-06T01:36:00","1886-06-21T18:24:00"],"y":[50,810,466,442,210],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: vague, inaccurate, denied, experience, ford","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: heard, remarkable, lecture, fact, seldom","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: ford, troubles, quite, policy, agree","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: five, hear, years, ford, creeds","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: denied, well, assertion, gone, deny"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_ford_five_hear_years","x":["1886-01-20T20:13:55.200000","1886-02-05T16:48:00","1886-04-04T06:24:00","1886-06-06T01:36:00","1886-06-21T18:24:00"],"y":[3,25,29,62,21],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: newspaper, tells, reported, american, newspapers","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: chapters, describing, incidents, written, remain","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: literature, americans, native, born, american","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: reported, newspapers, represent, local, facts"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_literature_americans_native_born","x":["1886-01-20T20:13:55.200000","1886-02-05T16:48:00","1886-04-04T06:24:00","1886-06-06T01:36:00"],"y":[1,1,35,4],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: proposed, leader, chairman, shaw, nominated"],"marker":{"color":"#F0E442"},"mode":"lines","name":"3_proposed_leader_chairman_shaw","x":["1886-02-05T16:48:00"],"y":[36],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, given, also, concluding, response","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, oh, cries, counter, given","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, cries, oh, ironical, counter","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: cries, cheers, counter, minutes, jolly"],"marker":{"color":"#D55E00"},"mode":"lines","name":"4_cheers_cries_oh_given","x":["1886-02-05T16:48:00","1886-04-04T06:24:00","1886-06-06T01:36:00","1886-06-21T18:24:00"],"y":[10,9,7,7],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: contest, desire, quarrels, old, happens","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: quarrels, old, desire, happens, defeated","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWor ...

# %% [markdown]
# ### <font color="blue">Publication</font>

# %% [markdown]
# <font color="blue">Set publication keywords or phrases in first cell and then run cells underneath sequentially to get results and visualisations. Error messages can occur if the format of the publication_word list is incorrect or if not enough data for model.</font>
#
# <font color="blue">Experiment with different publication searches. My initial search for 'freeman' and 'journal' will pick up 'The Freeman's Journal' and 'The Weekly Freeman's Journal'.</font>

# %%
publication_words = ['freeman', 'journal']
#use function to restrict dataframe to rows where publication contains any of publication_words
df_publication = dataframe_keyword_any(df_stop, column='publication', keywords=publication_words)
df_publication
# Out:
#                  filename     speech_id            publication  \
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 1    parnell_source_00002  speech_00001  the freeman's journal
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 1    home rule league saturday evening public meeti...     dublin, ireland
# 1    platform also well filled appearance successio...     dublin, ireland
# 1    besides gentlemen named present messrs cs high...     dublin, ireland
# 1    half past eight oclock motion alfred webb chai...     dublin, ireland
# 1                                          voice never     dublin, ireland
# ..                                                 ...                 ...
# 660  application perfectly disgraceful one one cann...  waterford, ireland
# 660  good legal opinion sales since passing land ac...  waterford, ireland
# 660  chairman already sent forms requesting particu...  waterford, ireland
# 660                               chairman must settle  waterford, ireland
# 660            cannot expect take everything shoulders  waterford, ireland
#
#           date
# 1   1874-07-11
# 1   1874-07-11
# 1   1874-07-11
# 1   1874-07-11
# 1   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [7557 rows x 6 columns]

# %%
topics_publication = bertopic_topics(df_publication, topic_model)
model_publication = topics_publication[2]

# %%
model_publication.get_topics()
# Out:
# {-1: [('hear', 0.011278975089672221),
#   ('cheers', 0.010812028778575147),
#   ('people', 0.009406464856206912),
#   ('land', 0.009024169274190025),
#   ('one', 0.008725679335953574),
#   ('country', 0.00856470130214614),
#   ('question', 0.008303090445536225),
#   ('great', 0.007827765299344291),
#   ('day', 0.007363087663055115),
#   ('shall', 0.007059933194415506),
#   ('men', 0.006945976092676333),
#   ('present', 0.006817993054029212),
#   ('time', 0.006630736852559665),
#   ('could', 0.006613613347219981),
#   ('government', 0.006604740847028268)],
#  0: [('irishmen', 0.037459382740181416),
#   ('cheers', 0.03327526445959369),
#   ('thank', 0.020666365612532277),
#   ('loud', 0.019227972026544287),
#   ('mayor', 0.016975672577562502),
#   ('voice', 0.015404640707322968),
#   ('address', 0.014899007767174432),
#   ('gentlemen', 0.014351965452552247),
#   ('men', 0.014212894706484139),
#   ('meeting', 0.013988328030920275),
#   ('magnificent', 0.012840981414328372),
#   ('great', 0.012815950596593212),
#   ('courage', 0.012457976612781717),
#   ('chairman', 0.011719351708534628),
#   ('shall', 0.011459764305533297)],
#  1: [('parliament', 0.0349017911452769),
#   ('english', 0.027216790576194),
#   ('gladstone', 0.024636976769338365),
#   ('party', 0.02092874655750881),
#   ('election', 0.017857009267722705),
#   ('england', 0.017170553662633106),
#   ('government', 0.016284268510838657),
#   ('power', 0.015620148848198536),
#   ('house', 0.014765510620317087),
#   ('hear', 0.01403172230443064),
#   ('general', 0.012820655810817353),
#   ('constituency', 0.0127354681787471),
#   ('country', 0.012524312282743815),
#   ('commons', 0.011992984450092396),
#   ('constituencies', 0.011853289089680722)],
#  2: [('tenant', 0.04597788467074442),
#   ('tenants', 0.04023064908690137),
#   ('rent', 0.03970917162064452),
#   ('landlords', 0.03141793511916729),
#   ('farmers', 0.029801147030551728),
#   ('court', 0.02834720787338839),
#   ('rents', 0.02143428553324058),
#   ('landlord', 0.019737639643807328),
#   ('landlordism', 0.01661208489098732),
#   ('purchase', 0.015714576084036213),
#   ('cases', 0.015141469305822258),
#   ('act', 0.014305789490691827),
#   ('years', 0.014047128612281395),
#   ('pay', 0.012906124871060484),
#   ('rack', 0.012613298793516494)],
#  3: [('voice', 0.449082273965946),
#   ('enniscorthy', 0.06592188336086359),
#   ('groans', 0.0651005948196704),
#   ('another', 0.06347715892583625),
#   ('thanks', 0.04770873026526522),
#   ('welcome', 0.04038799159198284),
#   ('voices', 0.03693012305885335),
#   ('noise', 0.03321297432860735),
#   ('groan', 0.032528751138382),
#   ('ennis', 0.031412771881080735),
#   ('man', 0.031160188959466897),
#   ('wexford', 0.030806400270268163),
#   ('right', 0.030027520040009383),
#   ('freeman', 0.029026940209416065),
#   ('sir', 0.028471759816284838)],
#  4: [('league', 0.09022217185369868),
#   ('national', 0.0463282607252093),
#   ('land', 0.04603315373332571),
#   ('organisation', 0.04157207142533705),
#   ('movement', 0.02562011070012809),
#   ('programme', 0.02297397100123745),
#   ('convention', 0.017354411697931126),
#   ('county', 0.01670642311878643),
#   ('meeting', 0.014261116287305569),
#   ('formed', 0.013888934721131155),
#   ('day', 0.013536916973406088),
#   ('purpose', 0.01275739153684336),
#   ('days', 0.01219246977893259),
#   ('conference', 0.01202819746548854),
#   ('branch', 0.011901457431169373)],
#  5: [('prison', 0.05153273544524563),
#   ('harrington', 0.04174662672757911),
#   ('prisoners', 0.03497403109606181),
#   ('condon', 0.02548055671595123),
#   ('imprisonment', 0.025120655253943504),
#   ('newspaper', 0.024452211358053852),
#   ('offence', 0.023723039309109423),
#   ('legal', 0.02349001040083927),
#   ('law', 0.02165054319198946),
#   ('penal', 0.019409759434725893),
#   ('sentenced', 0.019380971618889607),
#   ('government', 0.018846163892429345),
#   ('jail', 0.01828584010131302),
#   ('servitude', 0.01763288392723667),
#   ('illegal', 0.017248548278422274)],
#  6: [('resolution', 0.06486072067769025),
#   ('chairman', 0.06429816785092543),
#   ('reading', 0.05038184816455839),
#   ('convention', 0.04980992879132851),
#   ('resolutions', 0.049570280448114436),
#   ('second', 0.043827172235839415),
#   ('committee', 0.03707017256129614),
#   ('executive', 0.03432176604733015),
#   ('amendments', 0.028566327012495396),
#   ('bill', 0.025855131150623115),
#   ('party', 0.022968758949402184),
#   ('action', 0.020878833262041954),
#   ('adopted', 0.019844455519907916),
#   ('discussion', 0.019534494820901326),
#   ('adequate', 0.019185984622723862)],
#  7: [('constabulary', 0.09886342808144807),
#   ('police', 0.08133666050233758),
#   ('control', 0.07693691810339713),
#   ('force', 0.056653317362875814),
#   ('imperial', 0.05467165283246463),
#   ('authority', 0.04028389485142659),
#   ('armed', 0.03199558366696188),
#   ('retained', 0.027559179854115302),
#   ('legislature', 0.02497499066116446),
#   ('civil', 0.02359711270836497),
#   ('power', 0.022415305473134712),
#   ('army', 0.0221795443335186),
#   ('royal', 0.0221795443335186),
#   ('weapons', 0.02111777891113327),
#   ('million', 0.020285466432299393)],
#  8: [('cork', 0.1923226895147446),
#   ('city', 0.06247588486988351),
#   ('constituency', 0.054000562080995185),
#   ('tory', 0.023091786237141233),
#   ('return', 0.022916112556930525),
#   ('cheers', 0.02270553711315865),
#   ('whig', 0.020756945079782787),
#   ('representative', 0.019865643546584155),
#   ('represented', 0.019454658488959553),
#   ('two', 0.019286812172709115),
#   ('examiner', 0.018656144946067266),
#   ('ronayne', 0.018656144946067266),
#   ('amongst', 0.01789706315555399),
#   ('honoured', 0.017864127576190145),
#   ('nationalists', 0.017864127576190145)],
#  9: [('question', 0.11094906974798249),
#   ('land', 0.08780624448993367),
#   ('settled', 0.04652201030358895),
#   ('constitutional', 0.031836176458478124),
#   ('settlement', 0.03164478561974171),
#   ('final', 0.023877132343858593),
#   ('nationalisation', 0.022619367447563418),
#   ('settling', 0.021698839144424716),
#   ('dont', 0.02019268283567134),
#   ('questions', 0.01962742410628722),
#   ('followed', 0.01928004701341325),
#   ('present', 0.01892931346694024),
#   ('solution', 0.01817951136939201),
#   ('underlined', 0.018015432099971),
#   ('proposal', 0.017773353837048044)],
#  10: [('labourers', 0.13618649427110943),
#   ('artisans', 0.04891415405038286),
#   ('labourer', 0.03668561553778714),
#   ('act', 0.03291219960298734),
#   ('farmers', 0.03240452099961693),
#   ('labour', 0.02659669344573027),
#   ('towns', 0.025583198600335817),
#   ('work', 0.022619517596442557),
#   ('employer', 0.02162444995645282),
#   ('agricultural', 0.020554204099331213),
#   ('benefit', 0.01976930483018671),
#   ('time', 0.018956638365694257),
#   ('separate', 0.018212530410367862),
#   ('condition', 0.017807462185146648),
#   ('working', 0.01774700681370697)],
#  11: [('dickson', 0.19109995331427365),
#   ('rylett', 0.11514080244329114),
#   ('thomas', 0.09474335994339832),
#   ('harold', 0.061946567251053845),
#   ('knox', 0.05072434921351813),
#   ('ulster', 0.037269983870053564),
#   ('government', 0.03647470282352258),
#   ('oppose', 0.03490030581436613),
#   ('coercion', 0.033125065481850666),
#   ('dead', 0.029005512448187755),
#   ('tyrone', 0.026665142129526653),
#   ('representative', 0.025485529549894144),
#   ('north', 0.02371726246276136),
#   ('whig', 0.022824836224949113),
#   ('place', 0.022024827498226245)],
#  12: [('hon', 0.1558678101345419),
#   ('gentleman', 0.12360230272314082),
#   ('right', 0.08259946428431493),
#   ('member', 0.07737398979938019),
#   ('birmingham', 0.045802580675968846),
#   ('edinburgh', 0.03700763155010857),
#   ('language', 0.031179461745419964),
#   ('sir', 0.028770572345049806),
#   ('kerry', 0.027313511786298785),
#   ('paddington', 0.024348253327343364),
#   ('west', 0.02404517400331273),
#   ('lord', 0.022688834585729144),
#   ('standard', 0.022509956791161183),
#   ('home', 0.02158217893509908),
#   ('occurrences', 0.020014211285645407)],
#  13: [('meath', 0.26008309531830753),
#   ('county', 0.061703990097313775),
#   ('priests', 0.0283474007515896),
#   ('parish', 0.025954446595598927),
#   ('feel', 0.02441129880503615),
#   ('patriotism', 0.02358898887538668),
#   ('honour', 0.0232151167798927),
#   ('parishes', 0.022955106139764054),
#   ('member', 0.021681890918811654),
#   ('electors', 0.020531299708663377),
#   ('constituencies', 0.019345930649910584),
#   ('leave', 0.019049247385724905),
#   ('saturday', 0.019047583420558685),
#   ('away', 0.018435247669091912),
#   ('cheers', 0.018287769112356956)],
#  14: [('tories', 0.09243568188511017),
#   ('whigs', 0.09159809840878233),
#   ('whig', 0.0819214901107973),
#   ('tory', 0.07575714404540283),
#   ('dan', 0.03579873683323824),
#   ('nicholas', 0.03523549727293359),
#   ('government', 0.03391830259343132),
#   ('liberal', 0.03295591775821388),
#   ('murphy', 0.030933699444938696),
#   ('borough', 0.027141525879734132),
#   ('hisses', 0.02699911975177554),
#   ('office', 0.02687361326101851),
#   ('next', 0.026812523611933235),
#   ('party', 0.026315663798488625),
#   ('independent', 0.026281895285372246)],
#  15: [('hear', 0.1685614316172958),
#   ('heard', 0.07675312092350202),
#   ('seldom', 0.05093402359257968),
#   ('lecture', 0.05093402359257968),
#   ('kelly', 0.05093402359257968),
#   ('bit', 0.046907642378722136),
#   ('delay', 0.04344058753259712),
#   ('plan', 0.042019193815704056),
#   ('kinnear', 0.033956015728386454),
#   ('votes', 0.03261024417203822),
#   ('contradicted', 0.02999911142459864),
#   ('believe', 0.02792450950938905),
#   ('speak', 0.027438553329784968),
#   ('never', 0.027308429327380812),
#   ('dictation', 0.0269795937597713)],
#  16: [('rule', 0.19499641482657015),
#   ('home', 0.19179289977519523),
#   ('hartlepool', 0.045174894688916674),
#   ('repeal', 0.035430422630067425),
#   ('lose', 0.02983985036970923),
#   ('house', 0.02868156716095434),
#   ('confederation', 0.021776925283182817),
#   ('election', 0.021679194838563523),
#   ('difference', 0.020886135912105214),
#   ('tuke', 0.020805191083432147),
#   ('first', 0.020462940527479313),
#   ('question', 0.019883468919178488),
#   ('beyond', 0.019493597894943773),
#   ('cheers', 0.01892633603875367),
#   ('commons', 0.017672840613310783)],
#  17: [('history', 0.11900392377025294),
#   ('future', 0.11147764289512435),
#   ('closed', 0.06916721491754985),
#   ('past', 0.06889633852534782),
#   ('promising', 0.06369948323024913),
#   ('book', 0.058063163794114296),
#   ('retired', 0.05565797050292651),
#   ('succeed', 0.05251460205037381),
#   ('years', 0.051068449835039116),
#   ('happened', 0.049199645221883144),
#   ('hope', 0.04720081624306561),
#   ('days', 0.04564736474716043),
#   ('forecast', 0.04469678780712867),
#   ('expectations', 0.04350132539877863),
#   ('many', 0.04190406449009202)],
#  18: [('emigration', 0.12330467839271586),
#   ('emigrants', 0.05542413908810393),
#   ('emigrate', 0.050963840947293004),
#   ('emigrated', 0.04637611102032302),
#   ('population', 0.04627021878767773),
#   ('migration', 0.03864675918360251),
#   ('scheme', 0.037111676246264984),
#   ('resources', 0.03224072299161853),
#   ('districts', 0.030367008591981878),
#   ('rate', 0.027376997841604054),
#   ('people', 0.026010084990271538),
#   ('instead', 0.025294738783316447),
#   ('country', 0.024679997138142264),
#   ('find', 0.0244644397257555),
#   ('developed', 0.02375320246633026)],
#  19: [('negotiations', 0.0547257563814405),
#   ('injury', 0.04167167206066733),
#   ('promise', 0.03700918557111082),
#   ('cannot', 0.036211321205696256),
#   ('satisfactory', 0.03596794678956981),
#   ('objection', 0.03480578959489962),
#   ('boulogne', 0.02892012705546845),
#   ('disappeared', 0.028446762000483943),
#   ('accept', 0.028215413785905058),
#   ('public', 0.027139567945435365),
#   ('confidence', 0.025161124517756733),
#   ('assurances', 0.024861442747339743),
#   ('last', 0.0220644008665183),
#   ('party', 0.020843171779971102),
#   ('guarantee', 0.020705205989808007)],
#  20: [('lynch', 0.21273354869625502),
#   ('oshea', 0.08695611447933708),
#   ('galway', 0.05872640153710866),
#   ('poll', 0.058246665202361846),
#   ('morrow', 0.04859568267507256),
#   ('tories', 0.045874817904309556),
#   ('vote', 0.04527315618872921),
#   ('votes', 0.04445693443766148),
#   ('comrade', 0.04263220622441152),
#   ('forward', 0.04224316460363785),
#   ('ballot', 0.040897226121816115),
#   ('name', 0.040284640170241845),
#   ('withdrawn', 0.0388599820184567),
#   ('retired', 0.03725025630013571),
#   ('paper', 0.03725025630013571)],
#  21: [('bill', 0.09063990545602257),
#   ('land', 0.08077069018772765),
#   ('principle', 0.05654165898816804),
#   ('act', 0.04896577609998404),
#   ('measure', 0.031614857070019216),
#   ('convention', 0.028316407000653087),
#   ('principles', 0.023138909563762265),
#   ('admit', 0.021966418448589233),
#   ('butt', 0.020156766826909152),
#   ('objects', 0.01984650856414516),
#   ('unthought', 0.0196834866961025),
#   ('render', 0.01941906867186485),
#   ('qualifications', 0.018518219917066252),
#   ('responsible', 0.018347954278021703),
#   ('acceptable', 0.01769189630260201)],
#  22: [('coercion', 0.24459849488757462),
#   ('act', 0.032495083184407816),
#   ('government', 0.02835079174010164),
#   ('living', 0.027292545239440705),
#   ('thing', 0.026616485930225333),
#   ('inflicted', 0.026202751470670565),
#   ('office', 0.02371036503341946),
#   ('meet', 0.021785394677827197),
#   ('drastic', 0.021375036334048806),
#   ('bill', 0.021282004828356654),
#   ('prevent', 0.02110733585738691),
#   ('iniquity', 0.020109629441189134),
#   ('coerce', 0.020109629441189134),
#   ('hear', 0.019934166291789387),
#   ('even', 0.019235467684338405)],
#  23: [('position', 0.17318418532775182),
#   ('difficulties', 0.1593501193370755),
#   ('struggle', 0.10108369686577552),
#   ('contentions', 0.09417192323678815),
#   ('avoid', 0.06889666991824525),
#   ('lots', 0.06673182075020115),
#   ('troubled', 0.06278128215785876),
#   ('revenge', 0.054535807938956626),
#   ('chances', 0.05323826728511878),
#   ('patience', 0.052094366363219034),
#   ('short', 0.04900031561396745),
#   ('winning', 0.04714185481993283),
#   ('ordinary', 0.046517393233340205),
#   ('help', 0.04252964561284394),
#   ('amongst', 0.03830408029024056)],
#  24: [('soil', 0.062392842121408915),
#   ('produce', 0.06002956282771686),
#   ('acres', 0.059310154307845954),
#   ('lands', 0.04092413019728499),
#   ('land', 0.038456743993700145),
#   ('employment', 0.03794437990464593),
#   ('farmer', 0.03576432096864347),
#   ('tillers', 0.03475665496651155),
#   ('make', 0.03447550691355429),
#   ('agricultural', 0.03215286995266032),
#   ('farmers', 0.030414167667416555),
#   ('labourers', 0.02924024340821364),
#   ('amount', 0.028360382782458598),
#   ('tiller', 0.027902877300245987),
#   ('mutton', 0.027902877300245987)],
#  25: [('reason', 0.18668001090788178),
#   ('want', 0.16873196148305813),
#   ('contrary', 0.11747456474487235),
#   ('live', 0.10870323092712436),
#   ('girls', 0.1031866249149149),
#   ('think', 0.09762008792091874),
#   ('brace', 0.093698789409529),
#   ('obvious', 0.093698789409529),
#   ('speaking', 0.09022634345826291),
#   ('boys', 0.08815180029014415),
#   ('exaggerated', 0.08815180029014415),
#   ('untrue', 0.084218273495263),
#   ('career', 0.08116883211785529),
#   ('misled', 0.08116883211785529),
#   ('mislead', 0.07867859223583608)],
#  26: [('feudal', 0.12662967584615484),
#   ('prussia', 0.12248296874354712),
#   ('system', 0.11077516185047231),
#   ('tenure', 0.09178342628143062),
#   ('serfs', 0.04544650661579719),
#   ('evils', 0.04255971498855661),
#   ('prussian', 0.03998656237498666),
#   ('land', 0.039610967407603205),
#   ('edict', 0.037356339728234364),
#   ('nobles', 0.03549217819007919),
#   ('emperor', 0.03139064107892938),
#   ('england', 0.031109003106417628),
#   ('administered', 0.029260168513704218),
#   ('russia', 0.028904023144407008),
#   ('crushed', 0.027267903969478313)],
#  27: [('money', 0.07005526660043346),
#   ('sum', 0.06849863785276028),
#   ('spent', 0.06099671800196156),
#   ('salaries', 0.05797773722703949),
#   ('pay', 0.05580901370858107),
#   ('paid', 0.05022157069068738),
#   ('millions', 0.0462626539339987),
#   ('sterling', 0.0435690842871154),
#   ('per', 0.04328303589871063),
#   ('expenses', 0.04097725983242632),
#   ('pounds', 0.03521527130318609),
#   ('five', 0.034650409003942055),
#   ('annum', 0.03371939667250118),
#   ('officials', 0.03281753608851108),
#   ('million', 0.03220797475291372)],
#  28: [('sir', 0.35874417368518896),
#   ('quite', 0.20258298542319436),
#   ('less', 0.19550613129950564),
#   ('offensive', 0.1900003229693227),
#   ('well', 0.1854848935978095),
#   ('true', 0.17166780449236793),
#   ('glad', 0.1624373006616971),
#   ('play', 0.1403774541562629),
#   ('yes', 0.1403774541562629),
#   ('fair', 0.13796860995425245),
#   ('oh', 0.12630586866151552),
#   ('recognise', 0.11098092171155338),
#   ('agree', 0.10803334550234724),
#   ('notice', 0.10601847792895497),
#   ('indeed', 0.10537940014853091)],
#  29: [('settlement', 0.19673225705616088),
#   ('settled', 0.06344764377160172),
#   ('eventually', 0.048408928859481885),
#   ('settle', 0.047854248525164025),
#   ('question', 0.041123814982447895),
#   ('final', 0.04031746756224592),
#   ('going', 0.039806330780998905),
#   ('bygones', 0.03590557284459642),
#   ('according', 0.03265221723049495),
#   ('precedent', 0.03110406690080544),
#   ('allow', 0.026254116245978447),
#   ('urged', 0.023868825573829706),
#   ('think', 0.02338013916741164),
#   ('dispute', 0.023143505995404403),
#   ('recognised', 0.022508249937993916)],
#  30: [('bishops', 0.08882281604218674),
#   ('education', 0.049595849110500495),
#   ('catholic', 0.04311187304863144),
#   ('religious', 0.04152956555344595),
#   ('political', 0.041392599943980986),
#   ('protestant', 0.0397567894119928),
#   ('catholics', 0.038140518230213936),
#   ('ecclesiastical', 0.03447365047060994),
#   ('influence', 0.03428784629735646),
#   ('priests', 0.0340573771886955),
#   ('fears', 0.032935360527611784),
#   ('clergyman', 0.02994600168076636),
#   ('clergy', 0.026646844812656025),
#   ('church', 0.026252686605459492),
#   ('opinion', 0.025676097574649108)],
#  31: [('matter', 0.16877713450714377),
#   ('attach', 0.10854214201442822),
#   ('let', 0.09564699252648115),
#   ('plain', 0.07485535029567725),
#   ('another', 0.06719856070005444),
#   ('minds', 0.06087678426449262),
#   ('interpretation', 0.05968867927334173),
#   ('importance', 0.0569484113593215),
#   ('dont', 0.0540525351911868),
#   ('subject', 0.0487624500041909),
#   ('mind', 0.04835534594210151),
#   ('occupying', 0.04463858722356273),
#   ('much', 0.04428735784823328),
#   ('sort', 0.04280425137984989),
#   ('gray', 0.0420049895606177)],
#  32: [('fault', 0.15772231440960865),
#   ('sit', 0.10558915216519008),
#   ('find', 0.08373575200250508),
#   ('opposition', 0.07131254327054115),
#   ('parliament', 0.06647659405468428),
#   ('defects', 0.0647244272364349),
#   ('could', 0.06279631143527772),
#   ('refused', 0.06120101823621126),
#   ('vital', 0.055019478783095724),
#   ('considered', 0.048483490265216506),
#   ('last', 0.04506365705564103),
#   ('blemish', 0.04367702322068228),
#   ('house', 0.04314402028538353),
#   ('able', 0.042123589744088134),
#   ('demerits', 0.04172805858701945)],
#  33: [('carnarvon', 0.2484018887038451),
#   ('lord', 0.20125585009776512),
#   ('interview', 0.10665294405133399),
#   ('salisbury', 0.0816828372182256),
#   ('gray', 0.05181453802088172),
#   ('matter', 0.03469869232382397),
#   ('admits', 0.03267618201631542),
#   ('contradicted', 0.0313463769077393),
#   ('conversation', 0.0313463769077393),
#   ('letter', 0.02866098643887988),
#   ('immediately', 0.027227612406075203),
#   ('took', 0.027081227504006593),
#   ('interviews', 0.025688947789143803),
#   ('private', 0.02567557852208288),
#   ('held', 0.02529622716361922)],
#  34: [('confidence', 0.12841040860714173),
#   ('trust', 0.0564369301293836),
#   ('day', 0.053792574556917064),
#   ('confident', 0.051409491944217706),
#   ('feel', 0.0452200491080075),
#   ('occupy', 0.04452500748568692),
#   ('supplemented', 0.04252256445714002),
#   ('telegrams', 0.04252256445714002),
#   ('unabated', 0.04252256445714002),
#   ('shows', 0.040509026290986454),
#   ('gathered', 0.039154128268304646),
#   ('untouched', 0.037952889206273356),
#   ('crooked', 0.03693779943002018),
#   ('adhesion', 0.036058958568665256),
#   ('higher', 0.0359766238591415)],
#  35: [('bill', 0.12941759692919586),
#   ('objections', 0.04268233403399886),
#   ('first', 0.040856749499122554),
#   ('order', 0.04068464677576213),
#   ('reading', 0.037360863757164076),
#   ('third', 0.036881817891136086),
#   ('portion', 0.034683856981493906),
#   ('committee', 0.0339576630407978),
#   ('reassembling', 0.03261020990463103),
#   ('mcaleese', 0.031155070769362497),
#   ('clause', 0.031134053130970063),
#   ('entirely', 0.03063524174593799),
#   ('criticism', 0.027653322956375043),
#   ('provisions', 0.02490724250477605),
#   ('report', 0.024771450408244456)],
#  36: [('ulster', 0.18803370066101155),
#   ('protestants', 0.13208592046207557),
#   ('province', 0.04900649207954478),
#   ('protestant', 0.04515984192842996),
#   ('north', 0.04387453015423603),
#   ('connaught', 0.036892586383890945),
#   ('corner', 0.034950530830929215),
#   ('munster', 0.031855040224700586),
#   ('leinster', 0.03127830052922822),
#   ('counties', 0.02927639576005089),
#   ('comes', 0.029126073439916474),
#   ('wealth', 0.029014398416332885),
#   ('notwithstanding', 0.028648716700284536),
#   ('disproportion', 0.027748525869759098),
#   ('twelfths', 0.027748525869759098)],
#  37: [('famine', 0.23470711691729812),
#   ('famines', 0.06676422247440492),
#   ('peasantry', 0.04853693436520592),
#   ('starve', 0.04853693436520592),
#   ('cold', 0.04853693436520592),
#   ('western', 0.040834141851068574),
#   ('suppose', 0.039461839280850314),
#   ('death', 0.03885443225938277),
#   ('lingering', 0.03853527677124292),
#   ('torture', 0.03853527677124292),
#   ('peasants', 0.03853527677124292),
#   ('devastated', 0.03853527677124292),
#   ('world', 0.03652118432778714),
#   ('successive', 0.03625397983763675),
#   ('productive', 0.03463624769100958)],
#  38: [('gained', 0.0637228474008745),
#   ('remarkable', 0.06168061157993629),
#   ('ambition', 0.06085096925618178),
#   ('struggle', 0.05903748677345864),
#   ('strides', 0.057590750423082225),
#   ('worker', 0.05254644414661709),
#   ('completed', 0.04777709669865859),
#   ('personal', 0.04585498367945605),
#   ('fact', 0.04442275630526421),
#   ('great', 0.04345438452660866),
#   ('nation', 0.04236001123555573),
#   ('progress', 0.0420087964752918),
#   ('movement', 0.04138633266943769),
#   ('calculated', 0.0412994881969497),
#   ('march', 0.040238795821197375)],
#  39: [('opinion', 0.12765517438243626),
#   ('public', 0.12506872322554446),
#   ('english', 0.09570161649046113),
#   ('newspapers', 0.04453050347725871),
#   ('sentiment', 0.044038850090213646),
#   ('press', 0.04368421038046334),
#   ('regard', 0.03884020835862108),
#   ('classes', 0.037672224139808044),
#   ('actions', 0.03733705123706904),
#   ('england', 0.03603020133794132),
#   ('freedom', 0.03215884185334273),
#   ('cared', 0.031162621894336672),
#   ('movement', 0.02931114359760417),
#   ('cultivating', 0.02869406655982294),
#   ('bodies', 0.023399710019579252)],
#  40: [('county', 0.16196334479351085),
#   ('counties', 0.07095002933141546),
#   ('unanimously', 0.0516603874609771),
#   ('mayo', 0.043698881326792144),
#   ('rest', 0.03916475447699271),
#   ('town', 0.037154291184375236),
#   ('adopted', 0.03670666842657124),
#   ('corbet', 0.03453895486041685),
#   ('candidature', 0.03366836950799934),
#   ('mccoan', 0.03328834126181706),
#   ('meeting', 0.033124046432769075),
#   ('consulted', 0.03226706310795525),
#   ('neighbouring', 0.03140404670642165),
#   ('shopkeeper', 0.02999816040578624),
#   ('nally', 0.02940924125613743)],
#  41: [('dillon', 0.29826136332685976),
#   ('john', 0.09812260876585745),
#   ('friend', 0.07211667760062535),
#   ('davis', 0.0405935408124369),
#   ('cousin', 0.0405935408124369),
#   ('strongbow', 0.0405935408124369),
#   ('valentine', 0.0405935408124369),
#   ('duffy', 0.03819039419098233),
#   ('daughter', 0.03648625498607833),
#   ('tipperary', 0.035081254920241126),
#   ('alderman', 0.03408627438110406),
#   ('france', 0.03408627438110406),
#   ('america', 0.030918983065232046),
#   ('name', 0.03060198185039143),
#   ('solicitor', 0.03050485096124533)],
#  42: [('countrymen', 0.2200701640851627),
#   ('fellow', 0.1367285232005013),
#   ('exiled', 0.062181923880869246),
#   ('america', 0.059202825528313636),
#   ('country', 0.054831014620893695),
#   ('contributions', 0.04672788533608943),
#   ('prosperous', 0.04334575278561246),
#   ('citizens', 0.04089773553620021),
#   ('loss', 0.039698247621004656),
#   ('wishes', 0.038980196483525825),
#   ('personal', 0.03657977107156607),
#   ('american', 0.036321028923781105),
#   ('gives', 0.03558773752576741),
#   ('distinguished', 0.03558773752576741),
#   ('enormous', 0.034487803684973756)],
#  43: [('father', 0.31372526729420047),
#   ('murphy', 0.27873237691343694),
#   ('noise', 0.20033783451404646),
#   ('barry', 0.15874716058603588),
#   ('john', 0.10553399730029986),
#   ('dunne', 0.10268746948692323),
#   ('speak', 0.08489410560367866),
#   ('interruptions', 0.06540355282078936),
#   ('shouting', 0.0630353696234408),
#   ('ogorman', 0.06110145992783015),
#   ('listen', 0.055689839825451726),
#   ('dan', 0.053761578187504946),
#   ('nicholas', 0.052915720195345295),
#   ('sixteen', 0.05140468211747994),
#   ('crowd', 0.050084458628511616)],
#  44: [('valuation', 0.2643097538961331),
#   ('griffith', 0.17016647389446116),
#   ('production', 0.10722234040622391),
#   ('cost', 0.07762313444245968),
#   ('produce', 0.0708247050943701),
#   ('higher', 0.0655959326588363),
#   ('joseph', 0.053118528820777576),
#   ('showing', 0.05212667379209185),
#   ('holdings', 0.052068355166122224),
#   ('schedule', 0.05168740097333753),
#   ('agriculture', 0.04759296983617218),
#   ('lands', 0.04655912230706606),
#   ('mixed', 0.044898958343317696),
#   ('value', 0.04417077904120698),
#   ('account', 0.043933659489367456)],
#  45: [('cries', 0.35934644927159676),
#   ('no', 0.19905005734751266),
#   ('never', 0.12922904183397835),
#   ('lie', 0.08081411536300628),
#   ('shame', 0.07401368200526293),
#   ('loud', 0.06560761110397909),
#   ('yourself', 0.063835793379566),
#   ('stranger', 0.063835793379566),
#   ('rescued', 0.063835793379566),
#   ('tire', 0.063835793379566),
#   ('noes', 0.063835793379566),
#   ('lamb', 0.05796620022792896),
#   ('believer', 0.05796620022792896),
#   ('flinch', 0.05796620022792896),
#   ('pity', 0.05796620022792896)],
#  46: [('gentlemen', 0.24472731987866586),
#   ('ladies', 0.10682588012050269),
#   ('men', 0.10063931802965399),
#   ('occurrences', 0.08944404158629142),
#   ('terrible', 0.07459769216533314),
#   ('franchise', 0.06974857172932895),
#   ('unreserved', 0.06666038600698043),
#   ('cyphers', 0.06666038600698043),
#   ('situation', 0.06524375027799745),
#   ('reliable', 0.060531076344209005),
#   ('unpleasant', 0.05440649526685132),
#   ('quantity', 0.05440649526685132),
#   ('estimable', 0.05440649526685132),
#   ('must', 0.05335176753760502),
#   ('maryborough', 0.05243650216463218)],
#  47: [('manifesto', 0.16061819727119125),
#   ('gladstone', 0.12122179725042076),
#   ('mccarthy', 0.11406125901322052),
#   ('statements', 0.08579651561943845),
#   ('communicated', 0.06601766934731074),
#   ('outline', 0.0514015661033844),
#   ('intended', 0.047293893961893416),
#   ('retention', 0.04384397982912525),
#   ('blank', 0.04239954458727034),
#   ('justin', 0.040944923348443164),
#   ('controversy', 0.03961060160838644),
#   ('features', 0.037633947563618445),
#   ('issued', 0.03430398412663764),
#   ('colleagues', 0.033009549898572),
#   ('letter', 0.033009549898572)],
#  48: [('davitt', 0.2823278562609381),
#   ('michael', 0.17677078645368446),
#   ('arrest', 0.05099927473574462),
#   ('egan', 0.049903481796541596),
#   ('disgrace', 0.049903481796541596),
#   ('founder', 0.04261689487162378),
#   ('portland', 0.04261689487162378),
#   ('north', 0.03850492811043767),
#   ('gospel', 0.036917911181329824),
#   ('endorse', 0.034828163948554855),
#   ('clergyman', 0.034828163948554855),
#   ('preached', 0.034828163948554855),
#   ('letter', 0.03354942571467014),
#   ('request', 0.03202534197488995),
#   ('declaring', 0.03148653177336738)],
#  49: [('healy', 0.27999331817787804),
#   ('tim', 0.1270436434941603),
#   ('timothy', 0.12135619436886252),
#   ('tom', 0.11178061754825816),
#   ('sexton', 0.10571162140877152),
#   ('groans', 0.0479377107308482),
#   ('leave', 0.043692046503803574),
#   ('easy', 0.038980196483525825),
#   ('often', 0.038316087339466565),
#   ('pass', 0.03657977107156607),
#   ('gleeson', 0.034239198267221764),
#   ('judas', 0.034239198267221764),
#   ('shannon', 0.034239198267221764),
#   ('scurrilous', 0.034239198267221764),
#   ('micawber', 0.034239198267221764)],
#  50: [('forster', 0.24500080848075356),
#   ('boycotting', 0.08974019903301365),
#   ('buckshot', 0.07000716428122532),
#   ('intimidation', 0.05522331564620703),
#   ('groans', 0.05273148180393303),
#   ('desirable', 0.0519658431064521),
#   ('simply', 0.044738870032393324),
#   ('sanction', 0.04331647156821827),
#   ('bottle', 0.039085780725117814),
#   ('gentleness', 0.039085780725117814),
#   ('dinned', 0.039085780725117814),
#   ('holder', 0.039085780725117814),
#   ('assistant', 0.039085780725117814),
#   ('hisses', 0.037335925599598176),
#   ('landlords', 0.03705225913936395)],
#  51: [('resolution', 0.4903023738473613),
#   ('move', 0.18984944253003863),
#   ('second', 0.15499566550644606),
#   ('call', 0.11162735931482139),
#   ('subsequent', 0.10001023468746473),
#   ('resolutions', 0.07837222010824334),
#   ('though', 0.07742160010912474),
#   ('tormey', 0.0768635063141713),
#   ('td', 0.0768635063141713),
#   ('separately', 0.06979603700913894),
#   ('adopted', 0.06667129571356817),
#   ('fond', 0.06566409613449513),
#   ('brennan', 0.06566409613449513),
#   ('keegan', 0.06566409613449513),
#   ('lydon', 0.06273402005259386)],
#  52: [('workingmen', 0.09337799837576166),
#   ('industries', 0.07664869413172032),
#   ('classes', 0.04477303185536899),
#   ('britain', 0.044446078780609605),
#   ('working', 0.04400576749489929),
#   ('fair', 0.04168835696459427),
#   ('countries', 0.03780138419862912),
#   ('future', 0.03435222329022417),
#   ('labour', 0.032974797389550475),
#   ('loss', 0.03141587941230584),
#   ('great', 0.03048059346290895),
#   ('nations', 0.027801490298463908),
#   ('wear', 0.027546941166503757),
#   ('hear', 0.027195025689837907),
#   ('article', 0.02510716999324922)],
#  53: [('wish', 0.4398227808988343),
#   ('detain', 0.3353310807884803),
#   ('speak', 0.14346149980666598),
#   ('length', 0.12865163613850716),
#   ('stretch', 0.07230428563124183),
#   ('propose', 0.07173074990333299),
#   ('conferring', 0.06657668252363412),
#   ('explanation', 0.0628080934128433),
#   ('dont', 0.06255518117631732),
#   ('ends', 0.06131373479465927),
#   ('reserve', 0.05881848251227486),
#   ('sitting', 0.05775356614572851),
#   ('delay', 0.056781891568825446),
#   ('places', 0.053573402319296304),
#   ('rendered', 0.0516603874609771)],
#  54: [('electors', 0.2656434316151677),
#   ('mallow', 0.06850400637143375),
#   ('consistent', 0.0547658723305636),
#   ('ascertain', 0.05271863986635731),
#   ('byrne', 0.051831675380774),
#   ('wicklow', 0.046636013044251884),
#   ('assured', 0.045218850175636295),
#   ('candidature', 0.04097757109349663),
#   ('plumping', 0.03862883907071173),
#   ('mccann', 0.03862883907071173),
#   ('sweat', 0.03862883907071173),
#   ('courageously', 0.03862883907071173),
#   ('wasting', 0.03862883907071173),
#   ('foley', 0.03862883907071173),
#   ('redeem', 0.03862883907071173)],
#  55: [('oshea', 0.2650091107941701),
#   ('candidature', 0.24415802776541742),
#   ('unfair', 0.1779890850743317),
#   ('step', 0.14556024127701708),
#   ('regard', 0.11457861465793218),
#   ('voted', 0.11356367330229475),
#   ('withdrawing', 0.10725135701967538),
#   ('examining', 0.10246556608590332),
#   ('temper', 0.10246556608590332),
#   ('exhibited', 0.08566778978283063),
#   ('admire', 0.08422647249375775),
#   ('record', 0.07846565185133487),
#   ('public', 0.07485997491615921),
#   ('equally', 0.07421267356905323),
#   ('merits', 0.07210856541239372)],
#  56: [('shaw', 0.31592367219701784),
#   ('leader', 0.28470484066340823),
#   ('chairman', 0.2097944949676479),
#   ('voted', 0.2071769715649972),
#   ('proposed', 0.14822776738769627),
#   ('attained', 0.12010793401223183),
#   ('party', 0.08605933296262497),
#   ('william', 0.07988096559541391),
#   ('fear', 0.07099131559815132),
#   ('member', 0.07040336008772433),
#   ('done', 0.06324499526905653),
#   ('things', 0.05944952402037279),
#   ('also', 0.05942308567961659),
#   ('groans', 0.05344406939587807),
#   ('synan', 0.050896105532356684)],
#  57: [('ejectments', 0.31653195122945404),
#   ('suspension', 0.13422679342544774),
#   ('suspending', 0.10052310768586199),
#   ('bill', 0.07857971013547072),
#   ('two', 0.07714724869083646),
#   ('quarter', 0.07073499206195326),
#   ('years', 0.06730559798771822),
#   ('suspend', 0.06077256148311217),
#   ('february', 0.06077256148311217),
#   ('suspended', 0.0559684348382018),
#   ('drafted', 0.0536907173701791),
#   ('session', 0.051733123948034976),
#   ('ejectment', 0.048902900578639705),
#   ('pending', 0.045218850175636295),
#   ('commenced', 0.04437450179224229)],
#  58: [('desire', 0.3320106730314833),
#   ('sentiments', 0.1485000454450234),
#   ('compulsion', 0.11292768310592029),
#   ('sentiment', 0.0918588135720113),
#   ('feelings', 0.0890674321641321),
#   ('enabled', 0.08587089712609484),
#   ('real', 0.07908386116837204),
#   ('prejudge', 0.07608710726049282),
#   ('express', 0.0728952682308338),
#   ('destiny', 0.06909102653429917),
#   ('consistently', 0.06909102653429917),
#   ('also', 0.06662588394381254),
#   ('entreat', 0.06500082243616691),
#   ('versus', 0.06500082243616691),
#   ('first', 0.06107877702899129)],
#  59: [('millions', 0.09570937716709853),
#   ('hundred', 0.09215364547401894),
#   ('amount', 0.09107471912164437),
#   ('sterling', 0.0721094803909829),
#   ('rental', 0.07006500282985625),
#   ('money', 0.06689176188007755),
#   ('sum', 0.06298300304590285),
#   ('ascertain', 0.062429968262791555),
#   ('seventeen', 0.05868874638513905),
#   ('thousand', 0.05755122921939703),
#   ('small', 0.05650538935467036),
#   ('fifty', 0.05649366002412081),
#   ('year', 0.05501215408732853),
#   ('pounds', 0.0546406992993768),
#   ('capability', 0.052105922438708686)]}

# %%
model_publication.visualize_topics()
# Out:
# <div>                            <div id="daabd2dd-3d5b-49a5-9432-f96b2208d7a8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daabd2dd-3d5b-49a5-9432-f96b2208d7a8")) {                    Plotly.newPlot(                        "daabd2dd-3d5b-49a5-9432-f96b2208d7a8",                        [{"customdata":[[0,"irishmen | cheers | thank | loud | mayor",524],[1,"parliament | english | gladstone | party | election",413],[2,"tenant | tenants | rent | landlords | farmers",320],[3,"voice | enniscorthy | groans | another | thanks",145],[4,"league | national | land | organisation | movement",137],[5,"prison | harrington | prisoners | condon | imprisonment",127],[6,"resolution | chairman | reading | convention | resolutions",91],[7,"constabulary | police | control | force | imperial",79],[8,"cork | city | constituency | tory | return",74],[9,"question | land | settled | constitutional | settlement",73],[10,"labourers | artisans | labourer | act | farmers",68],[11,"dickson | rylett | thomas | harold | knox",57],[12,"hon | gentleman | right | member | birmingham",56],[13,"meath | county | priests | parish | feel",53],[14,"tories | whigs | whig | tory | dan",52],[15,"hear | heard | seldom | lecture | kelly",50],[16,"rule | home | hartlepool | repeal | lose",48],[17,"history | future | closed | past | promising",48],[18,"emigration | emigrants | emigrate | emigrated | population",47],[19,"negotiations | injury | promise | cannot | satisfactory",45],[20,"lynch | oshea | galway | poll | morrow",44],[21,"bill | land | principle | act | measure",44],[22,"coercion | act | government | living | thing",43],[23,"position | difficulties | struggle | contentions | avoid",43],[24,"soil | produce | acres | lands | land",39],[25,"reason | want | contrary | live | girls",38],[26,"feudal | prussia | system | tenure | serfs",37],[27,"money | sum | spent | salaries | pay",37],[28,"sir | quite | less | offensive | well",36],[29,"settlement | settled | eventually | settle | question",34],[30,"bishops | education | catholic | religious | political",34],[31,"matter | attach | let | plain | another",33],[32,"fault | sit | find | opposition | parliament",33],[33,"carnarvon | lord | interview | salisbury | gray",32],[34,"confidence | trust | day | confident | feel",31],[35,"bill | objections | first | order | reading",31],[36,"ulster | protestants | province | protestant | north",31],[37,"famine | famines | peasantry | starve | cold",30],[38,"gained | remarkable | ambition | struggle | strides",30],[39,"opinion | public | english | newspapers | sentiment",25],[40,"county | counties | unanimously | mayo | rest",25],[41,"dillon | john | friend | davis | cousin",23],[42,"countrymen | fellow | exiled | america | country",23],[43,"father | murphy | noise | barry | john",22],[44,"valuation | griffith | production | cost | produce",22],[45,"cries | no | never | lie | shame",21],[46,"gentlemen | ladies | men | occurrences | terrible",20],[47,"manifesto | gladstone | mccarthy | statements | communicated",19],[48,"davitt | michael | arrest | egan | disgrace",19],[49,"healy | tim | timothy | tom | sexton",19],[50,"forster | boycotting | buckshot | intimidation | groans",19],[51,"resolution | move | second | call | subsequent",18],[52,"workingmen | industries | classes | britain | working",18],[53,"wish | detain | speak | length | stretch",17],[54,"electors | mallow | consistent | ascertain | byrne",17],[55,"oshea | candidature | unfair | step | regard",17],[56,"shaw | leader | chairman | voted | proposed",17],[57,"ejectments | suspension | suspending | bill | two",16],[58,"desire | sentiments | compulsion | sentiment | feelings",16],[59,"millions | hundred | amount | sterling | rental",15]],"hovertemplate":"\u003cb\u003eTopic %{customdata[ ...

# %%
model_publication.visualize_hierarchy()
# Out:
# <div>                            <div id="6209db6e-8d87-416f-86f7-429b8fe6feb1" class="plotly-graph-div" style="height:1100px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6209db6e-8d87-416f-86f7-429b8fe6feb1")) {                    Plotly.newPlot(                        "6209db6e-8d87-416f-86f7-429b8fe6feb1",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6423923077564668,0.6423923077564668,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8832914666930103,0.8832914666930103,0.6423923077564668],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6296009043830701,0.6296009043830701,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8832914666930103,1.032248151569435,1.032248151569435,0.6296009043830701],"xaxis":"x","y":[-12.5,-12.5,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8857790010722995,0.8857790010722995,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.8857790010722995,0.9546588747171181,0.9546588747171181,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9615043052396341,0.9615043052396341,0.9546588747171181],"xaxis":"x","y":[-55.0,-55.0,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9124505188777327,0.9124505188777327,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9615043052396341,1.0087666958676094,1.0087666958676094,0.9124505188777327],"xaxis":"x","y":[-66.25,-66.25,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9455243298098022,0.9455243298098022,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9061549753861411,0.9061549753861411,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.9061549753861411,0.945978208046869,0.945978208046869,0.0],"xaxis":"x","y":[-140.0,-140.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9455243298098022,1.0206019981405987,1.0206019981405987,0.945978208046869],"xaxis":"x","y":[-120.0,-120.0,-147.5,-147.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.834460843043181,0.834460843043181,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8879734684202016,0.8879734684202016,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9112603388711277,0.9112603388711277,0.8879734684202016],"xaxis":"x","y":[-185.0,-185.0,-200.0,-200.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.9112603388711277,0.9599228575844553,0.9599228575844553,0.0],"xaxis":"x" ...

# %%
model_publication_time = bertopic_time(df_publication, model_publication)
model_publication_time
# Out:
# <div>                            <div id="7c53ad6c-711b-4b91-88a8-97e84b453c8b" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c53ad6c-711b-4b91-88a8-97e84b453c8b")) {                    Plotly.newPlot(                        "7c53ad6c-711b-4b91-88a8-97e84b453c8b",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hailed, oleary, succession, meldon, advocacy","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: banners, arches, bands, roads, rathdrum","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheering, address, irishmen, oconnell, listen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: dundalk, misunderstood, laugher, rose, rejection","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: god, thank, inspiring, gratifying, see","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, voice, irishmen, thank, loud","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, voice, variety, intentions, promises","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, cheers, meeting, scotchmen, gentlemen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: conference, chair, address, moving, desires","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mayor, lord, lordship, irishmen, pleasure","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, mayor, toast, health, abroad","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, cheers, charleville, convinced, true","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, loud, cheers, legislative, discretion","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, nation, moderation, received, irishmen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: corner, experiment, cheers, irishmen, battle","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hospitality, cheers, stronger, ladies, thank","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, platform, without, empire, danger","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: honouring, electing, entering, thanked, exceedingly","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, britain, help, movement, great","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, irishmen, thank, loud, men"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_irishmen_cheers_thank_loud","x":["1874-07-04T21:34:33.600000","1875-01-30T08:48:00","1875-08-21T17:36:00","1876-03-12T02:24:00","1879-07-15T07:12:00","1880-02-03T16:00:00","1880-08-25T00:48:00","1881-03-16T09:36:00","1882-04-27T03:12:00","1883-06-07T20:48:00","1883-12-28T05:36:00","1884-07-18T14:24:00","1885-02-06T23:12:00","1885-08-29T08:00:00","1886-03-20T16:48:00","1887-11-20T19:12:00","1888-12-31T12:48:00","1889-07-22T21:36:00","1890-02-11T06:24:00","1890-09-02T15:12:00"],"y":[3,5,13,2,11,107,13,46,10,19,10,38,15,37,11,9,3,1,11,160],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: vainly, emancipation, contended, oconnell, reserved","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: colonies, weakness, demand, england, bear","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: england, parliament, ministers, government, english","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: humiliation, sensitive, manifestly, tending, particularly","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: enters, domain, amelioration, forcibly, drawn","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: constituency, constituencies, parliament, engl ...

# %% [markdown]
# ### <font color="blue">Place</font>

# %% [markdown]
# <font color="blue">Set place keywords or phrases in first cell and then run cells underneath sequentially to get results and visualisations. Error messages can occur if the format of the place_words list is incorrect or if not enough data for model.</font>
#
# <font color="blue">Experiment with different place searches. Can use a series of place names to get more than one place</font>

# %%
place_words = ['london']
#use function to restrict dataframe to rows where place name contains any of place_words
df_place = dataframe_keyword_any(df_stop, column='place', keywords=place_words)
df_place
# Out:
#                  filename     speech_id                      publication  \
# 16   parnell_source_00017  speech_00005  hansard's parliamentary debates
# 16   parnell_source_00017  speech_00005  hansard's parliamentary debates
# 16   parnell_source_00017  speech_00005  hansard's parliamentary debates
# 16   parnell_source_00017  speech_00005  hansard's parliamentary debates
# 16   parnell_source_00017  speech_00005  hansard's parliamentary debates
# ..                    ...           ...                              ...
# 639  parnell_source_00643  speech_00382            the freeman's journal
# 639  parnell_source_00643  speech_00382            the freeman's journal
# 639  parnell_source_00643  speech_00382            the freeman's journal
# 639  parnell_source_00643  speech_00382            the freeman's journal
# 639  parnell_source_00643  speech_00382            the freeman's journal
#
#                                               sentence            place  \
# 16   supporting motion hon member cavan observed ar...  london, england
# 16   hon member derry r smyth although agreed princ...  london, england
# 16   chief secretary open foe course opposed also n...  london, england
# 16   reason hon member derry given approving princi...  london, england
# 16   coercion necessary district prevent catholics ...  london, england
# ..                                                 ...              ...
# 639  entered lengthy contrast policies governments ...  london, england
# 639    view apprehension accession conservatives power  london, england
# 639  view general election might occur moment advis...  london, england
# 639        land league change one single inch platform  london, england
# 639  felt confident could carry entirety asked peop...  london, england
#
#           date
# 16  1875-04-26
# 16  1875-04-26
# 16  1875-04-26
# 16  1875-04-26
# 16  1875-04-26
# ..         ...
# 639 1881-06-22
# 639 1881-06-22
# 639 1881-06-22
# 639 1881-06-22
# 639 1881-06-22
#
# [9325 rows x 6 columns]

# %%
topics_place = bertopic_topics(df_place, topic_model)
model_place = topics_place[2]

# %%
model_place.get_topics()
# Out:
# {-1: [('government', 0.009930230745380688),
#   ('hon', 0.009828502645045391),
#   ('bill', 0.009118582707266825),
#   ('house', 0.008645000990781722),
#   ('right', 0.008428682420456255),
#   ('gentleman', 0.008172711491207123),
#   ('could', 0.008057167797414557),
#   ('people', 0.007733899543180564),
#   ('member', 0.007137670044042689),
#   ('one', 0.007047263934926646),
#   ('members', 0.006904967756014047),
#   ('country', 0.006764423555422183),
#   ('time', 0.0064689966774007),
#   ('great', 0.006465014373836054),
#   ('question', 0.0063870693174196275)],
#  0: [('right', 0.013876069957524067),
#   ('gentleman', 0.013685747407151167),
#   ('hon', 0.01356847169376498),
#   ('secretary', 0.009954184100182905),
#   ('amendment', 0.00949336460390386),
#   ('question', 0.009303586622941493),
#   ('government', 0.009299027807815642),
#   ('order', 0.009068985348629537),
#   ('member', 0.008778966452336785),
#   ('chief', 0.008393263038370803),
#   ('parliament', 0.008345102542811431),
#   ('landlords', 0.008269262930130285),
#   ('tenants', 0.007997960760523224),
#   ('ulster', 0.007966630588449564),
#   ('prisoners', 0.007714175864486117)],
#  1: [('jury', 0.05946453184703929),
#   ('evidence', 0.036371481375212976),
#   ('person', 0.030465406719913764),
#   ('judges', 0.029116371977703615),
#   ('juries', 0.02902221626860347),
#   ('removal', 0.025476334135254502),
#   ('trial', 0.024904750115048658),
#   ('depositions', 0.02483473319639251),
#   ('witnesses', 0.02370947695953528),
#   ('cases', 0.019782656463904102),
#   ('case', 0.019762171799757103),
#   ('crown', 0.0190391972698924),
#   ('council', 0.018725336591407033),
#   ('jurors', 0.018547432657584604),
#   ('accused', 0.01826086494163598)],
#  2: [('sir', 0.09963355492937861),
#   ('results', 0.08359791513579286),
#   ('well', 0.07109556686573623),
#   ('denied', 0.06521477391493431),
#   ('reason', 0.06314175839184658),
#   ('facts', 0.062215155526064284),
#   ('stronger', 0.05912553919235745),
#   ('argument', 0.057238707552683225),
#   ('creeds', 0.05525812794891039),
#   ('another', 0.05266146171659034),
#   ('honest', 0.048745934716397),
#   ('obvious', 0.04628692198797699),
#   ('one', 0.0453714683116771),
#   ('truth', 0.04273899248331537),
#   ('phraseology', 0.04259078965936857)],
#  3: [('wealth', 0.07210978225501762),
#   ('relative', 0.06333317416799046),
#   ('ulster', 0.06292435050748199),
#   ('counties', 0.05894642218412307),
#   ('munster', 0.054650011920046815),
#   ('budget', 0.0526589719524567),
#   ('leinster', 0.051920825336391495),
#   ('pay', 0.04362814040604762),
#   ('provinces', 0.04338417443567528),
#   ('eastern', 0.03946858414900497),
#   ('standard', 0.03922177531152214),
#   ('connaught', 0.03801678212501899),
#   ('income', 0.03664961956642576),
#   ('tax', 0.03408756562803057),
#   ('arrived', 0.03370391346085921)],
#  4: [('letters', 0.1166184411715219),
#   ('letter', 0.06956499824521797),
#   ('forged', 0.06327040472938632),
#   ('signature', 0.05933879632199624),
#   ('times', 0.03533614497053191),
#   ('handwriting', 0.03070664525350499),
#   ('evidence', 0.020781361025345505),
#   ('threatening', 0.02066651509738485),
#   ('authenticity', 0.02047109683566999),
#   ('production', 0.019917158460705277),
#   ('learned', 0.0190613536841265),
#   ('commission', 0.018766428894967897),
#   ('forgeries', 0.01863685871934385),
#   ('published', 0.01829514468206166),
#   ('write', 0.01769671318566478)],
#  5: [('coercion', 0.17926816415208185),
#   ('drastic', 0.04586852651848878),
#   ('bill', 0.039191316805277966),
#   ('never', 0.01843684508863867),
#   ('arrears', 0.017875993497884757),
#   ('passage', 0.01707024974744473),
#   ('little', 0.01700842831415393),
#   ('heard', 0.016640979951239587),
#   ('severer', 0.016480698071093907),
#   ('abstaining', 0.016480698071093907),
#   ('pitifully', 0.016480698071093907),
#   ('intentioned', 0.016480698071093907),
#   ('precede', 0.016480698071093907),
#   ('severe', 0.016443315077257457),
#   ('remedial', 0.016443315077257457)],
#  6: [('league', 0.2021890945082627),
#   ('land', 0.10090514283047372),
#   ('national', 0.08543029996096918),
#   ('organisation', 0.05488632750514602),
#   ('movement', 0.049169430345036534),
#   ('branch', 0.024655345380530456),
#   ('page', 0.02120923762586127),
#   ('inquiry', 0.01615317903139588),
#   ('act', 0.015247674256527375),
#   ('anything', 0.015042994945383898),
#   ('shape', 0.014983290048103984),
#   ('says', 0.014983290048103984),
#   ('suppressed', 0.014793207228318273),
#   ('attorney', 0.014645840292102754),
#   ('odonnell', 0.014571481654160391)],
#  7: [('piers', 0.10197849114267109),
#   ('fishery', 0.08995753810257709),
#   ('harbours', 0.07973451343233327),
#   ('fishermen', 0.07815659531427196),
#   ('coast', 0.0517959268957842),
#   ('fisheries', 0.04744783360824685),
#   ('work', 0.03445882175904945),
#   ('grant', 0.03287584974463357),
#   ('commissioners', 0.031590834477136315),
#   ('west', 0.028389255726183737),
#   ('cornish', 0.026893303776788346),
#   ('silting', 0.026893303776788346),
#   ('act', 0.02646990650318182),
#   ('mentioned', 0.022418339156130795),
#   ('vanguard', 0.022332169678955335)],
#  8: [('adjournment', 0.23177681272295023),
#   ('debate', 0.2140434307090754),
#   ('moved', 0.10315208540142301),
#   ('motion', 0.09303867216018737),
#   ('adjourned', 0.08850687203089458),
#   ('butt', 0.07301418596605445),
#   ('met', 0.058456225985249674),
#   ('interruptions', 0.04251733120170809),
#   ('agreed', 0.04106734027395392),
#   ('press', 0.037886712207494136),
#   ('amid', 0.037589353401462314),
#   ('appealed', 0.035342066769331326),
#   ('withdraw', 0.03218773002924947),
#   ('oconnor', 0.03144910664053784),
#   ('petulantly', 0.026713749727177917)],
#  9: [('cheers', 0.10224936093165046),
#   ('loud', 0.06553141266274227),
#   ('thank', 0.06130372474606289),
#   ('chairman', 0.05648760070762963),
#   ('honour', 0.052001145388999075),
#   ('received', 0.04214815411490017),
#   ('electing', 0.03774926692568743),
#   ('rising', 0.03715794755567128),
#   ('renewed', 0.03581291069748165),
#   ('thanked', 0.03472744009437451),
#   ('inviting', 0.03472744009437451),
#   ('also', 0.032555553981691285),
#   ('pleasure', 0.03125608285129455),
#   ('toast', 0.030634796916628945),
#   ('reception', 0.030634796916628945)],
#  10: [('bill', 0.15411337413723897),
#   ('nevertheless', 0.04243363566784646),
#   ('predecessors', 0.03863317898209103),
#   ('blots', 0.0380541318789753),
#   ('remove', 0.03653876979874007),
#   ('repairing', 0.0355482181408903),
#   ('allows', 0.0355482181408903),
#   ('provisions', 0.033475633228155506),
#   ('interpreted', 0.0334227980129446),
#   ('errors', 0.0334227980129446),
#   ('size', 0.0334227980129446),
#   ('committee', 0.03275501454721397),
#   ('cumbrous', 0.030747304790469825),
#   ('appropriation', 0.02898704558126267),
#   ('relieve', 0.026172635823659116)],
#  11: [('carnarvon', 0.17789156920338325),
#   ('lord', 0.12057798084672007),
#   ('interview', 0.07938823783114143),
#   ('salisbury', 0.07235379921508103),
#   ('gray', 0.06450294323780241),
#   ('crossmaglen', 0.04217487446068012),
#   ('hear', 0.037401758086169),
#   ('prisoners', 0.03373078498002729),
#   ('conversation', 0.028036649889860345),
#   ('says', 0.02555721188205165),
#   ('case', 0.025535383064015555),
#   ('private', 0.023503614149072764),
#   ('dinner', 0.023187789088464437),
#   ('letter', 0.02204216658684192),
#   ('barbavilla', 0.021829861787883247)],
#  12: [('labourers', 0.1385191681103715),
#   ('labourer', 0.08415018282794924),
#   ('farmers', 0.06120890998542302),
#   ('independent', 0.048831404507627824),
#   ('labour', 0.045879655045707374),
#   ('land', 0.04137885409976667),
#   ('sanitary', 0.04040775256818214),
#   ('houses', 0.03662355338072087),
#   ('regarded', 0.03164307221716511),
#   ('authorities', 0.03088852893550459),
#   ('little', 0.029958614614140438),
#   ('commission', 0.027110685598592355),
#   ('agricultural', 0.026938501712121424),
#   ('building', 0.025176438525367197),
#   ('purpose', 0.023594423422198415)],
#  13: [('whiskey', 0.10966010779380163),
#   ('revenue', 0.08533398546067927),
#   ('duties', 0.08214568644388014),
#   ('customs', 0.08043611804291112),
#   ('tobacco', 0.07817048532432803),
#   ('collecting', 0.07542945725275434),
#   ('giving', 0.07455760249732603),
#   ('whisky', 0.07178023262975058),
#   ('fourths', 0.07111165455056606),
#   ('custom', 0.06568145622376016),
#   ('eighths', 0.06522325845466265),
#   ('anticipate', 0.06034356580220347),
#   ('control', 0.05811970677518768),
#   ('separate', 0.05673319429883625),
#   ('deprive', 0.054830053896900814)],
#  14: [('evictions', 0.18175391796575543),
#   ('eviction', 0.11228659906163863),
#   ('quarter', 0.06988401217530056),
#   ('evicted', 0.049655522850153726),
#   ('increasing', 0.04862047030814752),
#   ('agrarian', 0.04231926963944416),
#   ('month', 0.041726957957644084),
#   ('number', 0.04152754792931417),
#   ('thousands', 0.03948823928149345),
#   ('six', 0.03613950898347761),
#   ('persons', 0.03580242035582907),
#   ('year', 0.033228083172975716),
#   ('crime', 0.03154329941635557),
#   ('months', 0.027833956960206182),
#   ('families', 0.02734607567342915)],
#  15: [('kerry', 0.16069977241195887),
#   ('outrages', 0.08232109482174675),
#   ('occurrences', 0.07268761082556387),
#   ('denounce', 0.061239337243710605),
#   ('belfast', 0.05499761498595543),
#   ('stop', 0.05455925324056888),
#   ('rest', 0.047971182191696236),
#   ('outrage', 0.04014746081888794),
#   ('munster', 0.0365611775652243),
#   ('ulster', 0.03602875724752722),
#   ('lurid', 0.03471029074124149),
#   ('county', 0.034572309460052575),
#   ('soon', 0.032484666131893256),
#   ('allusion', 0.031240647748651942),
#   ('resort', 0.031240647748651942)],
#  16: [('militia', 0.10458833326677959),
#   ('commanding', 0.08804741848664775),
#   ('mass', 0.08120844705274256),
#   ('attend', 0.0682563601875091),
#   ('meath', 0.0647532551607447),
#   ('whether', 0.05974973878488541),
#   ('divine', 0.05827755941500266),
#   ('regiments', 0.05827755941500266),
#   ('behan', 0.05334871409755342),
#   ('war', 0.052337417523183716),
#   ('service', 0.052294166633389795),
#   ('27th', 0.051533717048135),
#   ('dillon', 0.049714540675767034),
#   ('holidays', 0.04648626273727921),
#   ('officers', 0.046255556036054205)],
#  17: [('faced', 0.17034293670125547),
#   ('risk', 0.15401978274384043),
#   ('fear', 0.13462281330958592),
#   ('danger', 0.12070317040700129),
#   ('otherwise', 0.11867555523608263),
#   ('personal', 0.08031922944698881),
#   ('allay', 0.06996750573039502),
#   ('physical', 0.06716238899047561),
#   ('victory', 0.06068167234319274),
#   ('disgrace', 0.05678097890041849),
#   ('small', 0.05111826869925437),
#   ('running', 0.05099366774109879),
#   ('operative', 0.049611249493330414),
#   ('blame', 0.04869652232575797),
#   ('post', 0.04770927754275327)],
#  18: [('member', 0.17440092162678744),
#   ('hon', 0.09391036456548688),
#   ('furnished', 0.0654878261271866),
#   ('life', 0.061565907337177976),
#   ('wrote', 0.0467687168853507),
#   ('misled', 0.043658550751457734),
#   ('dundalk', 0.041454397921665394),
#   ('information', 0.04127280604796801),
#   ('conveyed', 0.03901791433155073),
#   ('letter', 0.037090184160551314),
#   ('cross', 0.035695567418769156),
#   ('impression', 0.032763798994550654),
#   ('private', 0.031639480585290265),
#   ('unrepentant', 0.028709653210140493),
#   ('nest', 0.028709653210140493)],
#  19: [('intimidation', 0.24899827101729463),
#   ('person', 0.05153405192046571),
#   ('definition', 0.05138229877295167),
#   ('intimidated', 0.04596223223724095),
#   ('define', 0.04406881944510092),
#   ('law', 0.039745845006560365),
#   ('uses', 0.03889083067225324),
#   ('paragraphs', 0.02887819000358039),
#   ('impossible', 0.028678478036412564),
#   ('acts', 0.028495466589274626),
#   ('offence', 0.02764316306744252),
#   ('wife', 0.027151569387914486),
#   ('particular', 0.026530871776054298),
#   ('punishments', 0.025927220448168826),
#   ('act', 0.025878781893807653)],
#  20: [('exchequer', 0.2930800881275683),
#   ('chancellor', 0.18588950682307326),
#   ('imperial', 0.15314257341217052),
#   ('contribution', 0.11337726883541653),
#   ('expenditure', 0.07093509726968728),
#   ('tribute', 0.06812250078538476),
#   ('proposals', 0.04965135609685126),
#   ('question', 0.04860733103485967),
#   ('industries', 0.04528631705728152),
#   ('especially', 0.04340630107165756),
#   ('showed', 0.042551639877042226),
#   ('protect', 0.04055895330674493),
#   ('industry', 0.03899515768436966),
#   ('financial', 0.03723851707263844),
#   ('unfavorable', 0.0356697088037308)],
#  21: [('progress', 0.22835122488645432),
#   ('report', 0.16927435798372245),
#   ('chairman', 0.12148092392618344),
#   ('motion', 0.09855639476177996),
#   ('sit', 0.09791490629536055),
#   ('leave', 0.09618490944736657),
#   ('division', 0.06050095520523899),
#   ('move', 0.05313378474848583),
#   ('ask', 0.0489414576452835),
#   ('proposed', 0.044377735592812224),
#   ('question', 0.04011790436609792),
#   ('begged', 0.03713387871501172),
#   ('moved', 0.03572275088696821),
#   ('made', 0.03340751942305563),
#   ('reported', 0.03317679096249484)],
#  22: [('outrage', 0.09694699345470101),
#   ('outrages', 0.08254120470094928),
#   ('agitation', 0.07272374091908093),
#   ('publicly', 0.04196874683844328),
#   ('crime', 0.03518971898973899),
#   ('individuals', 0.0325446111018846),
#   ('ratio', 0.029582634154467182),
#   ('unprecedented', 0.02662555205851018),
#   ('evictions', 0.026219580061819472),
#   ('height', 0.02609630848453577),
#   ('terror', 0.02561782254091715),
#   ('reign', 0.02518124810306597),
#   ('agrarian', 0.023605698104156844),
#   ('unhappy', 0.023436483658787827),
#   ('endeavored', 0.022801129817641756)],
#  23: [('relief', 0.1304008123090188),
#   ('door', 0.11009112557311854),
#   ('boards', 0.10401772250562642),
#   ('poor', 0.06699199774287097),
#   ('machinery', 0.06664165717178515),
#   ('grant', 0.05652915848195677),
#   ('speedy', 0.052483022362179596),
#   ('grants', 0.05087236577505119),
#   ('law', 0.04578442426545182),
#   ('emergency', 0.040705471617894645),
#   ('assistance', 0.03638297913148967),
#   ('system', 0.03579237811736691),
#   ('operation', 0.031753391075675305),
#   ('aid', 0.03077494686179361),
#   ('save', 0.03077494686179361)],
#  24: [('regret', 0.13741613029220814),
#   ('wish', 0.08956157740665309),
#   ('regretted', 0.07416138170582644),
#   ('explanation', 0.05999372669092525),
#   ('hopes', 0.044320470173352076),
#   ('personal', 0.04079469700284269),
#   ('hope', 0.03849379302378624),
#   ('wished', 0.03655224981590101),
#   ('3½', 0.03471865039365827),
#   ('toils', 0.03471865039365827),
#   ('miss', 0.03471865039365827),
#   ('trod', 0.03471865039365827),
#   ('pain', 0.03471865039365827),
#   ('matrimony', 0.03471865039365827),
#   ('steadying', 0.03471865039365827)],
#  25: [('condon', 0.12572224555810815),
#   ('spike', 0.11437026319518336),
#   ('island', 0.11187223502046499),
#   ('handcuffed', 0.08945775385614627),
#   ('citizen', 0.08260074564096576),
#   ('foreign', 0.08206556181269328),
#   ('whether', 0.081930401392783),
#   ('edward', 0.07911046898949368),
#   ('chained', 0.07825472299315224),
#   ('omeagher', 0.07114065726650204),
#   ('american', 0.06590187924096737),
#   ('prisoner', 0.06351082683045327),
#   ('imprisonment', 0.06311747094175164),
#   ('clemency', 0.06046644297129314),
#   ('states', 0.06018141199597507)],
#  26: [('settlement', 0.24743597106938106),
#   ('final', 0.13246548771546757),
#   ('proposing', 0.10170082933537032),
#   ('drive', 0.09689974433343083),
#   ('rich', 0.09552783044882904),
#   ('equitable', 0.08898822566844904),
#   ('worth', 0.08620652456841389),
#   ('succeed', 0.0824688215756939),
#   ('recognised', 0.07497574623168513),
#   ('bargain', 0.07472868971360132),
#   ('cheerfully', 0.06843595973386),
#   ('accepted', 0.06639453397961796),
#   ('manufactures', 0.06606339984442375),
#   ('admittedly', 0.06606339984442375),
#   ('hard', 0.06498568159714557)],
#  27: [('debt', 0.15714830478073832),
#   ('collection', 0.13080504231494086),
#   ('repudiation', 0.11844284423926836),
#   ('possibility', 0.11246793652092975),
#   ('borrow', 0.10520960753829893),
#   ('sums', 0.1050735369306581),
#   ('excise', 0.10268440029828643),
#   ('conjured', 0.09757498448749866),
#   ('unsuccessful', 0.09693445054558465),
#   ('treasury', 0.09232555969832482),
#   ('hands', 0.0886128505690452),
#   ('various', 0.08795991259208918),
#   ('danger', 0.08392732383600471),
#   ('money', 0.08288253805331873),
#   ('attempt', 0.07279904733030396)],
#  28: [('literature', 0.274776869308319),
#   ('americans', 0.1789972712509443),
#   ('native', 0.12726042195755843),
#   ('born', 0.12690396279053304),
#   ('assassination', 0.12061445052548504),
#   ('especially', 0.11506967437560704),
#   ('study', 0.10720450940950471),
#   ('america', 0.0949659522462131),
#   ('sympathy', 0.08663514522135819),
#   ('domestic', 0.08370179642081839),
#   ('welcoming', 0.07114286111968979),
#   ('efforts', 0.0672821762856153),
#   ('american', 0.06646115968714249),
#   ('classes', 0.057263865563516606),
#   ('england', 0.05624899426102538)],
#  29: [('attorney', 0.25422623709531633),
#   ('general', 0.20345728937914462),
#   ('learned', 0.08381381401862024),
#   ('james', 0.06881036988449268),
#   ('johnson', 0.06438715364408826),
#   ('henry', 0.055820647514177514),
#   ('ii', 0.0421927448961969),
#   ('dissented', 0.03967004997798098),
#   ('richard', 0.037881203707760686),
#   ('strike', 0.03725396510923524),
#   ('statements', 0.03698022328465129),
#   ('intent', 0.0353620660292181),
#   ('hon', 0.034948540151507286),
#   ('sir', 0.03290080007013749),
#   ('charges', 0.03227145866674211)],
#  30: [('catholics', 0.1587281576161433),
#   ('protestant', 0.15813501869584268),
#   ('fear', 0.13518875261934768),
#   ('fears', 0.10868162695473794),
#   ('civil', 0.08960235398736559),
#   ('protestants', 0.08869576277169218),
#   ('catholic', 0.06790179176128575),
#   ('abundant', 0.06383852234948599),
#   ('rights', 0.051733345527084446),
#   ('fairly', 0.051186033674576845),
#   ('disastrous', 0.04787889176211449),
#   ('religious', 0.04509652837953781),
#   ('real', 0.0436254523411495),
#   ('perhaps', 0.0432594796839797),
#   ('danger', 0.04232750869763822)],
#  31: [('faults', 0.2609630848453577),
#   ('blots', 0.2440845832641345),
#   ('task', 0.19565719043663826),
#   ('measure', 0.18262295665288134),
#   ('terrible', 0.17984518526252793),
#   ('seems', 0.168440170734583),
#   ('undoubtedly', 0.14915013429975732),
#   ('tremendous', 0.13312776029255088),
#   ('large', 0.1166849602309516),
#   ('shape', 0.11294222422623836),
#   ('even', 0.10861802136289435),
#   ('meet', 0.10362635694841206),
#   ('many', 0.10021319625705957),
#   ('suppose', 0.09821699605023138),
#   ('opposition', 0.0933382107021449)],
#  32: [('forster', 0.27303506940953526),
#   ('hisses', 0.058434202997148556),
#   ('arrested', 0.0421817382718325),
#   ('intimidation', 0.03510707945740475),
#   ('evictions', 0.03296175779200162),
#   ('ruffians', 0.032168958704209466),
#   ('village', 0.030991331018965614),
#   ('landlords', 0.027057847539236513),
#   ('aware', 0.02397001694831444),
#   ('commenced', 0.02397001694831444),
#   ('sentence', 0.022331419510827476),
#   ('lay', 0.0212507038135047),
#   ('houses', 0.0212507038135047),
#   ('eviction', 0.02109086913591625),
#   ('late', 0.020953356030296005)],
#  33: [('vital', 0.15851027697192485),
#   ('matter', 0.1460453345153694),
#   ('thoroughly', 0.14501324263874968),
#   ('open', 0.0980872163191138),
#   ('mind', 0.09734019097950479),
#   ('always', 0.08316145672510498),
#   ('keep', 0.08258395249761182),
#   ('desired', 0.07564981500340273),
#   ('question', 0.07299862996160715),
#   ('regard', 0.07180241149722448),
#   ('gray', 0.0678366290061023),
#   ('vitality', 0.05831648308309787),
#   ('wh', 0.05831648308309787),
#   ('narrowed', 0.05831648308309787),
#   ('dimension', 0.05831648308309787)],
#  34: [('food', 0.19516435116601702),
#   ('unfit', 0.13024001013530626),
#   ('stores', 0.11498982309298326),
#   ('condemned', 0.11162175142680036),
#   ('sold', 0.1036053520425122),
#   ('human', 0.09600907896494404),
#   ('selling', 0.09350979877964714),
#   ('admiralty', 0.06639621294187677),
#   ('articles', 0.0617936238126645),
#   ('meat', 0.061258772746555064),
#   ('discontinued', 0.05901623740639296),
#   ('enforced', 0.05718500350316882),
#   ('reminding', 0.05718500350316882),
#   ('pains', 0.05563760386126487),
#   ('fined', 0.05429795193769774)],
#  35: [('fever', 0.15597903565472868),
#   ('famine', 0.11869777316903503),
#   ('potatoes', 0.052297871094504476),
#   ('actual', 0.04315066739848092),
#   ('broken', 0.04196857469457515),
#   ('weaker', 0.040309140213330964),
#   ('famines', 0.03789906560396397),
#   ('retrace', 0.03789906560396397),
#   ('happened', 0.037032675187409124),
#   ('suffering', 0.037032675187409124),
#   ('distress', 0.03680464224501677),
#   ('ill', 0.03642673911792294),
#   ('potato', 0.03619007854223565),
#   ('crop', 0.03619007854223565),
#   ('disease', 0.03486524739633632)],
#  36: [('association', 0.3087021481995531),
#   ('unlawful', 0.24299744079441782),
#   ('person', 0.08154647915887),
#   ('objects', 0.07632616965936001),
#   ('offence', 0.07351086508501853),
#   ('convicted', 0.04555978878851628),
#   ('encouraging', 0.04444595241085774),
#   ('act', 0.04379383554503636),
#   ('knowing', 0.0404995734657363),
#   ('might', 0.0395509802884648),
#   ('persons', 0.03668825343679804),
#   ('formed', 0.03654749304448639),
#   ('guilty', 0.03369723408409888),
#   ('charged', 0.03364779200995769),
#   ('crimes', 0.032399658772589046)],
#  37: [('davitt', 0.3264390854037884),
#   ('wilson', 0.15062455164528615),
#   ('englishman', 0.1455185094793638),
#   ('sentenced', 0.1349361344868845),
#   ('seven', 0.13015246791785562),
#   ('servitude', 0.13004049607839382),
#   ('years', 0.12093938867501511),
#   ('penal', 0.11690946254859237),
#   ('judge', 0.1109029931353321),
#   ('got', 0.10654884330795858),
#   ('fifteen', 0.07562619910532299),
#   ('effect', 0.062392889823356695),
#   ('selling', 0.05892601605638082),
#   ('devitt', 0.0540534437875191),
#   ('arms', 0.047619862135277156)],
#  38: [('dublin', 0.08587578007178275),
#   ('cork', 0.04816922002540699),
#   ('city', 0.04507789962329111),
#   ('crown', 0.038295319327997165),
#   ('county', 0.03770001435466153),
#   ('christmas', 0.03667600386229083),
#   ('meeting', 0.03586095735833127),
#   ('court', 0.029638681256044835),
#   ('town', 0.029620892074959354),
#   ('exhibition', 0.029466558296101404),
#   ('proceedings', 0.028069178692522064),
#   ('proclamation', 0.02611827978909451),
#   ('mayo', 0.025954009827155986),
#   ('expense', 0.023422656293844248),
#   ('period', 0.022652317728383144)],
#  39: [('party', 0.25340150617823776),
#   ('minority', 0.17323559069000014),
#   ('sometimes', 0.12525337640055403),
#   ('often', 0.11227736955548132),
#   ('bound', 0.10899346707636685),
#   ('remarkable', 0.1049534780978231),
#   ('small', 0.10027751392739957),
#   ('cent', 0.09343352586419211),
#   ('biggar', 0.08681810925682389),
#   ('per', 0.08439717301153143),
#   ('distinguish', 0.08110102462083356),
#   ('tries', 0.08110102462083356),
#   ('possessing', 0.08110102462083356),
#   ('struggling', 0.06613212195485675),
#   ('extravagant', 0.0645397811954072)],
#  40: [('consequences', 0.1074172167694442),
#   ('happening', 0.0997976246262315),
#   ('picture', 0.09762702421453731),
#   ('peaceful', 0.0837256563878856),
#   ('solution', 0.08114458723303915),
#   ('horrible', 0.07720174492001722),
#   ('countries', 0.07418613892079277),
#   ('contains', 0.06779353660398728),
#   ('adopted', 0.06273040752951241),
#   ('england', 0.06137043046689035),
#   ('proposal', 0.06079034780420033),
#   ('suggested', 0.06039271712097467),
#   ('discussion', 0.05957295466583965),
#   ('kind', 0.0584933342093969),
#   ('alternative', 0.057707026902859504)],
#  41: [('treason', 0.2885416841224408),
#   ('felony', 0.1531996735392271),
#   ('romilly', 0.07074108167372586),
#   ('societies', 0.06492184004366298),
#   ('treasonable', 0.05483682703081647),
#   ('john', 0.04967551299622867),
#   ('murder', 0.04927936117608487),
#   ('offences', 0.04237724793529324),
#   ('jurisdiction', 0.04077911388933713),
#   ('convictions', 0.03406145192603201),
#   ('worked', 0.03177847773772166),
#   ('high', 0.03146046562601846),
#   ('sir', 0.030612048760910532),
#   ('sedition', 0.027418413515408236),
#   ('law', 0.02701565406967654)],
#  42: [('rule', 0.4292747490994267),
#   ('home', 0.3054390228346626),
#   ('cheers', 0.2327238058704753),
#   ('ministerial', 0.16286175806248648),
#   ('loud', 0.13702022647664297),
#   ('oh', 0.0899291793513111),
#   ('cries', 0.06085428819321801),
#   ('drowned', 0.056549316929064605),
#   ('noise', 0.056549316929064605),
#   ('tolerant', 0.056549316929064605),
#   ('babel', 0.056549316929064605),
#   ('sound', 0.04823517440504505),
#   ('believe', 0.045669457142730296),
#   ('seconded', 0.04437395123170077),
#   ('phrase', 0.04437395123170077)],
#  43: [('boycotting', 0.3690709659341676),
#   ('practice', 0.11280538565550331),
#   ('advocating', 0.07846467646575353),
#   ('advocated', 0.07450329580391477),
#   ('bellman', 0.062414152588383426),
#   ('speech', 0.06239000434170315),
#   ('power', 0.060046592976294104),
#   ('boycotted', 0.056036250646042306),
#   ('combination', 0.04922951154190858),
#   ('town', 0.042247309203686266),
#   ('number', 0.03566680527799967),
#   ('grew', 0.034398662832426395),
#   ('cases', 0.033696610117375826),
#   ('taking', 0.03247540989153398),
#   ('reprobate', 0.031207076294191713)],
#  44: [('magistrates', 0.19215205147646192),
#   ('stipendiary', 0.1609945177590557),
#   ('elections', 0.13405501996517924),
#   ('castle', 0.12716486470895558),
#   ('magistrate', 0.08852029120068458),
#   ('appoint', 0.08387434288152766),
#   ('vested', 0.08001860058175549),
#   ('jointly', 0.08001860058175549),
#   ('dismissing', 0.08001860058175549),
#   ('residing', 0.08001860058175549),
#   ('situations', 0.07753567756406428),
#   ('candidates', 0.0705883754089902),
#   ('bearing', 0.0705883754089902),
#   ('weight', 0.0679944200162266),
#   ('voting', 0.06702750998258962)],
#  45: [('fund', 0.2397240641910111),
#   ('church', 0.19798200951476397),
#   ('surplus', 0.13394173643559704),
#   ('interest', 0.05793443602521699),
#   ('consolidated', 0.04230593369744815),
#   ('loans', 0.03761064745026012),
#   ('loss', 0.035303058441336056),
#   ('purposes', 0.03493800167907599),
#   ('objections', 0.033703181814628544),
#   ('loan', 0.03260075568588412),
#   ('funds', 0.03211212457561371),
#   ('sometimes', 0.027797094829093056),
#   ('might', 0.026553468216923354),
#   ('commissioners', 0.025398611107863747),
#   ('thrown', 0.025398611107863747)],
#  46: [('manchester', 0.40304427706785395),
#   ('maloney', 0.19515800878485937),
#   ('condon', 0.11967952080498147),
#   ('attack', 0.11291763431378185),
#   ('men', 0.10566810825087719),
#   ('trial', 0.10196378828687971),
#   ('fellow', 0.09456935741645725),
#   ('report', 0.09211574026217012),
#   ('van', 0.08467912529404541),
#   ('gives', 0.08373097127126626),
#   ('young', 0.08197065285617923),
#   ('business', 0.07914584127555303),
#   ('workman', 0.07625784637770784),
#   ('apprehended', 0.07554773453013787),
#   ('hanged', 0.07243554784959928)],
#  47: [('speeches', 0.19602259823266435),
#   ('voice', 0.12300888787559908),
#   ('speech', 0.07937220820355702),
#   ('young', 0.0661120089618933),
#   ('serves', 0.058867955402859315),
#   ('doings', 0.05298351062899513),
#   ('delivered', 0.04321156193818737),
#   ('little', 0.04245391618687238),
#   ('many', 0.039883844942508136),
#   ('speak', 0.03867241656587305),
#   ('made', 0.038401859638311435),
#   ('sober', 0.03751009967154034),
#   ('exerted', 0.03751009967154034),
#   ('complimentary', 0.03751009967154034),
#   ('grotesque', 0.03751009967154034)],
#  48: [('lose', 0.5707367804667669),
#   ('proportionately', 0.37322897752814266),
#   ('constitution', 0.33950604899025383),
#   ('desperate', 0.32073155421107463),
#   ('careful', 0.30439294958227564),
#   ('nothing', 0.18545684272374552),
#   ('parnellite', 0.1506799539209603),
#   ('give', 0.13917388506547737),
#   ('people', 0.1214768769083285),
#   ('submit', 0.08018288855276866),
#   ('hear', 0.07898601365743654),
#   ('prestige', 0.06605760915607546),
#   ('loss', 0.06269156690762333),
#   ('burning', 0.05634551346430042),
#   ('forbidden', 0.050226651306986766)],
#  49: [('imputation', 0.2518114481674509),
#   ('hardy', 0.1051374370869763),
#   ('wish', 0.07859485364257311),
#   ('cast', 0.06399438518589637),
#   ('ceased', 0.05178080087817711),
#   ('disclaim', 0.048370968255997154),
#   ('letter', 0.045921180389254),
#   ('question', 0.0429053172019242),
#   ('existence', 0.042090628137604516),
#   ('observe', 0.03944308702307527),
#   ('exist', 0.03922853038227542),
#   ('convey', 0.03765613791132154),
#   ('wished', 0.037422541478184364),
#   ('rev', 0.03623092045072568),
#   ('behan', 0.03403178959739534)],
#  50: [('quarrels', 0.4339005340097435),
#   ('old', 0.30241977640046785),
#   ('happens', 0.26301359176216943),
#   ('retract', 0.2629539134871685),
#   ('defeated', 0.2386628532139096),
#   ('generally', 0.2339891381142663),
#   ('unhappy', 0.22097256021142808),
#   ('distant', 0.21517793092183735),
#   ('back', 0.20098033355674397),
#   ('desire', 0.14639680216682985),
#   ('refer', 0.13458788746454725),
#   ('recur', 0.12993965349930503),
#   ('recollections', 0.11582880811611233),
#   ('nothing', 0.10692154708052674),
#   ('like', 0.10556679206498538)],
#  51: [('meath', 0.25737257528799934),
#   ('slight', 0.1452874612326579),
#   ('hardship', 0.119648857459582),
#   ('appointments', 0.108701420929735),
#   ('obnoxious', 0.10608408916961616),
#   ('locality', 0.09984899336814164),
#   ('individual', 0.09513532969743825),
#   ('gentry', 0.09224191437140948),
#   ('precedent', 0.0913469244968502),
#   ('great', 0.08072313850389308),
#   ('religious', 0.07678838001633899),
#   ('parties', 0.07047598498406683),
#   ('sought', 0.07009713913775696),
#   ('set', 0.06797334797916153),
#   ('questions', 0.06731633423814169)],
#  52: [('plan', 0.1665278973419488),
#   ('paris', 0.1106760494631781),
#   ('defended', 0.1106760494631781),
#   ('french', 0.10699517581434143),
#   ('enthusiasm', 0.10696503467792454),
#   ('rumours', 0.086745621405497),
#   ('germans', 0.086745621405497),
#   ('circulated', 0.08164714467769169),
#   ('celebrated', 0.07779275249303604),
#   ('elicited', 0.07590241872980988),
#   ('discouraging', 0.07590241872980988),
#   ('interesting', 0.07590241872980988),
#   ('disappointed', 0.07469494993062359),
#   ('lobby', 0.07133011720956096),
#   ('unsuccessful', 0.06806865843140653)],
#  53: [('overseer', 0.26771675564076863),
#   ('orangeman', 0.24164373743149317),
#   ('irritated', 0.21094137834029877),
#   ('digging', 0.18248743757025054),
#   ('workman', 0.15691518389259115),
#   ('drain', 0.1486700972408222),
#   ('works', 0.1315257607422153),
#   ('catholic', 0.12908802170002676),
#   ('papist', 0.0935374337707014),
#   ('orangemen', 0.0935374337707014),
#   ('nice', 0.09011325480899234),
#   ('executing', 0.09011325480899234),
#   ('drains', 0.08495434128046983),
#   ('crust', 0.08290879584333079),
#   ('earn', 0.08110552780900024)],
#  54: [('blood', 0.16286175806248648),
#   ('used', 0.14974744985311142),
#   ('attorney', 0.13983818723343563),
#   ('spencer', 0.12953294618551509),
#   ('head', 0.12870036667906348),
#   ('late', 0.1266725614558804),
#   ('giffen', 0.12389933663448385),
#   ('gravity', 0.10296211825525976),
#   ('general', 0.10236644183496149),
#   ('asserted', 0.10072499241226388),
#   ('exceeded', 0.09625152613404744),
#   ('ever', 0.09567875968603493),
#   ('passes', 0.07322537497924035),
#   ('forgot', 0.06972262857614316),
#   ('meeting', 0.06306230853638368)],
#  55: [('welcomed', 0.21398657186296402),
#   ('prime', 0.1716621045777232),
#   ('minister', 0.16607417338739985),
#   ('truly', 0.164522080788087),
#   ('cheerfully', 0.1506765980406446),
#   ('unless', 0.15044833341061337),
#   ('proceed', 0.12098135530408369),
#   ('ought', 0.11673406816177276),
#   ('regards', 0.11471565519630729),
#   ('measure', 0.1095461108324277),
#   ('members', 0.07984560946419582),
#   ('people', 0.058913678500605665),
#   ('proceeded', 0.040347470951007866),
#   ('disavowals', 0.03203652289543574),
#   ('courageously', 0.03203652289543574)],
#  56: [('govern', 0.2797480710971813),
#   ('swords', 0.2570681134297554),
#   ('drawing', 0.24044152978258027),
#   ('policemen', 0.20524625590746087),
#   ('officers', 0.17811840981047738),
#   ('burghs', 0.1577723271596166),
#   ('border', 0.1577723271596166),
#   ('leaving', 0.15167650775792552),
#   ('seen', 0.14944976387919506),
#   ('armed', 0.1483336173385129),
#   ('expected', 0.14444585744740676),
#   ('side', 0.13947251244824566),
#   ('one', 0.11746100615831737),
#   ('night', 0.11543888576381858),
#   ('done', 0.09552170970065092)],
#  57: [('position', 0.3708059281929589),
#   ('difficulty', 0.23505757030045354),
#   ('difficulties', 0.15305682959128913),
#   ('unions', 0.1205304873880517),
#   ('application', 0.10277620497292698),
#   ('placed', 0.08717632634287521),
#   ('ameliorating', 0.08268887040864867),
#   ('better', 0.08000418060183849),
#   ('advantageous', 0.07606963068291561),
#   ('precisely', 0.07370924152843514),
#   ('view', 0.07124644811593482),
#   ('plain', 0.06846570529331189),
#   ('compared', 0.06587440081950124),
#   ('understanding', 0.06276460712506317),
#   ('maintained', 0.06026524369402585)],
#  58: [('case', 0.23544215153860495),
#   ('cases', 0.20033327110878227),
#   ('analogous', 0.1855324809819069),
#   ('sis', 0.10225355937858256),
#   ('derive', 0.09276624049095344),
#   ('retrospect', 0.09276624049095344),
#   ('custody', 0.08721976741734173),
#   ('coward', 0.08721976741734173),
#   ('lessons', 0.08328675609719986),
#   ('rests', 0.08023782962444523),
#   ('particulars', 0.08023782962444523),
#   ('two', 0.07715355074803382),
#   ('mrs', 0.07564427648261011),
#   ('summer', 0.07564427648261011),
#   ('variety', 0.07382290040844522)],
#  59: [('cries', 0.5737690029646269),
#   ('oh', 0.5652691273510984),
#   ('cheers', 0.5196915063423396),
#   ('counter', 0.2768072721395401),
#   ('ironical', 0.2091914843780179),
#   ('murmurs', 0.12092742063999289),
#   ('name', 0.11575574534491555),
#   ('subscriptions', 0.10857023562670695),
#   ('rank', 0.09414034477830384),
#   ('front', 0.09414034477830384),
#   ('renewed', 0.08089880720056124),
#   ('need', 0.07831124871081409),
#   ('remind', 0.06965803044339322),
#   ('respect', 0.05693846544610378),
#   ('loud', 0.05382937468725259)],
#  60: [('execution', 0.27163455102814577),
#   ('men', 0.2284138905625022),
#   ('imprisonment', 0.21429884181651868),
#   ('innocent', 0.19980653919596084),
#   ('guilt', 0.11715242905744479),
#   ('complained', 0.09554556472999208),
#   ('sentenced', 0.07871274511734928),
#   ('executed', 0.06252797463031694),
#   ('hasten', 0.055292665441752056),
#   ('awful', 0.055292665441752056),
#   ('jeffreys', 0.055292665441752056),
#   ('doubts', 0.055292665441752056),
#   ('repentance', 0.055292665441752056),
#   ('seven', 0.05521619851060542),
#   ('barbarities', 0.05016248559881187)],
#  61: [('vitally', 0.17398103651241092),
#   ('everything', 0.170279224271273),
#   ('success', 0.12536549368949682),
#   ('alternatives', 0.12039471673456614),
#   ('done', 0.118811037437072),
#   ('variety', 0.10671429167953467),
#   ('necessary', 0.10217421445974822),
#   ('trial', 0.0810157822774465),
#   ('ought', 0.08078922143077144),
#   ('request', 0.08078801546945287),
#   ('comes', 0.07089465420179397),
#   ('delaying', 0.06304002991550443),
#   ('usefulness', 0.06304002991550443),
#   ('make', 0.06263100771180105),
#   ('thought', 0.061780497735091686)],
#  62: [('kilmartin', 0.24986841690155642),
#   ('bryan', 0.18583005964884486),
#   ('kilmainham', 0.1765362349955762),
#   ('sentenced', 0.15703774272180523),
#   ('servitude', 0.13969867615848675),
#   ('penal', 0.1360584262418963),
#   ('case', 0.1100663063104119),
#   ('released', 0.06416075255749576),
#   ('prominent', 0.04912204063455233),
#   ('life', 0.04731173174679686),
#   ('fifteen', 0.046940399444683235),
#   ('years', 0.046916142158411035),
#   ('churchill', 0.045718460733398913),
#   ('tenure', 0.045718460733398913),
#   ('noble', 0.04378966009365193)],
#  63: [('glenbeigh', 0.29470828104960917),
#   ('estate', 0.29209257197907823),
#   ('campaign', 0.07227724058695446),
#   ('typical', 0.06981376861690311),
#   ('dunsandle', 0.06981376861690311),
#   ('plan', 0.06665944344309645),
#   ('congested', 0.06267972366077927),
#   ('estates', 0.05911068512989939),
#   ('condition', 0.05506600002368124),
#   ('arrears', 0.05339761975270215),
#   ('tenants', 0.05012700594601038),
#   ('national', 0.046945774186946426),
#   ('league', 0.04093424085100136),
#   ('dillon', 0.03966912833303473),
#   ('inhabited', 0.03847685481771406)],
#  64: [('sum', 0.1720332476925048),
#   ('expenditure', 0.09872838099523726),
#   ('amount', 0.09437793684635039),
#   ('morally', 0.07111032976719987),
#   ('bound', 0.06386634737457285),
#   ('sterling', 0.0630300787113041),
#   ('pounds', 0.05831446929131066),
#   ('million', 0.056524850861167986),
#   ('money', 0.05638597618052287),
#   ('sanctioned', 0.050287139331574776),
#   ('fully', 0.04851063884198622),
#   ('like', 0.045375200098107756),
#   ('issued', 0.043860399335123694),
#   ('defray', 0.04365210429612004),
#   ('spend', 0.04365210429612004)],
#  65: [('representation', 0.11793266549486109),
#   ('legislation', 0.09639814615061292),
#   ('minority', 0.08970649192319387),
#   ('insisted', 0.08334152489326038),
#   ('proportional', 0.07919458043287682),
#   ('numerical', 0.07919458043287682),
#   ('rash', 0.07867470521025359),
#   ('cordially', 0.07867470521025359),
#   ('protestant', 0.07157448375274042),
#   ('hasty', 0.06743546160878879),
#   ('ill', 0.06641526388011997),
#   ('obstruction', 0.06558809812733604),
#   ('influence', 0.06521760313427519),
#   ('deadlock', 0.06321395167299669),
#   ('hear', 0.06227036890667672)],
#  66: [('floating', 0.1839020688692447),
#   ('loans', 0.17551635476788055),
#   ('balance', 0.1682769091624243),
#   ('credit', 0.13163726607591042),
#   ('secure', 0.1275389915065964),
#   ('contribution', 0.1255059999201355),
#   ('anxious', 0.1255059999201355),
#   ('remember', 0.12269407415372677),
#   ('bargain', 0.11556878758033692),
#   ('direction', 0.11288005582482645),
#   ('treasury', 0.11101333448653009),
#   ('small', 0.10818052213098017),
#   ('shows', 0.10791683173116255),
#   ('poor', 0.10571826886333459),
#   ('impossible', 0.10426516433393405)],
#  67: [('positive', 0.30256095497830826),
#   ('definite', 0.1697715943925911),
#   ('opinion', 0.14594072950413664),
#   ('reserve', 0.1447181418796849),
#   ('expression', 0.14447591499370446),
#   ('printed', 0.13667783390035224),
#   ('express', 0.12826351494347896),
#   ('monday', 0.11613795830033044),
#   ('difficult', 0.11567300843830355),
#   ('seen', 0.11125704644340076),
#   ('like', 0.1053712980056058),
#   ('suppose', 0.08403009662075352),
#   ('merits', 0.08389505931910055),
#   ('issued', 0.08333475873673503),
#   ('measure', 0.07877853032085078)]}

# %%
model_place.visualize_topics()
# Out:
# <div>                            <div id="6bcecb17-556a-4ba1-975e-2b36f4d731fa" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bcecb17-556a-4ba1-975e-2b36f4d731fa")) {                    Plotly.newPlot(                        "6bcecb17-556a-4ba1-975e-2b36f4d731fa",                        [{"customdata":[[0,"right | gentleman | hon | secretary | amendment",1723],[1,"jury | evidence | person | judges | juries",197],[2,"sir | results | well | denied | reason",133],[3,"wealth | relative | ulster | counties | munster",99],[4,"letters | letter | forged | signature | times",82],[5,"coercion | drastic | bill | never | arrears",78],[6,"league | land | national | organisation | movement",71],[7,"piers | fishery | harbours | fishermen | coast",56],[8,"adjournment | debate | moved | motion | adjourned",49],[9,"cheers | loud | thank | chairman | honour",47],[10,"bill | nevertheless | predecessors | blots | remove",46],[11,"carnarvon | lord | interview | salisbury | gray",43],[12,"labourers | labourer | farmers | independent | labour",42],[13,"whiskey | revenue | duties | customs | tobacco",42],[14,"evictions | eviction | quarter | evicted | increasing",41],[15,"kerry | outrages | occurrences | denounce | belfast",41],[16,"militia | commanding | mass | attend | meath",41],[17,"faced | risk | fear | danger | otherwise",40],[18,"member | hon | furnished | life | wrote",36],[19,"intimidation | person | definition | intimidated | define",35],[20,"exchequer | chancellor | imperial | contribution | expenditure",35],[21,"progress | report | chairman | motion | sit",35],[22,"outrage | outrages | agitation | publicly | crime",33],[23,"relief | door | boards | poor | machinery",33],[24,"regret | wish | regretted | explanation | hopes",33],[25,"condon | spike | island | handcuffed | citizen",32],[26,"settlement | final | proposing | drive | rich",31],[27,"debt | collection | repudiation | possibility | borrow",29],[28,"literature | americans | native | born | assassination",29],[29,"attorney | general | learned | james | johnson",29],[30,"catholics | protestant | fear | fears | civil",28],[31,"faults | blots | task | measure | terrible",28],[32,"forster | hisses | arrested | intimidation | evictions",27],[33,"vital | matter | thoroughly | open | mind",27],[34,"food | unfit | stores | condemned | sold",26],[35,"fever | famine | potatoes | actual | broken",25],[36,"association | unlawful | person | objects | offence",25],[37,"davitt | wilson | englishman | sentenced | seven",25],[38,"dublin | cork | city | crown | county",25],[39,"party | minority | sometimes | often | bound",24],[40,"consequences | happening | picture | peaceful | solution",24],[41,"treason | felony | romilly | societies | treasonable",24],[42,"rule | home | cheers | ministerial | loud",23],[43,"boycotting | practice | advocating | advocated | bellman",22],[44,"magistrates | stipendiary | elections | castle | magistrate",22],[45,"fund | church | surplus | interest | consolidated",22],[46,"manchester | maloney | condon | attack | men",22],[47,"speeches | voice | speech | young | serves",21],[48,"lose | proportionately | constitution | desperate | careful",21],[49,"imputation | hardy | wish | cast | ceased",21],[50,"quarrels | old | happens | retract | defeated",21],[51,"meath | slight | hardship | appointments | obnoxious",20],[52,"plan | paris | defended | french | enthusiasm",20],[53,"overseer | orangeman | irritated | digging | workman",20],[54,"blood | used | attorney | spencer | head",19],[55,"welcomed | prime | minister | truly | cheerfully",18],[56,"govern | swords | drawing | policemen | officers",18],[57,"position | difficulty | difficulties | unions | application",18],[58,"case | cases | analogous | sis | derive",18],[59,"cries | oh | chee ...

# %%
model_place.visualize_hierarchy()
# Out:
# <div>                            <div id="734f3e9a-3a69-4d85-9850-90493c18359b" class="plotly-graph-div" style="height:1220px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("734f3e9a-3a69-4d85-9850-90493c18359b")) {                    Plotly.newPlot(                        "734f3e9a-3a69-4d85-9850-90493c18359b",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6807244431134047,0.6807244431134047,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.6807244431134047,0.8413389953951151,0.8413389953951151,0.0],"xaxis":"x","y":[-10.0,-10.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8588743082562086,0.8588743082562086,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9117359294493561,0.9117359294493561,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.9117359294493561,0.9221342871217438,0.9221342871217438,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8588743082562086,1.068084438368767,1.068084438368767,0.9221342871217438],"xaxis":"x","y":[-40.0,-40.0,-67.5,-67.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.7606039161998444,0.7606039161998444,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.068084438368767,1.112285287781808,1.112285287781808,0.7606039161998444],"xaxis":"x","y":[-53.75,-53.75,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.8000425736168745,0.8000425736168745,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9046474429279051,0.9046474429279051,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8933058710225094,0.8933058710225094,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9046474429279051,1.0136269978247576,1.0136269978247576,0.8933058710225094],"xaxis":"x","y":[-130.0,-130.0,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8000425736168745,1.0479711890794805,1.0479711890794805,1.0136269978247576],"xaxis":"x","y":[-110.0,-110.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8297588008621035,0.8297588008621035,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9292936409040038,0.9292936409040038,0.0],"xaxis":"x","y":[-185.0,-185.0,-195.0,-195.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9314672544941736,0.9314672544941736,0.0],"xaxis":"x","y":[-205.0,-205.0,-215.0,-215.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.9292936409040038,0.9668740593098757,0.9668740593098757,0.9314672544941736],"xaxis":" ...

# %%
model_place_time = bertopic_time(df_place, model_place)
model_place_time
# Out:
# <div>                            <div id="9ac48f68-fb2c-483d-8291-754ddbdd65c8" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ac48f68-fb2c-483d-8291-754ddbdd65c8")) {                    Plotly.newPlot(                        "9ac48f68-fb2c-483d-8291-754ddbdd65c8",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: derry, amendment, member, argument, supporting","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: prisoners, keeping, political, release, prison","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ten, thieves, reformation, murderers, discipline","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: unwritten, opinion, laws, public, landlords","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chief, secretary, hon, right, gentleman","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tenants, land, landlords, tenant, hear","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: landlords, reopened, settled, cheers, liable","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tenantry, hon, arrears, tenants, gentleman","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: amendment, learned, clause, secretary, hon","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tree, roof, plot, labourer, independent","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, rely, democracy, seats, cheers","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: uphold, mistake, fatal, earl, law","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: toast, nation, shall, position, glories","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: fence, guest, underlined, steed, parent","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ulster, right, gentleman, hon, parliament","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tenants, rent, right, gentleman, hon","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: purchase, rents, value, gentleman, question","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: campaign, plan, cause, hear, actions","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: boast, pleased, gentleman, order, statement","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cheers, irishmen, country, value, govern","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: prisoners, political, treatment, prison, prisons","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: irishmen, help, attendance, trust, movement"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_right_gentleman_hon_secretary","x":["1875-04-20T10:40:48","1875-10-28T04:00:00","1876-04-30T08:00:00","1879-11-17T12:00:00","1880-05-20T16:00:00","1880-11-21T20:00:00","1881-05-26T00:00:00","1881-11-27T04:00:00","1882-05-31T08:00:00","1882-12-02T12:00:00","1883-12-07T20:00:00","1884-06-10T00:00:00","1884-12-12T04:00:00","1885-06-15T08:00:00","1885-12-17T12:00:00","1886-12-22T20:00:00","1887-06-26T00:00:00","1887-12-28T04:00:00","1888-06-30T08:00:00","1889-01-01T12:00:00","1889-07-05T16:00:00","1890-01-06T20:00:00"],"y":[70,35,29,23,216,89,22,59,350,1,14,10,5,7,417,138,45,19,14,28,67,65],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: debater, displaying, admirably, acquitted, ability","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: acquittals, manslaughter, default, depriving, ascertained","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: trials, empanelled, packing, fitzgerald, adverting","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: prevented, deliberately, revision ...

# %% [markdown]
# ### <font color="blue">Sentences Containing Any Keywords in List</font>

# %% [markdown]
# <font color="blue">Set sentence keywords or phrases in first cell and then run cells underneath sequentially to get results and visualisations. Error messages can occur if the format of the keywords_any list is incorrect or if not enough data for model.</font>
#
# <font color="blue">Experiment with different keyword searches. Can use a series of keywords and phrases to get a range of results</font>

# %%
keywords_any = ['america']
#use function to restrict dataframe to rows where sentence contains any of keywords_any
df_keyword_any = dataframe_keyword_any(df_stop, column='sentence', keywords=keywords_any)
df_keyword_any
# Out:
#                  filename     speech_id            publication  \
# 9    parnell_source_00010  speech_00004     the drogheda argus
# 10   parnell_source_00011  speech_00004  the freeman's journal
# 11   parnell_source_00012  speech_00004   the dundalk democrat
# 12   parnell_source_00013  speech_00004             the nation
# 68   parnell_source_00071  speech_00017      the cork examiner
# ..                    ...           ...                    ...
# 654  parnell_source_00658  speech_00394  the freeman's journal
# 654  parnell_source_00658  speech_00394  the freeman's journal
# 657  parnell_source_00661  speech_00397  the freeman's journal
# 657  parnell_source_00661  speech_00397  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence                 place  \
# 9    england remember example set american colonies...        navan, ireland
# 10   england remember example set american colonies...        navan, ireland
# 11   england remember example set american colonies...        navan, ireland
# 12   england remember example set american colonies...        navan, ireland
# 68   contended fenian prisoners done moral wrong qu...       london, england
# ..                                                 ...                   ...
# 654  per cent call tenant farmers admire “see fine ...  maryborough, ireland
# 654  commencement new system american competition c...  maryborough, ireland
# 657  helped helped past countries descendants irish...         cork, ireland
# 657  exiled countrymen america work renewed vigour ...         cork, ireland
# 660  asking executive lord waterford got full rack ...    waterford, ireland
#
#           date
# 9   1875-04-12
# 10  1875-04-12
# 11  1875-04-12
# 12  1875-04-12
# 68  1875-08-01
# ..         ...
# 654 1881-09-26
# 654 1881-09-26
# 657 1881-10-02
# 657 1881-10-02
# 660 1881-10-05
#
# [568 rows x 6 columns]

# %%
topics_keyword_any = bertopic_topics(df_keyword_any, topic_model)
model_keyword_any = topics_place[2]

# %%
model_keyword_any.get_topics()
# Out:
# {-1: [('america', 0.07411963417692041),
#   ('great', 0.03905965537664548),
#   ('country', 0.03427551920001184),
#   ('people', 0.03312199194872208),
#   ('american', 0.03177520279583188),
#   ('government', 0.030479648659017308),
#   ('hear', 0.026936439001383643),
#   ('states', 0.025764817401458015),
#   ('irishmen', 0.02275736721523579),
#   ('england', 0.02155991133738988),
#   ('time', 0.02147152311022702),
#   ('opinion', 0.02147152311022702),
#   ('last', 0.021249921669766365),
#   ('months', 0.021102291763543054),
#   ('two', 0.02085557362550014)],
#  0: [('america', 0.05952642358933751),
#   ('land', 0.0466203900760042),
#   ('people', 0.040503874506769004),
#   ('help', 0.02907010743478977),
#   ('famine', 0.02819103830551288),
#   ('england', 0.0254955258228148),
#   ('landlords', 0.0251705699156365),
#   ('relief', 0.023794604705789164),
#   ('country', 0.023760302660395922),
#   ('american', 0.023549652786254476),
#   ('charity', 0.022623233867167403),
#   ('government', 0.019894139742670444),
#   ('time', 0.019380071623193183),
#   ('league', 0.01918909264863792),
#   ('tenants', 0.018306584302877633)],
#  1: [('america', 0.06357497949764528),
#   ('cheers', 0.04674208635843784),
#   ('countrymen', 0.044755638003591974),
#   ('country', 0.04060208998715903),
#   ('great', 0.040433981388586095),
#   ('people', 0.03670431290440472),
#   ('way', 0.03008219721378068),
#   ('hear', 0.027829850731783574),
#   ('feel', 0.02732097573766225),
#   ('proud', 0.024788072802533354),
#   ('dillon', 0.024225181370805534),
#   ('american', 0.02389376301559666),
#   ('loud', 0.02262817509686138),
#   ('home', 0.022377819001795987),
#   ('cause', 0.022311795337332675)],
#  2: [('america', 0.0857986706533352),
#   ('without', 0.08443033881491027),
#   ('character', 0.06891781912480886),
#   ('threatening', 0.05730832014204848),
#   ('one', 0.053172702967592335),
#   ('opinion', 0.05233400442805861),
#   ('cabled', 0.05209493121380469),
#   ('lies', 0.05209493121380469),
#   ('proud', 0.047006311814745856),
#   ('england', 0.046882342698814264),
#   ('force', 0.04661874716178776),
#   ('public', 0.04375324163817001),
#   ('people', 0.042535416801779365),
#   ('great', 0.04165120578725727),
#   ('solution', 0.04142483865815125)],
#  3: [('whether', 0.09990398835923572),
#   ('condon', 0.09486777433481655),
#   ('american', 0.08905635514893154),
#   ('citizen', 0.07667621240616676),
#   ('house', 0.07201851201863738),
#   ('foreign', 0.0712299392206295),
#   ('newspapers', 0.06729068334153417),
#   ('imprisonment', 0.06683731909790297),
#   ('edward', 0.06575071312673493),
#   ('secretary', 0.06575071312673493),
#   ('affairs', 0.06380988498214915),
#   ('information', 0.05849239456697006),
#   ('omeagher', 0.05776231007203347),
#   ('held', 0.05395442231381366),
#   ('conductors', 0.05306083917370965)],
#  4: [('literature', 0.23672432607482707),
#   ('assassination', 0.15242208676847205),
#   ('gentleman', 0.10509352179995889),
#   ('right', 0.10221843075622469),
#   ('hon', 0.09981319400063211),
#   ('american', 0.08993612399070584),
#   ('book', 0.07588748998981201),
#   ('neither', 0.0709205643064427),
#   ('citizens', 0.06838571699033773),
#   ('member', 0.06439341028537209),
#   ('saying', 0.06355346231287358),
#   ('learned', 0.06204580794045782),
#   ('called', 0.061304554383309354),
#   ('devoted', 0.057557422135869125),
#   ('affair', 0.057557422135869125)],
#  5: [('americans', 0.16603688820361012),
#   ('native', 0.12653995719879046),
#   ('especially', 0.12016444814745336),
#   ('born', 0.11296544422955182),
#   ('england', 0.08379996586594952),
#   ('literature', 0.08301844410180506),
#   ('peace', 0.08053663900345524),
#   ('bring', 0.0776580933344739),
#   ('concession', 0.07248297510310972),
#   ('domestic', 0.07248297510310972),
#   ('belief', 0.06989228400102651),
#   ('settlement', 0.06885108649103865),
#   ('study', 0.06770465108472674),
#   ('prime', 0.06725132614564294),
#   ('minister', 0.06725132614564294)]}

# %%
model_keyword_any.visualize_topics()
# Out:
# <div>                            <div id="b639388e-27e0-4e16-8309-24679133d979" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b639388e-27e0-4e16-8309-24679133d979")) {                    Plotly.newPlot(                        "b639388e-27e0-4e16-8309-24679133d979",                        [{"customdata":[[0,"america | land | people | help | famine",200],[1,"america | cheers | countrymen | country | great",88],[2,"america | without | character | threatening | one",50],[3,"whether | condon | american | citizen | house",39],[4,"literature | assassination | gentleman | right | hon",32],[5,"americans | native | especially | born | england",26]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[200,88,50,39,32,26],"sizemode":"area","sizeref":0.125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.7290961146354675,1.239861011505127,0.5927605628967285,-2.9414689540863037,-2.202941417694092,-2.5675926208496094],"xaxis":"x","y":[-17.331748962402344,-17.66539764404297,-18.18427085876465,-16.72675895690918,-16.97635841369629,-17.601457595825195],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7 ...

# %%
model_keyword_any.visualize_hierarchy()
# Out:
# <div>                            <div id="73a5164c-0ca1-49b9-be64-ffa4c80b3e0f" class="plotly-graph-div" style="height:290px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73a5164c-0ca1-49b9-be64-ffa4c80b3e0f")) {                    Plotly.newPlot(                        "73a5164c-0ca1-49b9-be64-ffa4c80b3e0f",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5321906756835689,0.5321906756835689,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7204594861066328,0.7204594861066328,0.5321906756835689],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7422818191505994,0.7422818191505994,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8696551878556422,0.8696551878556422,0.7422818191505994],"xaxis":"x","y":[-35.0,-35.0,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.7204594861066328,1.0481439743433787,1.0481439743433787,0.8696551878556422],"xaxis":"x","y":[-12.5,-12.5,-42.5,-42.5],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":290,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["2_america_without_character","0_america_land_people","1_america_cheers_countrymen","3_whether_condon_american","5_americans_native_especially","4_literature_assassination_..."],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0],"type":"linear","zeroline":false,"range":[-60.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444 ...

# %%
keyword_any_time = bertopic_time(df_keyword_any, model_keyword_any)
keyword_any_time
# Out:
# <div>                            <div id="c79dd8db-1f7a-4195-b228-9f3ea82818ce" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c79dd8db-1f7a-4195-b228-9f3ea82818ce")) {                    Plotly.newPlot(                        "c79dd8db-1f7a-4195-b228-9f3ea82818ce",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: england, refuse, weakness, mind, remember","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: flowers, cultivated, carefully, extracted, noxious","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: america, land, landlords, people, relieve","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: america, land, people, help, famine","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: land, america, bogs, face, people","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: land, resolution, cases, rent, america","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: time, respectable, businesses, aliens, farms","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: let, first, furnished, year, relieve","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: assistance, received, time, reorganised, urgency","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: million, success, wanting, post, absurd","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: distinguished, preparations, regret, unprecedented, sea","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: agreeing, final, condemn, returns, reservation","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: state, union, militia, appointing, right","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tenant, wants, family, produced, provided","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: conduct, proposes, inquire, vessel, sir","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mercy, cotton, expected, refused, slaves","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: glad, shall, desolate, exchequer, equip","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: measures, prosper, taxation, excessive, members"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_america_land_people_help","x":["1875-04-06T04:10:33.600000","1875-10-23T04:48:00","1879-07-13T14:24:00","1880-01-23T19:12:00","1881-02-15T04:48:00","1881-08-28T09:36:00","1882-03-10T14:24:00","1882-09-20T19:12:00","1883-04-03T00:00:00","1883-10-14T04:48:00","1885-05-18T19:12:00","1885-11-29T00:00:00","1886-06-11T04:48:00","1886-12-22T09:36:00","1888-01-14T19:12:00","1889-08-19T09:36:00","1890-03-01T14:24:00","1890-09-11T19:12:00"],"y":[5,1,32,121,11,7,1,3,2,2,1,2,4,1,2,2,1,2],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: god, great, america, kindness, thank","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: america, cheers, country, way, countrymen","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: race, america, much, home, many","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: spirit, countrymen, short, fall, exiled","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: might, exhibition, dublin, formed, subscribed","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: congratulate, movement, national, league, making","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: countrymen, assemblage, wield, benefit, consented","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: underlined, hear, remains, contest, gain","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: collins, general, years, president, league","\u003cb\u003eTopic 1\u ...
