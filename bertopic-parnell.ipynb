# %% [markdown]
# # BERTopic and Parnell

# %% [markdown]
# Import additional Python Libraries

# %%
#libraries for getting file paths and data extraction from files
import glob
import os
from pathlib import Path
from natsort import natsorted
from natsort import os_sorted
#libraries for data analysis and manipulation
import pandas as pd
import string
import re
import cufflinks as cf
from bs4 import BeautifulSoup
from datetime import datetime
import cufflinks as cf
#nlp libraries
import spacy
from nltk.corpus import stopwords
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters
from gensim.utils import simple_preprocess
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from bertopic import BERTopic
#libraries for visualisations
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

#optimise notebook and spacy settings
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
os.environ["TOKENIZERS_PARALLELISM"] = "false"

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Functions

# %% [markdown]
# Functions to extract data from TEI files using Beautiful Soup.

# %%
def soup_objects(file_paths):
    '''Takes either a list of file paths or a file path.
    Returns a list of beautiful soup objects or single
    beautiful soup object, depending on the input.
    '''
    if type(file_paths) == list:
        soup_list = []
        for path in file_paths:
            with path.open("r", encoding="utf-8") as xml:
                source = BeautifulSoup(xml, "lxml-xml")
                soup_list.append(source)
        return soup_list
    else:
        with file_paths.open("r", encoding="utf-8") as xml:
            soup_object = BeautifulSoup(xml, "lxml-xml")
        return soup_object

# %%
def tei_extractor(soup_obj, element, attributes=False):
    '''Takes Beautiful soup object or list of objects, 
    element using element name and, where necessary, attributes.
    Returns list of elements for all input files or list of
    elements for input file, depending on input.
    '''
    attrib_dict ={}
    if attributes:
        attrib_dict = {attr: True for attr in attributes}
    
    if type(soup_obj) == list:
        elem_ls = [obj.find(element, attrib_dict) for obj in soup_obj]
        return elem_ls 
    else:
        elem_ls = soup_obj.find_all(element, attrib_dict)
        return elem_ls

# %%
def tei_values(object_list, attribute=False):
    '''Takes a list of beautiful soup elements, if attribute
    value is being extracted include name of that attribute.
    Return element or attribute value depending on input(s)
    '''
    if attribute:
        values = [obj[attribute] for obj in object_list]
        return values
    else:
        values = [obj.get_text() for obj in object_list]
        return values

# %% [markdown]
# Functions to perform text cleaning and convert results into dataframe format.

# %%
def text_cleaning(text):
    '''Takes as input a string, removes/replaces special characters, newlines,
    possessive apostrophes, hyphens, underscores, digits and makes single space.
    Returns clean string.
    '''
    text = text.replace(u"\xa0", u" ").replace("&", "and").replace("|", " ")
    text = text.replace("\n", " ").replace("’", "'").replace("'s ", ' ')
    text = text.replace("-", " "). replace("–", " ").replace("_", " ").replace("—", " ")
    non_digit_text = re.sub(r"\b\d+\b", "", text)
    sing_space_text = re.sub(r"\s\s+", " ", non_digit_text)
    sing_space_text = sing_space_text.strip()
    return sing_space_text

# %%
def create_dataframe(data, columns):
    '''Takes as input a list of lists of data and a list of columns.
    Returns a dataframe.
    '''
    df = pd.DataFrame(data)
    df = df.transpose()
    df.columns = columns
    return df

# %%
def dataframe_cleaning(dataframe, clean_column=None):
    '''Takes as input dataframe and makes lowercase, strips leading and
    trailing spaces, standardises apostrophes. Applies data cleaning function
    to column if identified as clean column parameter.
    Returns lowercase/cleaned dataframe.
    '''
    lower_dataframe = dataframe.applymap(lambda x: x.lower())
    lower_dataframe = lower_dataframe.applymap(lambda x: x.replace("’", "'"))
    if clean_column:
        lower_dataframe[clean_column] = lower_dataframe[clean_column].apply(lambda x: text_cleaning(x))
    clean_dataframe = lower_dataframe.applymap(lambda x: x.strip())
    return clean_dataframe

# %%
def punct_removal(text):
    '''Takes as input a string and removes punctuation, removes extra spacing.
    Returns string without punctuation.
    '''
    text = text.translate(str.maketrans(" ", " ", string.punctuation))
    text = re.sub(r"\s\s+", " ", text)
    text = text.strip()
    return text

# %% [markdown]
# Functions to perform topic modelling and sentence/year counts then visualise the results.

# %%
def bertopic_time(dataframe, topic_model):
    '''Takes as input a dataframe and Bertopic topic model tool.
    Extracts dates and sentences for each dataframe row as lists.
    Fit sentence list to topic model, create dictionary of topics/sentences.
    Send sentence list/dates to topics_over_time to create visualisation.
    Return visualisation, topic/sentence dictionary.
    '''
    sent_list = dataframe["sentence"].to_list()
    date_list = dataframe["date"].to_list()
    topics, probs = topic_model.fit_transform(sent_list)
    
    topic_docs = {topic: [] for topic in set(topics)}
    for topic, doc in zip(topics, sent_list):
        topic_docs[topic].append(doc)
    
    topics_over_time = topic_model.topics_over_time(docs=sent_list, 
                                                timestamps=date_list, 
                                              )
    fig = topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=15, height=500, width=1000)
    fig.update_layout(yaxis_title = "Count")
    return (fig, topic_docs)

# %%
def year_counts(dataframe):
    '''Takes as input a dataframe.
    Returns as series with number of sentences per year.
    '''
    dataframe["year"] = dataframe["date"].dt.year
    year_counts = dataframe.groupby(["year"]).size()
    return year_counts

# %%
def year_counts_plot(year_counts):
    '''Takes as input a year count series.
    Returns a bar chart of number of sentences per year.
    '''
    year_counts_plot = px.bar(year_counts, 
                          title="Sentence Count by Year",
                          labels= {
                              "value":"Count",
                              "year":"Year"
                          }
                         )
    year_counts_plot.update_layout(showlegend=False)
    return year_counts_plot

# %% [markdown]
# Functions to alter the data prior to input in topic modelling: lemmatization, removal of stopwords, narrow dataframe by date window or keyword search.

# %%
def lemmatization(text):
    '''Takes string and converts to lemmatized string'''
    doc = nlp(text)
    return ' '.join(token.lemma_ for token in doc)

# %%
def remove_stopwords(text, stopwords):
    ''' Take as input string and list of stopwords, tokenizes
    string and removes words contained in stopwords.
    Returns re-joined string without stopwords.
    '''
    tokenized_text = text.split()
    non_stop_text = [token for token in tokenized_text if token not in stopwords]
    return ' '.join(non_stop_text)

# %%
def dataframe_date_window(dataframe, start_date, end_date):
    '''Takes as input dataframe, start date and end date.
    Returns dataframe with just the rows where the date is on/between
    the start date and end date.
    '''
    mask = (dataframe['date'] > start_date) & (dataframe['date'] <= end_date)
    win_dataframe = dataframe.loc[mask]
    return win_dataframe

# %%
def dataframe_keyword(dataframe, keywords):
    '''Takes as input dataframe and a list of keywords.
    Returns dataframe with just rows where sentence contains any
    of the words in keywords, keywords removed from sentences in
    which they appear.
    '''
    boundary_list = [fr'\b{word}\b' for word in keywords]
    keyword_df = dataframe[dataframe['sentence'].apply
                           (lambda sentence: any(re.search(word, sentence) for word in boundary_list))]
    keyword_df['sentence'] = keyword_df['sentence'].str.replace('|'.join(boundary_list), '', regex=True).str.strip()
    return keyword_df

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# We begin by extracting the data we need from the speech report files and the speech register file.

# %%
# get paths for speech reports
dir_path = Path('sources/')
#get filepaths to all the XML files in the directory
xml_files = (file for file in dir_path.iterdir() if file.is_file() and file.name.lower().endswith('.xml'))
#sort xml file paths numerically using os_sorted library
xml_files = os_sorted(xml_files)

#get path for speech register file
speech_file = Path('speeches/parnell_speeches.xml')

#basename returns filename removing directory path.
#split to remove ".xml" extension so that we can use later in dataframe
filenames = []
for path in xml_files:
    filename = os.path.basename(path)
    filename = filename.split(".")[0]
    filenames.append(filename)

# %%
#extract speech reports and speech register as beautiful soup objects using function
report_objects = soup_objects(xml_files)
speech_object = soup_objects(speech_file)

# %%
#speech register beautiful soup objects extracted as lists using function
speech_objs = tei_extractor(speech_object, element='speech_id')
place_objs = tei_extractor(speech_object, element='place', attributes=['key'])
date_objs = tei_extractor(speech_object, element='date', attributes=['when'])

#speech report beautiful soup objects extracted as lists using function
speech_rep_objs = tei_extractor(report_objects, element='term', attributes=['key'])
publication_objs = tei_extractor(report_objects, element='title', attributes=['key', 'level'])
text_objs = tei_extractor(report_objects, element='body')

# %%
#use function to extract values from tei elements extracted above
speech_ids = tei_values(speech_objs)
speech_places = tei_values(place_objs)
speech_dates = tei_values(date_objs, attribute='when')

speech_rep_ids = tei_values(speech_rep_objs, attribute='key')
publications = tei_values(publication_objs)
texts = tei_values(text_objs)

#for speech ids, if more than one id present, shown by inclusion of comma, convert into a list
speech_rep_ids = [item.split(',') if ',' in item else item for item in speech_rep_ids]

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# The next stage is to convert the speech data into a dataframe format where we can easily manipulate it and get different subsets prior to analysis/visualisation.
#
# We begin by converting the speech report data into a dataframe and performing some data cleaning on the text to standardise it and make it more suitable for data analysis. This includes making the text lower case, removing extra spacing and some special characters.

# %%
#prepare data for speech report dataframe, make list of lists of data and list of column names
speech_rep_data = [filenames, speech_rep_ids, publications, texts]
speech_rep_columns = ['filename', 'speech_id', 'publication', 'sentence']
#use function to turn the above lists into dataframe
speech_rep_df = create_dataframe(speech_rep_data, speech_rep_columns)
speech_rep_df = speech_rep_df.explode('speech_id')
#use function to clean the text in the dataframe and standardise it
speech_rep_df = dataframe_cleaning(speech_rep_df, clean_column='sentence')
speech_rep_df
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 1    parnell_source_00002  speech_00001  the freeman's journal
# 2    parnell_source_00003  speech_00001             the nation
# 3    parnell_source_00004  speech_00001        the irish times
# 4    parnell_source_00005  speech_00002  the freeman's journal
# ..                    ...           ...                    ...
# 656  parnell_source_00660  speech_00396  the freeman's journal
# 657  parnell_source_00661  speech_00397  the freeman's journal
# 658  parnell_source_00662  speech_00398  the freeman's journal
# 659  parnell_source_00663  speech_00399  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence
# 0    the home rule league great meeting in the rotu...
# 1    the home rule league on saturday evening a pub...
# 2    the week "though beaten, we are not vanquished...
# 3    irish home rule league a public meeting of the...
# 4    mr. charles stewart parnell, in seconding the ...
# ..                                                 ...
# 656  fellow countrymen and fellow citizens, it is n...
# 657  mr. chairman, fellow citizens, and people of t...
# 658  people of mallow, i certainly did not expect t...
# 659  people of dungarvan, i will, through you, expr...
# 660  the chairman said one of the resolutions which...
#
# [683 rows x 4 columns]

# %% [markdown]
# We then use the sentence tokenizer to divide each report text into sentences before amending the dataframe so that each sentence has its own row with the appropriate report data for that sentence.
#
# Having done this we remove punctuation from all sentences in the sentence column and remove rows where the sentence is less than 3 words as these tend not to be proper sentences (crowd reactions etc).

# %%
#initialize nltk abbreviation words, these will be added to the sentence tokenizer
#they will prevent the tokenizer from reading some full stops as sentence-enders
punkt_param = PunktParameters()
#we can add our own abbreviation words, e.g. "hon." and "mr." frequently have full stops in the reports
punkt_param.abbrev_types = set(['hon', 'mr', 'rev', 'dr', 'm.p', 'c.s', 'c.v', 'c.e', 't.l', 'j.r', 'j.j', 'a.j',
                            'r.b', 'j.g', 'j.l', 'j.r', 'j.f', 'n.b', 'p.j', 'c.j', 't.d', 'r', 'p.p', 'l.p', 'c.c', 'wm',
                            'capt', 'messrs', 'patk', '1d', '2d', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d', '11d',
                            '1/2d', '3/4d', 'prof', 'per cent', 'adm', '2s', '1,400,000/', '400,000/'])

#initialize nltk sentence detector for dividing text into sentences
sentence_tokenizer = PunktSentenceTokenizer(punkt_param)

#apply sentence tokenizer to each text in the dataframe to convert into a list of sentences
speech_rep_df['sentence'] = speech_rep_df['sentence'].apply(lambda x: sentence_tokenizer.tokenize(x))
#use explode on the sentence column, so that each sentence is converted into its own row
speech_rep_df = speech_rep_df.explode('sentence')
#now that the text has been divided into sentences, we can remove punctuation using function
speech_rep_df['sentence'] = speech_rep_df['sentence'].apply(lambda x: punct_removal(x))
#we then remove rows with very short sentences from our dataframe, likely to be crowd reactions etc
speech_rep_df = speech_rep_df[speech_rep_df['sentence'].apply(lambda x: len(x.split()) > 3)]
speech_rep_df
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence
# 0    the home rule league great meeting in the rotu...
# 0    there was an immense attendance the platform t...
# 0    mr charles stewart parnell high sheriff of wic...
# 0    the following report of the proceedings is tak...
# 0    in view of the unwise course adopted by our op...
# ..                                                 ...
# 660  the application is a perfectly disgraceful one...
# 660  we have had a good legal opinion that all the ...
# 660  the chairman said they had already sent out fo...
# 660       the chairman you must settle that yourselves
# 660  you cannot expect me to take everything on my ...
#
# [21851 rows x 4 columns]

# %% [markdown]
# We then convert the speech register into a dataframe before applying some data cleaning to make lowercase and remove spacing. We also convert dates into datetime format.

# %%
#prepare data for speech register dataframe, make list of lists of data and list of column names
speech_data = [speech_ids, speech_places, speech_dates]
speech_columns = ["speech_id", 'place', 'date']
#use function to turn the above lists into dataframe
speech_df = create_dataframe(speech_data, speech_columns)
#use function to clean the text in the dataframe and standardise it
speech_df = dataframe_cleaning(speech_df)
#make speech id index so we can use it when we merge dataframes below
speech_df.set_index('speech_id', inplace=True)
#convert date column to datetime format, enables us to manipulate dataframe using dates
speech_df['date'] = pd.to_datetime(speech_df['date'], format="%Y-%m-%d")
speech_df
# Out:
#                            place       date
# speech_id
# speech_00001     dublin, ireland 1874-07-11
# speech_00002     dublin, ireland 1875-01-21
# speech_00003     dublin, ireland 1875-01-22
# speech_00004      navan, ireland 1875-04-12
# speech_00005     london, england 1875-04-26
# ...                          ...        ...
# speech_00396       cork, ireland 1881-10-02
# speech_00397       cork, ireland 1881-10-02
# speech_00398     mallow, ireland 1881-10-03
# speech_00399  dungarvan, ireland 1881-10-05
# speech_00400  waterford, ireland 1881-10-05
#
# [400 rows x 2 columns]

# %% [markdown]
# Having converted our speech reports and register into dataframes, we then join the dataframes together using the speech id contained in both dataframes. We end up with each sentence row in the final dataframe containing the appropriate speech data as well.

# %%
#join the speech register and speech report dataframes indexing on speech_id
df_all = speech_rep_df.merge(speech_df, left_on='speech_id', right_index=True)
df_all
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 0    the home rule league great meeting in the rotu...     dublin, ireland
# 0    there was an immense attendance the platform t...     dublin, ireland
# 0    mr charles stewart parnell high sheriff of wic...     dublin, ireland
# 0    the following report of the proceedings is tak...     dublin, ireland
# 0    in view of the unwise course adopted by our op...     dublin, ireland
# ..                                                 ...                 ...
# 660  the application is a perfectly disgraceful one...  waterford, ireland
# 660  we have had a good legal opinion that all the ...  waterford, ireland
# 660  the chairman said they had already sent out fo...  waterford, ireland
# 660       the chairman you must settle that yourselves  waterford, ireland
# 660  you cannot expect me to take everything on my ...  waterford, ireland
#
#           date
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [21851 rows x 6 columns]

# %% [markdown]
# ## Topic Modelling

# %% [markdown]
# Having prepared our main dataframe, we are now able to begin our topic modelling stage, which will involve manipulating the data in different ways before performing topic modelling on the resulting data subsets and getting visualisations of the results.
#
# Before we do this, however, we first do a count of the number of sentences in each year of the dataset to use alongside our topic modelling process.

# %%
#make copy of main dataframe
df_year_counts = df_all.copy()
#use function to get a count of all sentences by year
year_counts_all = year_counts(df_year_counts)
#use function to get visualisation of year/sentence count
report_sent_nums = year_counts_plot(year_counts_all)
report_sent_nums
# Out:
# <div>                            <div id="8078b4a9-5d3b-49e1-a056-437d617e8727" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8078b4a9-5d3b-49e1-a056-437d617e8727")) {                    Plotly.newPlot(                        "8078b4a9-5d3b-49e1-a056-437d617e8727",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":[1874,1875,1876,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891],"xaxis":"x","y":[32,1030,615,39,5870,2102,2037,485,410,1387,3474,864,345,729,834,1598],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","m ...

# %% [markdown]
# We first initialize our topic model, setting our embedding model, which is a Sentence Transformers model, alongside the minimum topic size, which is the number of times a topic needs to occur in order to be included. Other parameters are also available and can be seen on the BERTopic website.
#
# Sentence Transformers creates embeddings for all the input sentences in our dataset and uses the similarity of these embeddings to calculate sentence similarity. In the context of BERTopic these embeddings are used to calculate topics.
#
# BERTopic is stochastic by nature and this means that every time the algorithm is run we get different results, although the difference between runs should ideally be relatively small.

# %%
#initialize BERTopic topic model with parameters, uses a sentence transformers model to calculate topics
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2", nr_topics="auto", min_topic_size=15)

# %% [markdown]
# Our first visualisation shows the topics over time for the whole dataset.

# %%
#use function to get visualisation of topics for the whole dataset
all_vis_obj = bertopic_time(df_all, topic_model)
all_vis = all_vis_obj[0]
all_vis
# Out:
# <div>                            <div id="223d31b4-f55f-4bae-814d-e38719bdd0ad" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("223d31b4-f55f-4bae-814d-e38719bdd0ad")) {                    Plotly.newPlot(                        "223d31b4-f55f-4bae-814d-e38719bdd0ad",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: solidity, obviously, skill, rented, fell","<b>Topic 0</b><br>Words: interest, tenant, landlord, define, fast","<b>Topic 0</b><br>Words: knowing, steadily, root, occupiers, increasing","<b>Topic 0</b><br>Words: legally, accordance, spent, wishes, money","<b>Topic 0</b><br>Words: purchasers, tithe, charge, rent, to","<b>Topic 0</b><br>Words: reduce, landlords, bad, rents, good","<b>Topic 0</b><br>Words: rebuked, refuse, provoked, receipt, landlords","<b>Topic 0</b><br>Words: black, advice, deed, homesteads, shown","<b>Topic 0</b><br>Words: grants, american, rents, land, irish","<b>Topic 0</b><br>Words: landlord, rented, estate, landlords, value","<b>Topic 0</b><br>Words: landlords, rent, systematic, payment, tenants","<b>Topic 0</b><br>Words: estates, tenants, landlords, market, court","<b>Topic 0</b><br>Words: landlords, tenants, paid, per, state","<b>Topic 0</b><br>Words: needy, tickets, necessitous, lazy, honored","<b>Topic 0</b><br>Words: landlords, tenants, per, state, tenant","<b>Topic 0</b><br>Words: landlords, improve, tenant, console, capita","<b>Topic 0</b><br>Words: elapse, landlords, wretched, breaking, demands","<b>Topic 0</b><br>Words: tenant, landlord, land, does, ownership","<b>Topic 0</b><br>Words: rental, rentals, arrange, partial, saturday","<b>Topic 0</b><br>Words: solutation, german, unbiased, shore, neglects","<b>Topic 0</b><br>Words: thirds, cent, extending, per, bonds","<b>Topic 0</b><br>Words: raised, desired, sent, money, only","<b>Topic 0</b><br>Words: tenants, landlords, purchase, rent, immigration","<b>Topic 0</b><br>Words: organizations, tainted, hearers, distributed, kill","<b>Topic 0</b><br>Words: landlords, tenants, bonds, titles, sell","<b>Topic 0</b><br>Words: soon, unless, up, gave, landlords","<b>Topic 0</b><br>Words: transfer, nearly, obstructing, cost, estate","<b>Topic 0</b><br>Words: landlords, give, money, confiscation, tenants","<b>Topic 0</b><br>Words: landlords, tenants, terms, much, expense","<b>Topic 0</b><br>Words: million, save, beg, enslaved, half","<b>Topic 0</b><br>Words: money, reproductive, appropriated, landlords, paupers","<b>Topic 0</b><br>Words: farms, handicapped, cap, heartiness, tenants","<b>Topic 0</b><br>Words: tenants, landlords, interest, instalments, pay","<b>Topic 0</b><br>Words: wonderful, landlordism, advisedly, startling, circumstance","<b>Topic 0</b><br>Words: odds, vital, seem, win, fight","<b>Topic 0</b><br>Words: ruin, farmers, nominees, tenant, wrought","<b>Topic 0</b><br>Words: sold, bailiffs, deter, selfish, occasion","<b>Topic 0</b><br>Words: purses, expenses, aid, paying, hundred","<b>Topic 0</b><br>Words: remind, advantage, conclusion, fault, meath","<b>Topic 0</b><br>Words: grinding, obtains, foremost, tyranny, restoration","<b>Topic 0</b><br>Words: tenants, valuation, valued, rent, landlords","<b>Topic 0</b><br>Words: purchase, valuation, estates, tenants, years","<b>Topic 0</b><br>Words: tenant, admit, court, farmers, county","<b>Topic 0</b><br>Words: tenant, rack, landlords, thousand, rent","<b>Topic 0</b><br>Words: valuation, rent, tenants, rents, landlords","<b>Topic 0</b><br>Words: 9th, section, compensation, rent, repealing","<b>Topic 0</b><br>Words: discretionary, rent, exorbitant, non, evictions","<b>Topic 0</b><br>Words: improving, estates, alms, inclemency, landlords","<b>Topic 0</b><br>Words: expended, lent, distressed, relieve, celerity","<b>Topic 0</b><br ...

# %% [markdown]
# Next we lemmatize all of the sentences, so that words are reduced to their root forms - e.g. 'running' becomes 'run'. This reduces unnecessary variation in the dataset as related words are treated as being the same. Having performed lemmatization we then visualize topics over time for the lemmatized dataset.

# %%
#copy dataframe from original
df_lemma = df_all.copy()
#use function to lemmatize all of the sentences in dataframe
df_lemma['sentence'] = df_lemma['sentence'].apply(lambda x: lemmatization(x))
df_lemma
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 0    the home rule league great meeting in the rotu...     dublin, ireland
# 0    there be an immense attendance the platform th...     dublin, ireland
# 0    mr charles stewart parnell high sheriff of wic...     dublin, ireland
# 0    the following report of the proceeding be take...     dublin, ireland
# 0    in view of the unwise course adopt by our oppo...     dublin, ireland
# ..                                                 ...                 ...
# 660  the application be a perfectly disgraceful one...  waterford, ireland
# 660  we have have a good legal opinion that all the...  waterford, ireland
# 660  the chairman say they have already send out fo...  waterford, ireland
# 660         the chairman you must settle that yourself  waterford, ireland
# 660  you can not expect I to take everything on my ...  waterford, ireland
#
#           date
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [21851 rows x 6 columns]

# %%
#use function to get visualisation of topics for the whole dataset with lemmatized text
lemma_vis_obj = bertopic_time(df_lemma, topic_model)
lemma_vis = lemma_vis_obj[0]
lemma_vis
# Out:
# <div>                            <div id="c4c330b1-d92b-45f5-80aa-46ff52edae87" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4c330b1-d92b-45f5-80aa-46ff52edae87")) {                    Plotly.newPlot(                        "c4c330b1-d92b-45f5-80aa-46ff52edae87",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: chair, let, commencement, though, seemingly","<b>Topic 0</b><br>Words: stewart, double, charles, second, resolution","<b>Topic 0</b><br>Words: manage, lot, cast, identify, england","<b>Topic 0</b><br>Words: parnell, hind, mr, advocate, navan","<b>Topic 0</b><br>Words: member, parnell, he, her, when","<b>Topic 0</b><br>Words: support, amendment, parnell, mr, the","<b>Topic 0</b><br>Words: abuse, afraid, lieutenant, police, lord","<b>Topic 0</b><br>Words: rev, galvin, barron, till, drunk","<b>Topic 0</b><br>Words: immediately, notice, subject, another, parnell","<b>Topic 0</b><br>Words: parnell, hardy, mr, war, imputation","<b>Topic 0</b><br>Words: rule, home, resolution, britain, second","<b>Topic 0</b><br>Words: mr, laugh, gloat, eustace, refined","<b>Topic 0</b><br>Words: tuesday, louth, member, hon, speak","<b>Topic 0</b><br>Words: meldon, oclery, mr, protest, playfair","<b>Topic 0</b><br>Words: resolution, hyde, support, mp, debauch","<b>Topic 0</b><br>Words: vestment, board, grand, diocese, jury","<b>Topic 0</b><br>Words: chair, impartial, acclamation, dignified, clique","<b>Topic 0</b><br>Words: vestment, chaplain, requisite, denomination, divine","<b>Topic 0</b><br>Words: esq, surely, behold, departed, charles","<b>Topic 0</b><br>Words: extremely, respond, her, applaud, loudly","<b>Topic 0</b><br>Words: forward, butt, education, parnell, measure","<b>Topic 0</b><br>Words: rule, repeal, home, difference, they","<b>Topic 0</b><br>Words: themeselve, staunch, amidst, exhort, spirited","<b>Topic 0</b><br>Words: esq, conquer, eloquent, respond, spite","<b>Topic 0</b><br>Words: parnell, mr, keegan, subscribe, mayor","<b>Topic 0</b><br>Words: self, somewhere, hicks, would, michael","<b>Topic 0</b><br>Words: animated, wait, map, warmly, quickly","<b>Topic 0</b><br>Words: earnest, rule, home, preeminent, obtain","<b>Topic 0</b><br>Words: grievance, disraeli, ward, hartington, ronayne","<b>Topic 0</b><br>Words: barton, december, captain, johnston, lucky","<b>Topic 0</b><br>Words: provision, desirability, meath, relieve, protection","<b>Topic 0</b><br>Words: circle, tuesday, military, possess, considerable","<b>Topic 0</b><br>Words: cornwallis, intention, provision, meath, hardy","<b>Topic 0</b><br>Words: condon, spike, island, handcuff, whether","<b>Topic 0</b><br>Words: publichouse, parishioner, closing, petition, sunday","<b>Topic 0</b><br>Words: manslaughter, teacher, assize, monday, case","<b>Topic 0</b><br>Words: adjournment, parnell, mr, butt, debate","<b>Topic 0</b><br>Words: petty, clerk, appointment, meath, annul","<b>Topic 0</b><br>Words: petition, co, present, parnell, from","<b>Topic 0</b><br>Words: elcho, stifle, ignorant, unfortunate, altogether","<b>Topic 0</b><br>Words: chancellor, exchequer, decision, restricted, irish","<b>Topic 0</b><br>Words: plimsoll, bate, mr, condemn, parnell","<b>Topic 0</b><br>Words: manchester, brett, sergeant, maloney, junior","<b>Topic 0</b><br>Words: parnell, mr, challenge, amid, division","<b>Topic 0</b><br>Words: rebuke, anyone, expression, platform, else","<b>Topic 0</b><br>Words: rebuke, beaconsfield, talbot, excitable, less","<b>Topic 0</b><br>Words: your, midst, zulus, afghans, temerity","<b>Topic 0</b><br>Words: develin, kindness, prematurely, government, responsibility","<b>Topic 0</b><br>Words: oreilly, boyle, railroad, thank, quantity","<b>Topic 0</b><br>Words: parnell, rebellion, organize, mr, h ...

# %% [markdown]
# Next we remove stopwords from the lemmatized sentence dataframe, stopwords are words that will tend to lack specific meaning within a dataset due to their high frequency of appearance. We are also able to extend them to include our own stopwords specific to a dataset, such as crowd reactions in this case. Having done this we visualize topics over time with our new data.

# %%
#initialize stopwords list
stop_words = stopwords.words('english')
#extend stop words to include extra words
stop_words.extend(['every', 'would', 'cheer', 'hiss', 'applause', 'groan' 'could', 'upon', 'may', 'go',
                   'said', 'say', 'know', 'far', 'come', 'put', 'us', 'parnell', 'ireland', 'irish', 'mp',
                   'mr', 'dr', 'laughter', 'laugh', 'italics', 'irishman'])

#copy from lemmatized dataframe
df_stop = df_lemma.copy()
#use function to remove stopwords from all sentences in dataframe
df_stop['sentence'] = df_stop['sentence'].apply(lambda x: remove_stopwords(x, stop_words))
df_stop
# Out:
#                  filename     speech_id            publication  \
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# 0    parnell_source_00001  speech_00001             the nation
# ..                    ...           ...                    ...
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
# 660  parnell_source_00664  speech_00400  the freeman's journal
#
#                                               sentence               place  \
# 0    home rule league great meeting rotundo great s...     dublin, ireland
# 0    immense attendance platform gallery admission ...     dublin, ireland
# 0    charles stewart high sheriff wicklow occupy ch...     dublin, ireland
# 0    following report proceeding take somewhat abri...     dublin, ireland
# 0    view unwise course adopt opponent notably engl...     dublin, ireland
# ..                                                 ...                 ...
# 660  application perfectly disgraceful one one I sa...  waterford, ireland
# 660  good legal opinion sale since passing land act...  waterford, ireland
# 660  chairman already send form request particular ...  waterford, ireland
# 660                               chairman must settle  waterford, ireland
# 660                  expect I take everything shoulder  waterford, ireland
#
#           date
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# 0   1874-07-11
# ..         ...
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
# 660 1881-10-05
#
# [21851 rows x 6 columns]

# %%
#use function to get visualisation of topics for the whole dataset with lemmatized text and stopwords removed
stop_vis_obj = bertopic_time(df_stop, topic_model)
stop_vis = stop_vis_obj[0]
stop_vis
# Out:
# <div>                            <div id="02c62629-7431-411a-8aac-2a73ea00edee" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02c62629-7431-411a-8aac-2a73ea00edee")) {                    Plotly.newPlot(                        "02c62629-7431-411a-8aac-2a73ea00edee",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: chair, lady, manner, kind, chairman","<b>Topic 0</b><br>Words: ancient, custom, forget, advocacy, intelligent","<b>Topic 0</b><br>Words: world, national, people, party, oshea","<b>Topic 0</b><br>Words: rule, home, kell, principle, understand","<b>Topic 0</b><br>Words: geographical, fragment, curious, naturally, sometimes","<b>Topic 0</b><br>Words: resident, non, release, unfortunate, argument","<b>Topic 0</b><br>Words: conolly, indignant, ribbonism, donegal, assertion","<b>Topic 0</b><br>Words: rathdrum, goodly, townspeople, avondale, hearty","<b>Topic 0</b><br>Words: afternoon, war, hardy, answer, step","<b>Topic 0</b><br>Words: briefly, grant, bad, second, resolution","<b>Topic 0</b><br>Words: tuesday, louth, limerick, member, motion","<b>Topic 0</b><br>Words: guardian, levy, tax, england, obnoxious","<b>Topic 0</b><br>Words: lucrative, engage, cause, position, many","<b>Topic 0</b><br>Words: military, sentencing, exclamation, independently, dock","<b>Topic 0</b><br>Words: chairman, impartial, acclamation, painful, devolve","<b>Topic 0</b><br>Words: esq, liberate, urgently, chain, cheering","<b>Topic 0</b><br>Words: firmness, urge, determination, union, destine","<b>Topic 0</b><br>Words: rev, control, education, wrong, tired","<b>Topic 0</b><br>Words: repeal, difference, rule, home, cheering","<b>Topic 0</b><br>Words: spirited, address, receive, speech, loud","<b>Topic 0</b><br>Words: forester, resume, amid, fire, round","<b>Topic 0</b><br>Words: outlying, contingent, status, swell, procession","<b>Topic 0</b><br>Words: miscalculate, safety, constitutionally, strength, somewhere","<b>Topic 0</b><br>Words: animated, warmly, applaud, brief, mean","<b>Topic 0</b><br>Words: early, session, forward, period, promise","<b>Topic 0</b><br>Words: ringleader, ignore, vigorously, initiative, sailor","<b>Topic 0</b><br>Words: cavan, certain, rule, meeting, home","<b>Topic 0</b><br>Words: hardy, reflect, degree, slight, intention","<b>Topic 0</b><br>Words: condon, spike, handcuff, island, edward","<b>Topic 0</b><br>Words: moderately, italicise, heinous, acquittal, globe","<b>Topic 0</b><br>Words: 427gentleman, babel, tolerant, suggestion, drown","<b>Topic 0</b><br>Words: move, rejection, reduction, vote, party","<b>Topic 0</b><br>Words: revenue, restricted, narrow, department, plain","<b>Topic 0</b><br>Words: penalty, unfit, seaman, landsman, plimsoll","<b>Topic 0</b><br>Words: manchester, condon, maloney, junior, brave","<b>Topic 0</b><br>Words: callan, impugn, chairman, challenge, decision","<b>Topic 0</b><br>Words: provoke, rebuke, shoot, neither, speaker","<b>Topic 0</b><br>Words: black, downfall, harbinger, irishtown, handwriting","<b>Topic 0</b><br>Words: develin, speak, earth, character, double","<b>Topic 0</b><br>Words: railroad, injudicious, alleviate, supposing, action","<b>Topic 0</b><br>Words: annum, cite, per, estate, rental","<b>Topic 0</b><br>Words: contrast, province, kilkenny, munster, exceptional","<b>Topic 0</b><br>Words: owner, estate, clause, bright, land","<b>Topic 0</b><br>Words: debenture, sum, per, monthly, system","<b>Topic 0</b><br>Words: ticket, afflict, needy, necessitous, relieve","<b>Topic 0</b><br>Words: debenture, landlord, per, church, bright","<b>Topic 0</b><br>Words: revolution, generation, capita, system, feudal","<b>Topic 0</b><br>Words: stirring, competent, agency, enlist, wretched","<b>Topic 0</b><br>Words: mansion, sm ...

# %% [markdown]
# Sometimes reports for the same speech are more or less identical to other reports, due to them coming from the same original transcription. In order to prevent repetition from affecting the topic modelling process, we can remove instances of sentence repetition where the sentences are related to the same speech from our dataframe. We end up with a lemmatized dataframe with stopwords removed and repeated sentences related to the same speech removed. Having done this we visualize topics over time with our new data.

# %%
#drop duplicate sentences if they are related to same speech id to remove reports which are copies of others
df_drop = df_stop.drop_duplicates(subset=['speech_id', 'sentence'])
#use function to get visualisation of topics for the dataset with repetition removed with lemmatized text, stopwords
drop_vis_obj = bertopic_time(df_drop, topic_model)
drop_vis = drop_vis_obj[0]
drop_vis
# Out:
# <div>                            <div id="35d794f4-378b-4ec5-97b6-0c4659b3fccd" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35d794f4-378b-4ec5-97b6-0c4659b3fccd")) {                    Plotly.newPlot(                        "35d794f4-378b-4ec5-97b6-0c4659b3fccd",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: opportune, unwise, notably, persistently, juncture","<b>Topic 0</b><br>Words: ancient, undisturbed, custom, solvent, forget","<b>Topic 0</b><br>Words: separation, want, england, world, national","<b>Topic 0</b><br>Words: naper, crowd, hotel, hind, address","<b>Topic 0</b><br>Words: contented, geographical, fragment, hack, england","<b>Topic 0</b><br>Words: conolly, indignant, ribbonism, donegal, assertion","<b>Topic 0</b><br>Words: command, militia, attendance, officer, mass","<b>Topic 0</b><br>Words: militia, mass, 27th, dillon, command","<b>Topic 0</b><br>Words: fact, state, matter, lynch, vote","<b>Topic 0</b><br>Words: unprepared, arrangement, change, however, allow","<b>Topic 0</b><br>Words: guardian, levy, tax, england, writing","<b>Topic 0</b><br>Words: lucrative, engage, cause, position, many","<b>Topic 0</b><br>Words: vestment, board, grand, diocese, superintendence","<b>Topic 0</b><br>Words: chairman, inclined, conscience, include, debase","<b>Topic 0</b><br>Words: chaplain, vestment, requisite, denomination, divine","<b>Topic 0</b><br>Words: liberation, imprint, stand, esq, descendant","<b>Topic 0</b><br>Words: england, destine, ere, convert, stretch","<b>Topic 0</b><br>Words: rev, pound, education, control, england","<b>Topic 0</b><br>Words: england, cordially, oclock, owwn, detail","<b>Topic 0</b><br>Words: divine, command, honourable, service, denomination","<b>Topic 0</b><br>Words: new, member, lynch, vote, cork","<b>Topic 0</b><br>Words: mayor, subscribe, lord, list, oconnell","<b>Topic 0</b><br>Words: grievance, england, war, defenceless, let","<b>Topic 0</b><br>Words: mean, lot, whether, constitutional, gain","<b>Topic 0</b><br>Words: cc, timothy, lenehan, gaffney, carberry","<b>Topic 0</b><br>Words: ignore, vigorously, initiative, disraeli, adviser","<b>Topic 0</b><br>Words: scapular, lucky, cushion, barton, cover","<b>Topic 0</b><br>Words: bombay, army, native, staveley, loading","<b>Topic 0</b><br>Words: bombay, army, native, 25th, dismissal","<b>Topic 0</b><br>Words: militiaman, bombay, holiday, command, mass","<b>Topic 0</b><br>Words: condon, spike, island, handcuff, edward","<b>Topic 0</b><br>Words: 427gentleman, suggestion, fried, butt, glasgow","<b>Topic 0</b><br>Words: magistrate, stipendiary, reside, voting, mix","<b>Topic 0</b><br>Words: elcho, stifle, ignorant, unfortunate, altogether","<b>Topic 0</b><br>Words: whisky, restricted, narrow, revenue, scotch","<b>Topic 0</b><br>Words: bate, plymouth, thereby, condemnation, ship","<b>Topic 0</b><br>Words: manchester, van, condon, maloney, congress","<b>Topic 0</b><br>Words: callan, impugn, chairman, occasion, dundalk","<b>Topic 0</b><br>Words: reduce, bad, landlord, good, rent","<b>Topic 0</b><br>Words: provoke, rebuke, receipt, shoot, arrangement","<b>Topic 0</b><br>Words: downfall, inheritor, respecting, irishtown, handwriting","<b>Topic 0</b><br>Words: speak, earth, effectual, spread, ruler","<b>Topic 0</b><br>Words: railroad, injudicious, action, supposing, alleviate","<b>Topic 0</b><br>Words: annum, entail, organize, rebellion, per","<b>Topic 0</b><br>Words: munster, unable, contrast, province, check","<b>Topic 0</b><br>Words: owner, thousand, buy, estate, tenant","<b>Topic 0</b><br>Words: per, debenture, annum, england, pay","<b>Topic 0</b><br>Words: acknowledge, afflict, stare, appalling, taking","<b>Topic 0</b><br>Words: landlord, debenture, per, pay, cent","<b>To ...

# %% [markdown]
# Having performed performed various manipulations on the sentences, we can further narrow the data by time period to see how this affects the topics visualised over time.

# %%
#use function to restrict dataframe to a date window
df_80_81 = dataframe_date_window(df_drop, '1880-01-01', '1881-12-31')
#use function to get visualisation of topics for the date window with lemmatized text, stopwords, repetition removed
df_80_81_vis_obj = bertopic_time(df_80_81, topic_model)
df_80_81_vis = df_80_81_vis_obj[0]
df_80_81_vis
# Out:
# <div>                            <div id="a4061faa-52b9-4ea6-8cea-7d7e01885f0d" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4061faa-52b9-4ea6-8cea-7d7e01885f0d")) {                    Plotly.newPlot(                        "a4061faa-52b9-4ea6-8cea-7d7e01885f0d",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: develin, kindness, break, threshold, individually","<b>Topic 0</b><br>Words: oreilly, boyle, nolan, specially, thank","<b>Topic 0</b><br>Words: american, annum, rebellion, testimony, bring","<b>Topic 0</b><br>Words: shoot, landlord, people, english, money","<b>Topic 0</b><br>Words: thousand, estate, question, owner, land","<b>Topic 0</b><br>Words: per, tenant, england, pay, purchase","<b>Topic 0</b><br>Words: aid, distress, relieve, send, acknowledge","<b>Topic 0</b><br>Words: per, state, debenture, landlord, tenant","<b>Topic 0</b><br>Words: system, improve, landlord, soil, land","<b>Topic 0</b><br>Words: blooded, home, indication, variety, cold","<b>Topic 0</b><br>Words: obnoxious, land, country, demand, detain","<b>Topic 0</b><br>Words: host, equitable, vere, pattern, grateful","<b>Topic 0</b><br>Words: boston, aristocracy, thus, system, journal","<b>Topic 0</b><br>Words: one, land, blood, source, country","<b>Topic 0</b><br>Words: particep, crimen, fame, frustrate, safely","<b>Topic 0</b><br>Words: raise, send, desire, money, people","<b>Topic 0</b><br>Words: land, system, tenant, landlord, government","<b>Topic 0</b><br>Words: taint, almoner, express, hearer, even","<b>Topic 0</b><br>Words: politic, bond, landlord, government, land","<b>Topic 0</b><br>Words: scranton, unhealthy, succour, uncongenial, foster","<b>Topic 0</b><br>Words: nearly, transfer, thank, hunt, hold","<b>Topic 0</b><br>Words: sympathy, landlord, people, appeal, english","<b>Topic 0</b><br>Words: charity, landlord, rent, chicago, find","<b>Topic 0</b><br>Words: chicago, harrison, politic, feel, gentleman","<b>Topic 0</b><br>Words: work, beg, howl, feelingly, flogging","<b>Topic 0</b><br>Words: strongly, channel, america, money, government","<b>Topic 0</b><br>Words: govern, heartiness, possessor, subside, purchase","<b>Topic 0</b><br>Words: land, five, england, country, tenant","<b>Topic 0</b><br>Words: reform, conclusion, suffer, necessary, whether","<b>Topic 0</b><br>Words: address, america, chairman, representative, gentleman","<b>Topic 0</b><br>Words: honour, municipality, corporation, mark, great","<b>Topic 0</b><br>Words: betray, mislead, supporter, seek, rule","<b>Topic 0</b><br>Words: sample, service, ungrateful, britonism, requital","<b>Topic 0</b><br>Words: constituency, selection, place, unprepared, owing","<b>Topic 0</b><br>Words: wildest, vigorous, address, silence, wretched","<b>Topic 0</b><br>Words: match, boxing, quieter, agitate, thank","<b>Topic 0</b><br>Words: farmer, tenant, devote, unfortunately, representation","<b>Topic 0</b><br>Words: ruin, constituency, farmer, vote, gabbett","<b>Topic 0</b><br>Words: parliament, sell, represent, destiny, interest","<b>Topic 0</b><br>Words: constituency, earnest, shadow, thank, requisite","<b>Topic 0</b><br>Words: expense, conservative, ta, swear, sadli","<b>Topic 0</b><br>Words: circulate, lightly, farmer, advantage, believer","<b>Topic 0</b><br>Words: impede, dishonest, hearted, educate, merely","<b>Topic 0</b><br>Words: sufficiently, believe, work, man, four","<b>Topic 0</b><br>Words: fight, resound, inaugurate, echo, breadth","<b>Topic 0</b><br>Words: incumbrance, car, dozen, beneficial, deliver","<b>Topic 0</b><br>Words: compare, vacate, election, constituency, doubtful","<b>Topic 0</b><br>Words: sphere, republican, workingman, humble, endeavour","<b>Topic 0</b><br>Words: party, vital, miserable, former, draw", ...

# %% [markdown]
# Our final visualisation takes our dataframe with lemmatized text, stopwords and repetition related to same speech removed and narrows by sentences containing any of a list of keywords. We end up with a visualisation of topics over time for these keywords.

# %%
keywords = ['land', 'landlord']
#use function to restrict dataframe to rows where sentence contains any of keywords
df_keyword = dataframe_keyword(df_drop, keywords)
#use function to get visualisation of topics for keyword(s) with lemmatized text, stopwords, repetition removed
df_keyword_vis_obj = bertopic_time(df_keyword, topic_model)
df_keyword_vis = df_keyword_vis_obj[0]
df_keyword_vis
# Out:
# <div>                            <div id="ed54040a-92d1-47f6-b9cf-57b57c095fd5" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed54040a-92d1-47f6-b9cf-57b57c095fd5")) {                    Plotly.newPlot(                        "ed54040a-92d1-47f6-b9cf-57b57c095fd5",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: charles, stewart, double, second, important","<b>Topic 0</b><br>Words: bad, reduce, good, rent, tenant","<b>Topic 0</b><br>Words: appoint, disagree, estimate, another, ask","<b>Topic 0</b><br>Words: grant, american, rent, tenant, act","<b>Topic 0</b><br>Words: value, rack, rent, kavanagh, work","<b>Topic 0</b><br>Words: cease, rent, york, buy, new","<b>Topic 0</b><br>Words: estate, market, bright, tenant, clause","<b>Topic 0</b><br>Words: clause, bright, pay, tenant, rent","<b>Topic 0</b><br>Words: ward, withhold, predict, eight, warn","<b>Topic 0</b><br>Words: rent, debenture, tenant, pay, per","<b>Topic 0</b><br>Words: decrease, considerably, wait, reduce, agitation","<b>Topic 0</b><br>Words: build, demand, loan, waste, reclaim","<b>Topic 0</b><br>Words: side, small, beautifie, earning, thereon","<b>Topic 0</b><br>Words: abate, become, unbearable, productive, spring","<b>Topic 0</b><br>Words: approval, bright, create, principle, express","<b>Topic 0</b><br>Words: purchase, tenant, bond, occupy, advance","<b>Topic 0</b><br>Words: title, tenant, bright, vest, sell","<b>Topic 0</b><br>Words: six, advice, give, face, ago","<b>Topic 0</b><br>Words: tenant, get, wife, buy, facilitate","<b>Topic 0</b><br>Words: money, reproductive, loaning, fifty, employ","<b>Topic 0</b><br>Words: sell, bright, tenant, willing, clause","<b>Topic 0</b><br>Words: seed, traditional, potato, depart, custom","<b>Topic 0</b><br>Words: heel, worthless, good, record, deserve","<b>Topic 0</b><br>Words: award, permanent, rent, compensation, improvement","<b>Topic 0</b><br>Words: year, grip, twelve, renew, pledge","<b>Topic 0</b><br>Words: grip, circumstance, try, meet, plausibility","<b>Topic 0</b><br>Words: valuation, fallacious, joseph, tenement, uniform","<b>Topic 0</b><br>Words: compensation, deem, 9th, guarantee, calculate","<b>Topic 0</b><br>Words: severity, intense, remove, supply, addition","<b>Topic 0</b><br>Words: spend, shame, small, wage, probably","<b>Topic 0</b><br>Words: expend, third, assumption, unskilled, strip","<b>Topic 0</b><br>Words: believe, incalculable, work, prolong, lie","<b>Topic 0</b><br>Words: amount, distinctly, money, loan, government","<b>Topic 0</b><br>Words: attorney, valuable, rent, tenant, sale","<b>Topic 0</b><br>Words: high, pay, year, manifestly, current","<b>Topic 0</b><br>Words: like, soldier, preserve, peace, enough","<b>Topic 0</b><br>Words: less, perseverance, measure, acceptable, imperfect","<b>Topic 0</b><br>Words: rental, million, seventeen, amount, tenant","<b>Topic 0</b><br>Words: rent, tenant, lease, exorbitant, except","<b>Topic 0</b><br>Words: lease, tenant, greatly, nobleman, fulfil","<b>Topic 0</b><br>Words: arrear, price, fix, allow, rent","<b>Topic 0</b><br>Words: value, tenant, increase, counsel, employ","<b>Topic 0</b><br>Words: rent, fix, court, fair, farmer","<b>Topic 0</b><br>Words: rent, reduce, rack, large, purchase","<b>Topic 0</b><br>Words: excessive, still, claim, leave, rent","<b>Topic 0</b><br>Words: tolerate, indirectly, restoration, average, judge","<b>Topic 0</b><br>Words: million, year, rent, pay, eighty","<b>Topic 0</b><br>Words: perpetuate, mistake, intend, reduce, little","<b>Topic 0</b><br>Words: improvement, act, rent, tenant, clause","<b>Topic 0</b><br>Words: court, rent, fix, standard, application","<b>Topic 0</b><br>Words: rent, court, tenant, able, improvement","<b>Topic 0</b><br>Words: pay, rent, ...
